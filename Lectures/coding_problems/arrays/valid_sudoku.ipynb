# %%
board1 = [["5","3",".",".","7",".",".",".","."],["6",".",".","1","9","5",".",".","."],[".","9","8",".",".",".",".","6","."],["8",".",".",".","6",".",".",".","3"],["4",".",".","8",".","3",".",".","1"],["7",".",".",".","2",".",".",".","6"],[".","6",".",".",".",".","2","8","."],[".",".",".","4","1","9",".",".","5"],[".",".",".",".","8",".",".","7","9"]]

board2 = [["8","3",".",".","7",".",".",".","."],["6",".",".","1","9","5",".",".","."],[".","9","8",".",".",".",".","6","."],["8",".",".",".","6",".",".",".","3"],["4",".",".","8",".","3",".",".","1"],["7",".",".",".","2",".",".",".","6"],[".","6",".",".",".",".","2","8","."],[".",".",".","4","1","9",".",".","5"],[".",".",".",".","8",".",".","7","9"]]

# %%
board = board2
for i in range(0,9):
    row = [r for r in board[i]]# if r!='.']
    column = [row[i] for row in board]# if row[i]!='.']
    if len(set(row))!=len(row) or len(set(column))!=len(column):
        print(i)
        print(row)
        print(column)
        print(False)
# Out:
# 0
# ['8', '3', '.', '.', '7', '.', '.', '.', '.']
# ['8', '6', '.', '8', '4', '7', '.', '.', '.']
# False
# 1
# ['6', '.', '.', '1', '9', '5', '.', '.', '.']
# ['3', '.', '9', '.', '.', '.', '6', '.', '.']
# False
# 2
# ['.', '9', '8', '.', '.', '.', '.', '6', '.']
# ['.', '.', '8', '.', '.', '.', '.', '.', '.']
# False
# 3
# ['8', '.', '.', '.', '6', '.', '.', '.', '3']
# ['.', '1', '.', '.', '8', '.', '.', '4', '.']
# False
# 4
# ['4', '.', '.', '8', '.', '3', '.', '.', '1']
# ['7', '9', '.', '6', '.', '2', '.', '1', '8']
# False
# 5
# ['7', '.', '.', '.', '2', '.', '.', '.', '6']
# ['.', '5', '.', '.', '3', '.', '.', '9', '.']
# False
# 6
# ['.', '6', '.', '.', '.', '.', '2', '8', '.']
# ['.', '.', '.', '.', '.', '.', '2', '.', '.']
# False
# 7
# ['.', '.', '.', '4', '1', '9', '.', '.', '5']
# ['.', '.', '6', '.', '.', '.', '8', '.', '7']
# False
# 8
# ['.', '.', '.', '.', '8', '.', '.', '7', '9']
# ['.', '.', '.', '3', '1', '6', '.', '5', '9']
# False

# %%
m = 0 #rows
while m<9:
    n = 0
    for i in range(m,m+3):
        l = []
        for j in range(n,n+3):
            _ = board[i][j]
            if _!='.':
                l.append(_)
            n+=1
            if len(set(l))!=len(l):
                print(False)
                print(l)
        m+=3

# %%
m=0
while m<9:
    n = 0
    for i in range(m,m+3):
        for j in range(n,n+3):
            _ = board[i][j]
            print(i,j)
            #print(_)
        n+=1
    m+=3
# Out:
# 0 0
# 0 1
# 0 2
# 1 1
# 1 2
# 1 3
# 2 2
# 2 3
# 2 4
# 3 0
# 3 1
# 3 2
# 4 1
# 4 2
# 4 3
# 5 2
# 5 3
# 5 4
# 6 0
# 6 1
# 6 2
# 7 1
# 7 2
# 7 3
# 8 2
# 8 3
# 8 4

# %%
0,1,2 - 0,1,2
0,1,2 - 3,4,5
0,1,2 - 6,7,8

# %%
[["5","3",".",".","7",".",".",".","."],["6",".",".","1","9","5",".",".","."],[".","9","8",".",".",".",".","6","."],["8",".",".",".","6",".",".",".","3"],["4",".",".","8",".","3",".",".","1"],["7",".",".",".","2",".",".",".","6"],[".","6",".",".",".",".","2","8","."],[".",".",".","4","1","9",".",".","5"],[".",".",".",".","8",".",".","7","9"]]

# %%
m=0
n=0
for i in range(m,m+3):
    for j in range(n,n+3):
        print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2

# %%
[0,1,2] -> 0
[3,4,5] -> 1
[6,7,8] -> 2
# Out:
# [0, 1, 2]

# %%
if m==0 and n==0:
    k=0
elif m==3 and n==3:
    k=1
elif m==3 and n==

# %%
m=0
n=0
while n<9:
    L = []
    for i in range(m,m+3):
        for j in range(n,n+3):
            print(i,j)
    m+=3# one box
    if m==9:
        m=0
        n+=3
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2
# 3 0
# 3 1
# 3 2
# 4 0
# 4 1
# 4 2
# 5 0
# 5 1
# 5 2
# 6 0
# 6 1
# 6 2
# 7 0
# 7 1
# 7 2
# 8 0
# 8 1
# 8 2
# 0 3
# 0 4
# 0 5
# 1 3
# 1 4
# 1 5
# 2 3
# 2 4
# 2 5
# 3 3
# 3 4
# 3 5
# 4 3
# 4 4
# 4 5
# 5 3
# 5 4
# 5 5
# 6 3
# 6 4
# 6 5
# 7 3
# 7 4
# 7 5
# 8 3
# 8 4
# 8 5
# 0 6
# 0 7
# 0 8
# 1 6
# 1 7
# 1 8
# 2 6
# 2 7
# 2 8
# 3 6
# 3 7
# 3 8
# 4 6
# 4 7
# 4 8
# 5 6
# 5 7
# 5 8
# 6 6
# 6 7
# 6 8
# 7 6
# 7 7
# 7 8
# 8 6
# 8 7
# 8 8

# %%
Beats 69.48%of users with Python3
Memory
Details
16.20MB
Beats 96.97%of users with Python3
