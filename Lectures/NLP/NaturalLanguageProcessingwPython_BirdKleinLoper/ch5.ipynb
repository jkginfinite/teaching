# %% [markdown]
# # Ch5: Categorizing & Tagging Words
#
# Goals:
# 1. What are lexical categories and how are they used in NLP?
# 2. What is a good python data structure for stroing words and their categories?
# 3. How can we automatically tag each word of a text with it's word class?
#
#
# The process of classifying words into their parts of speech and labeling them accordingly is known as part of speech tagging, POS stagging AKA tagging. Parts of speech are also known as word classes or lexical categories. The collections used for a particular task is known as a tagset. Our emphasis in this chapter is on exploiting tags and tagging text auotmatically.

# %% [markdown]
# ### Using a tagger
#
# a part of speech tagger, or POS tagger, processes a sequence of words and attaches a part of speech tag to each word;

# %%
import nltk
text = nltk.word_tokenize("And now for something completely different")
nltk.pos_tag(text)
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %% [markdown]
# * CC: coordinating conjunction
# * RB: adverbs
# * IN: proposition
# * NN: noun
# * JJ: adjective

# %%
text = nltk.word_tokenize('They refuse to permit us to obtain the refuse permit.')
nltk.pos_tag(text)
# Out:
# [('They', 'PRP'),
#  ('refuse', 'VBP'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN'),
#  ('.', '.')]

# %% [markdown]
# * VRB: verb, non 3rd person singular
# * VB: verb, base singular marker
# * DT: determiner
# * NN: singular or mass

# %%
text = nltk.Text(word.lower() for word in nltk.corpus.brown.words())
text.similar('woman')
# Out:
# man time day year car moment world house family child country boy
# state job place way war girl work word

# %% [markdown]
# observe that searching for woman finds nouns. Searching for bought mostly finds verbs; searching for over generally finds propositions; searching the finds several determiner

# %%
text.similar('bought')
# Out:
# made said done put had seen found given left heard was been brought
# set got that took in told felt

# %% [markdown]
# searching for bought finds verbs

# %%
text.similar('the')
# Out:
# a his this their its her an that our any all one these my in your no
# some other and

# %% [markdown]
# searching for the finds determiners

# %% [markdown]
# # Tagged Corpora

# %%
tagged_token = nltk.tag.str2tuple('fly/NN')
tagged_token
# Out:
# ('fly', 'NN')

# %%
sent = '''
The/AT grand/JJ jury/NN commented/VBD on/IN a/AT number/NN of/IN
other/AP topics/NNS ,/, AMONG/IN them/PPO the/AT Atlanta/NP and/CC
Fulton/NP-t1 County/NN-t1 purchasing/VBG departments/NNS which WDT it/PPS
said/VBD ``/`` ARE/BER well/QL operated/VBN and/CC follow/VB generally/RB
accepted/VBN practices/NNS which/WDT inure/VB to/IN the/AT best/JJT
interest/NN of/IN both/ABX government/NNS ''/'' ./.
'''

# %%
[nltk.tag.str2tuple(t) for t in sent.split()]
# Out:
# [('The', 'AT'),
#  ('grand', 'JJ'),
#  ('jury', 'NN'),
#  ('commented', 'VBD'),
#  ('on', 'IN'),
#  ('a', 'AT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('other', 'AP'),
#  ('topics', 'NNS'),
#  (',', ','),
#  ('AMONG', 'IN'),
#  ('them', 'PPO'),
#  ('the', 'AT'),
#  ('Atlanta', 'NP'),
#  ('and', 'CC'),
#  ('Fulton', 'NP-T1'),
#  ('County', 'NN-T1'),
#  ('purchasing', 'VBG'),
#  ('departments', 'NNS'),
#  ('which', None),
#  ('WDT', None),
#  ('it', 'PPS'),
#  ('said', 'VBD'),
#  ('``', '``'),
#  ('ARE', 'BER'),
#  ('well', 'QL'),
#  ('operated', 'VBN'),
#  ('and', 'CC'),
#  ('follow', 'VB'),
#  ('generally', 'RB'),
#  ('accepted', 'VBN'),
#  ('practices', 'NNS'),
#  ('which', 'WDT'),
#  ('inure', 'VB'),
#  ('to', 'IN'),
#  ('the', 'AT'),
#  ('best', 'JJT'),
#  ('interest', 'NN'),
#  ('of', 'IN'),
#  ('both', 'ABX'),
#  ('government', 'NNS'),
#  ("''", "''"),
#  ('.', '.')]

# %%
nltk.corpus.brown.tagged_words()
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
nltk.corpus.conll2000.tagged_words()
# Out:
# [('Confidence', 'NN'), ('in', 'IN'), ('the', 'DT'), ...]

# %%
nltk.corpus.sinica_treebank.tagged_words()
# Out:
# [('一', 'Neu'), ('友情', 'Nad'), ('嘉珍', 'Nba'), ...]

# %%
nltk.corpus.mac_morpho.tagged_words()
# Out:
# [('Jersei', 'N'), ('atinge', 'V'), ('média', 'N'), ...]

# %%
from nltk.corpus import brown
brown_news_tagged = brown.tagged_words(categories='news')
tag_fd = nltk.FreqDist(tag for (word,tag) in brown_news_tagged)
tag_fd
# Out:
# FreqDist({'NN': 13162, 'IN': 10616, 'AT': 8893, 'NP': 6866, ',': 5133, 'NNS': 5066, '.': 4452, 'JJ': 4392, 'CC': 2664, 'VBD': 2524, ...})

# %%
word_tag_pairs = nltk.bigrams(brown_news_tagged)
list(nltk.FreqDist((a,b) for (a,b) in word_tag_pairs if b[1]=='NN'))
# Out:
# [(('per', 'IN'), ('cent', 'NN')),
#  (('the', 'AT'), ('state', 'NN')),
#  (('last', 'AP'), ('year', 'NN')),
#  (('last', 'AP'), ('week', 'NN')),
#  (('a', 'AT'), ('year', 'NN')),
#  (('the', 'AT'), ('city', 'NN')),
#  (('this', 'DT'), ('year', 'NN')),
#  (('the', 'AT'), ('jury', 'NN')),
#  (('a', 'AT'), ('result', 'NN')),
#  (('the', 'AT'), ('board', 'NN')),
#  (('the', 'AT'), ('ball', 'NN')),
#  (('a', 'AT'), ('number', 'NN')),
#  (('the', 'AT'), ('world', 'NN')),
#  (('the', 'AT'), ('year', 'NN')),
#  (('last', 'AP'), ('night', 'NN')),
#  ((',', ','), ('president', 'NN')),
#  (('his', 'PP$'), ('wife', 'NN')),
#  (('the', 'AT'), ('day', 'NN')),
#  (('this', 'DT'), ('week', 'NN')),
#  (('a', 'AT'), ('member', 'NN')),
#  (('the', 'AT'), ('administration', 'NN')),
#  (('the', 'AT'), ('country', 'NN')),
#  (('the', 'AT'), ('way', 'NN')),
#  (('the', 'AT'), ('man', 'NN')),
#  (('the', 'AT'), ('university', 'NN')),
#  (('a', 'AT'), ('meeting', 'NN')),
#  (('the', 'AT'), ('past', 'NN')),
#  (('the', 'AT'), ('problem', 'NN')),
#  (('the', 'AT'), ('project', 'NN')),
#  (('the', 'AT'), ('time', 'NN')),
#  (('high', 'JJ'), ('school', 'NN')),
#  (('the', 'AT'), ('meeting', 'NN')),
#  (('the', 'AT'), ('game', 'NN')),
#  (('the', 'AT'), ('plane', 'NN')),
#  (('the', 'AT'), ('case', 'NN')),
#  (('the', 'AT'), ('fact', 'NN')),
#  (('in', 'IN'), ('front', 'NN')),
#  (('a', 'AT'), ('car', 'NN')),
#  (('the', 'AT'), ('election', 'NN')),
#  (('the', 'AT'), ('bill', 'NN')),
#  (('a', 'AT'), ('group', 'NN')),
#  (('a', 'AT'), ('series', 'NN')),
#  (('vice', 'NN'), ('president', 'NN')),
#  (('a', 'AT'), ('week', 'NN')),
#  (('an', 'AT'), ('hour', 'NN')),
#  (('of', 'IN'), ('course', 'NN')),
#  (('The', 'AT'), ('jury', 'NN')),
#  (('the', 'AT'), ('end', 'NN')),
#  (('the', 'AT'), ('party', 'NN')),
#  (('the', 'AT'), ('committee', 'NN')),
#  (('In', 'IN'), ('addition', 'NN')),
#  (('first', 'OD'), ('time', 'NN')),
#  ((',', ','), ('chairman', 'NN')),
#  (('a', 'AT'), ('man', 'NN')),
#  (('tax', 'NN'), ('bill', 'NN')),
#  (('the', 'AT'), ('family', 'NN')),
#  (('the', 'AT'), ('field', 'NN')),
#  (('this', 'DT'), ('season', 'NN')),
#  (('a', 'AT'), ('month', 'NN')),
#  (('the', 'AT'), ('agency', 'NN')),
#  (('for', 'IN'), ('example', 'NN')),
#  (('the', 'AT'), ('future', 'NN')),
#  (('social', 'JJ'), ('security', 'NN')),
#  (('the', 'AT'), ('hospital', 'NN')),
#  (('the', 'AT'), ('government', 'NN')),
#  (('the', 'AT'), ('council', 'NN')),
#  (('the', 'AT'), ('situation', 'NN')),
#  (('the', 'AT'), ('nation', 'NN')),
#  (('the', 'AT'), ('public', 'NN')),
#  (('the', 'AT'), ('value', 'NN')),
#  (('the', 'AT'), ('kind', 'NN')),
#  (('the', 'AT'), ('program', 'NN')),
#  (('the', 'AT'), ('center', 'NN')),
#  (('sales', 'NNS'), ('tax', 'NN')),
#  (('the', 'AT'), ('total', 'NN')),
#  (('home', 'NN'), ('run', 'NN')),
#  (('the', 'AT'), ('tournament', 'NN')),
#  (('the', 'AT'), ('school', 'NN')),
#  (('higher', 'JJR'), ('education', 'NN')),
#  (('The', 'AT'), ('company', 'NN')),
#  (('farm', 'NN'), ('equipment', 'NN')),
#  (('the', 'AT'), ('system', 'NN')),
#  (('the', 'AT'), ('law', 'NN')),
#  (('a', 'AT'), ('candidate', 'NN')),
#  (('the', 'AT'), ('need', 'NN')),
#  (('a', 'AT'), ('way', 'NN')),
#  (('the', 'AT'), ('work', 'NN')),
#  (('the', 'AT'), ('ground', 'NN')),
#  (('the', 'AT'), ('question', 'NN')),
#  (('the', 'AT'), ('matter', 'NN')),
#  (('one', 'CD'), ('time', 'NN')),
#  (('the', 'AT'), ('statement', 'NN')),
#  (('civil', 'JJ'), ('defense', 'NN')),
#  (('the', 'AT'), ('town', 'NN')),
#  (('home', 'NR'), ('rule', 'NN')),
#  ((',', ','), ('director', 'NN')),
#  (('the', 'AT'), ('club', 'NN')),
#  (('the', 'AT'), ('season', 'NN')),
#  (('a', 'AT'), ('lot', 'NN')),
#  (('next', 'AP'), ('week', 'NN')),
#  (('the', 'AT'), ('weekend', 'NN')),
#  (('her', 'PP$'), ('husband', 'NN')),
#  ((',', ','), ('daughter', 'NN')),
#  (('collective', 'JJ'), ('bargaining', 'NN')),
#  (('the', 'AT'), ('stock', 'NN')),
#  (('the', 'AT'), ('market', 'NN')),
#  (('Soviet', 'NN-TL'), ('leader', 'NN')),
#  (('grand', 'JJ'), ('jury', 'NN')),
#  (('the', 'AT'), ('court', 'NN')),
#  (('in', 'IN'), ('fact', 'NN')),
#  (('a', 'AT'), ('daughter', 'NN')),
#  (('the', 'AT'), ('county', 'NN')),
#  (('a', 'AT'), ('system', 'NN')),
#  (('a', 'AT'), ('vote', 'NN')),
#  (('the', 'AT'), ('resolution', 'NN')),
#  (('a', 'AT'), ('school', 'NN')),
#  (('a', 'AT'), ('bill', 'NN')),
#  (('real', 'JJ'), ('estate', 'NN')),
#  (('an', 'AT'), ('effort', 'NN')),
#  (('the', 'AT'), ('fire', 'NN')),
#  (('the', 'AT'), ('subject', 'NN')),
#  (('of', 'IN'), ('education', 'NN')),
#  (('a', 'AT'), ('day', 'NN')),
#  (('a', 'AT'), ('program', 'NN')),
#  (('the', 'AT'), ('money', 'NN')),
#  (('the', 'AT'), ('area', 'NN')),
#  (('the', 'AT'), ('floor', 'NN')),
#  (('in', 'IN'), ('order', 'NN')),
#  (('foreign', 'JJ'), ('policy', 'NN')),
#  (('Kennedy', 'NP'), ('administration', 'NN')),
#  (('the', 'AT'), ('conference', 'NN')),
#  (('in', 'IN'), ('favor', 'NN')),
#  (('the', 'AT'), ('tax', 'NN')),
#  (('same', 'AP'), ('time', 'NN')),
#  (('an', 'AT'), ('opportunity', 'NN')),
#  (('the', 'AT'), ('organization', 'NN')),
#  (('special', 'JJ'), ('session', 'NN')),
#  (('that', 'DT'), ('time', 'NN')),
#  (('the', 'AT'), ('house', 'NN')),
#  (('the', 'AT'), ('car', 'NN')),
#  (('Monday', 'NR'), ('night', 'NN')),
#  (('Last', 'AP'), ('week', 'NN')),
#  (('Friday', 'NR'), ('night', 'NN')),
#  (('the', 'AT'), ('church', 'NN')),
#  (('a', 'AT'), ('conspiracy', 'NN')),
#  (('the', 'AT'), ('start', 'NN')),
#  (('the', 'AT'), ('opening', 'NN')),
#  (('the', 'AT'), ('result', 'NN')),
#  (('this', 'DT'), ('month', 'NN')),
#  (('a', 'AT'), ('knee', 'NN')),
#  (('the', 'AT'), ('team', 'NN')),
#  (('a', 'AT'), ('total', 'NN')),
#  (('the', 'AT'), ('back', 'NN')),
#  (('is', 'BEZ'), ('chairman', 'NN')),
#  (('the', 'AT'), ('basis', 'NN')),
#  (('the', 'AT'), ('number', 'NN')),
#  ((',', ','), ('state', 'NN')),
#  (('Tuesday', 'NR'), ('night', 'NN')),
#  (('some', 'DTI'), ('time', 'NN')),
#  (('a', 'AT'), ('plan', 'NN')),
#  (('a', 'AT'), ('bit', 'NN')),
#  (('in', 'IN'), ('prison', 'NN')),
#  (('the', 'AT'), ('governor', 'NN')),
#  (('the', 'AT'), ('bench', 'NN')),
#  (('the', 'AT'), ('help', 'NN')),
#  (('a', 'AT'), ('matter', 'NN')),
#  (('care', 'NN'), ('plan', 'NN')),
#  (('payroll', 'NN'), ('tax', 'NN')),
#  (('the', 'AT'), ('plan', 'NN')),
#  (('first', 'OD'), ('year', 'NN')),
#  (('a', 'AT'), ('base', 'NN')),
#  (('the', 'AT'), ('development', 'NN')),
#  (('the', 'AT'), ('salary', 'NN')),
#  (('a', 'AT'), ('letter', 'NN')),
#  (('and', 'CC'), ('state', 'NN')),
#  (('young', 'JJ'), ('man', 'NN')),
#  (('rule', 'NN'), ('charter', 'NN')),
#  (('the', 'AT'), ('group', 'NN')),
#  (('the', 'AT'), ('primary', 'NN')),
#  (('of', 'IN'), ('labor', 'NN')),
#  (('The', 'AT'), ('announcement', 'NN')),
#  (('Democratic', 'JJ-TL'), ('party', 'NN')),
#  (('of', 'IN'), ('work', 'NN')),
#  (('the', 'AT'), ('union', 'NN')),
#  (('the', 'AT'), ('battle', 'NN')),
#  (('The', 'AT'), ('city', 'NN')),
#  (('the', 'AT'), ('part', 'NN')),
#  (('his', 'PP$'), ('home', 'NN')),
#  (('the', 'AT'), ('army', 'NN')),
#  (('a', 'AT'), ('graduate', 'NN')),
#  ((',', ','), ('Aj', 'NN')),
#  (('the', 'AT'), ('face', 'NN')),
#  (('a', 'AT'), ('pair', 'NN')),
#  (('the', 'AT'), ('hole', 'NN')),
#  (('the', 'AT'), ('boy', 'NN')),
#  (('a', 'AT'), ('while', 'NN')),
#  (('four', 'CD'), ('home', 'NN')),
#  (('the', 'AT'), ('series', 'NN')),
#  (('in', 'IN'), ('marriage', 'NN')),
#  (('his', 'PP$'), ('brother', 'NN')),
#  (('wedding', 'NN'), ('trip', 'NN')),
#  ((',', ','), ('son', 'NN')),
#  (('in', 'IN'), ('hand', 'NN')),
#  (('her', 'PP$'), ('home', 'NN')),
#  (('in', 'IN'), ('charge', 'NN')),
#  (('to', 'IN'), ('school', 'NN')),
#  (('her', 'PP$'), ('father', 'NN')),
#  (('the', 'AT'), ('verdict', 'NN')),
#  (('the', 'AT'), ('trial', 'NN')),
#  (('a', 'AT'), ('collection', 'NN')),
#  (('the', 'AT'), ('month', 'NN')),
#  (('the', 'AT'), ('possibility', 'NN')),
#  (('a', 'AT'), ('share', 'NN')),
#  (('potato', 'NN'), ('chip', 'NN')),
#  (('gin', 'NN'), ('machinery', 'NN')),
#  (('The', 'AT'), ('firm', 'NN')),
#  (('this', 'DT'), ('country', 'NN')),
#  (('the', 'AT'), ('course', 'NN')),
#  (('an', 'AT'), ('investigation', 'NN')),
#  (('took', 'VBD'), ('place', 'NN')),
#  (('the', 'AT'), ('establishment', 'NN')),
#  (('a', 'AT'), ('son', 'NN')),
#  (('and', 'CC'), ('wife', 'NN')),
#  (('city', 'NN'), ('council', 'NN')),
#  (('the', 'AT'), ('audience', 'NN')),
#  (('a', 'AT'), ('state', 'NN')),
#  (('for', 'IN'), ('governor', 'NN')),
#  (('bond', 'NN'), ('issue', 'NN')),
#  (('million', 'CD'), ('worth', 'NN')),
#  (('the', 'AT'), ('act', 'NN')),
#  (('a', 'AT'), ('resolution', 'NN')),
#  (('the', 'AT'), ('event', 'NN')),
#  (('school', 'NN'), ('superintendent', 'NN')),
#  (('school', 'NN'), ('board', 'NN')),
#  (('the', 'AT'), ('fight', 'NN')),
#  (('the', 'AT'), ('economy', 'NN')),
#  (('a', 'AT'), ('board', 'NN')),
#  (('a', 'AT'), ('law', 'NN')),
#  (('in', 'IN'), ('college', 'NN')),
#  (('The', 'AT'), ('report', 'NN')),
#  (('tomorrow', 'NR'), ('night', 'NN')),
#  (('23d', 'OD'), ('ward', 'NN')),
#  (('aged', 'VBN'), ('care', 'NN')),
#  (('of', 'IN'), ('health', 'NN')),
#  (('The', 'AT'), ('plan', 'NN')),
#  (('in', 'IN'), ('connection', 'NN')),
#  (('the', 'AT'), ('balance', 'NN')),
#  (('a', 'AT'), ('coalition', 'NN')),
#  (('coalition', 'NN'), ('government', 'NN')),
#  (('each', 'DT'), ('year', 'NN')),
#  (('the', 'AT'), ('opinion', 'NN')),
#  (('in', 'IN'), ('case', 'NN')),
#  (('first', 'OD'), ('aid', 'NN')),
#  (('local', 'JJ'), ('level', 'NN')),
#  (('in', 'IN'), ('mind', 'NN')),
#  (('the', 'AT'), ('form', 'NN')),
#  (('of', 'IN'), ('government', 'NN')),
#  (('the', 'AT'), ('charter', 'NN')),
#  (('the', 'AT'), ('movement', 'NN')),
#  (('the', 'AT'), ('fall', 'NN')),
#  (('income', 'NN'), ('tax', 'NN')),
#  (('for', 'IN'), ('help', 'NN')),
#  (('as', 'CS'), ('president', 'NN')),
#  (('a', 'AT'), ('position', 'NN')),
#  (('the', 'AT'), ('truth', 'NN')),
#  (('the', 'AT'), ('impression', 'NN')),
#  (('the', 'AT'), ('return', 'NN')),
#  (('an', 'AT'), ('example', 'NN')),
#  (('the', 'AT'), ('staff', 'NN')),
#  ((',', ','), ('head', 'NN')),
#  (('a', 'AT'), ('native', 'NN')),
#  (('.', '.'), ('Division', 'NN')),
#  (('the', 'AT'), ('move', 'NN')),
#  (('a', 'AT'), ('tax', 'NN')),
#  (('the', 'AT'), ('spring', 'NN')),
#  (('for', 'IN'), ('work', 'NN')),
#  (('the', 'AT'), ('wall', 'NN')),
#  (('the', 'AT'), ('association', 'NN')),
#  (('a', 'AT'), ('decade', 'NN')),
#  (('no', 'AT'), ('reason', 'NN')),
#  (('the', 'AT'), ('afternoon', 'NN')),
#  (('the', 'AT'), ('top', 'NN')),
#  (('the', 'AT'), ("A's", 'NN')),
#  (('a', 'AT'), ('walk', 'NN')),
#  (('the', 'AT'), ('plate', 'NN')),
#  (('first', 'OD'), ('inning', 'NN')),
#  (('a', 'AT'), ('triple', 'NN')),
#  (('the', 'AT'), ('lead', 'NN')),
#  (('Saturday', 'NR'), ('night', 'NN')),
#  (('last', 'AP'), ('season', 'NN')),
#  (('the', 'AT'), ('line', 'NN')),
#  (('&', 'CC'), ('M', 'NN')),
#  (('In', 'IN'), ('fact', 'NN')),
#  (('the', 'AT'), ('book', 'NN')),
#  (('the', 'AT'), ('head', 'NN')),
#  (('the', 'AT'), ('road', 'NN')),
#  (('a', 'AT'), ('team', 'NN')),
#  (('the', 'AT'), ('championship', 'NN')),
#  (('a', 'AT'), ('record', 'NN')),
#  (('the', 'AT'), ('green', 'NN')),
#  (('a', 'AT'), ('game', 'NN')),
#  (('a', 'AT'), ('student', 'NN')),
#  (('a', 'AT'), ('wedding', 'NN')),
#  (('board', 'NN'), ('member', 'NN')),
#  (('Her', 'PP$'), ('husband', 'NN')),
#  (('the', 'AT'), ('wedding', 'NN')),
#  (('their', 'PP$'), ('daughter', 'NN')),
#  (('in', 'IN'), ('town', 'NN')),
#  (('a', 'AT'), ('luncheon', 'NN')),
#  (('the', 'AT'), ('panel', 'NN')),
#  (('his', 'PP$'), ('money', 'NN')),
#  (('his', 'PP$'), ('office', 'NN')),
#  (('the', 'AT'), ('name', 'NN')),
#  (('the', 'AT'), ('bus', 'NN')),
#  (('a', 'AT'), ('word', 'NN')),
#  (('of', 'IN'), ('race', 'NN')),
#  (('higher', 'JJR'), ('learning', 'NN')),
#  (('the', 'AT'), ('rest', 'NN')),
#  (('data', 'NN'), ('processing', 'NN')),
#  (('a', 'AT'), ('strike', 'NN')),
#  (('the', 'AT'), ('crew', 'NN')),
#  (('a', 'AT'), ('girl', 'NN')),
#  (('the', 'AT'), ('demand', 'NN')),
#  (('chip', 'NN'), ('industry', 'NN')),
#  (('farm', 'NN'), ('machinery', 'NN')),
#  (('in', 'IN'), ('turn', 'NN')),
#  (('the', 'AT'), ('collection', 'NN')),
#  (('the', 'AT'), ('concert', 'NN')),
#  (('little', 'JJ'), ('car', 'NN')),
#  (('my', 'PP$'), ('wife', 'NN')),
#  (('the', 'AT'), ('light', 'NN')),
#  (('the', 'AT'), ('gas', 'NN')),
#  (('the', 'AT'), ('tour', 'NN')),
#  (('cold', 'JJ'), ('war', 'NN')),
#  (('religious', 'JJ'), ('community', 'NN')),
#  (('The', 'AT'), ('problem', 'NN')),
#  (('the', 'AT'), ('institution', 'NN')),
#  (('any', 'DTI'), ('case', 'NN')),
#  (('first', 'OD'), ('place', 'NN')),
#  (('of', 'IN'), ('golf', 'NN')),
#  (('.', '.'), ('Traffic', 'NN')),
#  (('the', 'AT'), ('toll-road', 'NN')),
#  (('the', 'AT'), ('turnpike', 'NN')),
#  (('textile', 'NN'), ('industry', 'NN')),
#  (('U.S.', 'NP'), ('coal', 'NN')),
#  (('the', 'AT'), ('size', 'NN')),
#  (('this', 'DT'), ('city', 'NN')),
#  (('the', 'AT'), ('cost', 'NN')),
#  (('this', 'DT'), ('problem', 'NN')),
#  (('the', 'AT'), ('welfare', 'NN')),
#  (('the', 'AT'), ('appointment', 'NN')),
#  (('in', 'IN'), ('effect', 'NN')),
#  (('pension', 'NN'), ('plan', 'NN')),
#  (('the', 'AT'), ('couple', 'NN')),
#  (('the', 'AT'), ('race', 'NN')),
#  (('state', 'NN'), ('law', 'NN')),
#  (('the', 'AT'), ('highway', 'NN')),
#  (('Monday', 'NR'), ('afternoon', 'NN')),
#  (('The', 'AT'), ('department', 'NN')),
#  (('Sunday', 'NR'), ('night', 'NN')),
#  (('the', 'AT'), ('increase', 'NN')),
#  (('the', 'AT'), ('action', 'NN')),
#  (('constitutional', 'JJ'), ('amendment', 'NN')),
#  (('of', 'IN'), ('trouble', 'NN')),
#  (('county', 'NN'), ('school', 'NN')),
#  (('the', 'AT'), ('measure', 'NN')),
#  (('The', 'AT'), ('bill', 'NN')),
#  (('the', 'AT'), ('right', 'NN')),
#  ((',', ','), ('attorney', 'NN')),
#  (('attorney', 'NN'), ('general', 'NN')),
#  (('The', 'AT'), ('proposal', 'NN')),
#  (('The', 'AT'), ('board', 'NN')),
#  (('Texas', 'NP'), ('A', 'NN')),
#  (('.', '.'), ('State', 'NN')),
#  (('in', 'IN'), ('employment', 'NN')),
#  (('blue', 'JJ'), ('ribbon', 'NN')),
#  (('the', 'AT'), ('community', 'NN')),
#  (('of', 'IN'), ('color', 'NN')),
#  (('the', 'AT'), ('request', 'NN')),
#  (('the', 'AT'), ('address', 'NN')),
#  (('by', 'IN'), ('telephone', 'NN')),
#  (('a', 'AT'), ('case', 'NN')),
#  (('the', 'AT'), ('vote', 'NN')),
#  (('railroad', 'NN'), ('retirement', 'NN')),
#  (('child', 'NN'), ('health', 'NN')),
#  (('the', 'AT'), ('payroll', 'NN')),
#  (('nursing', 'VBG'), ('home', 'NN')),
#  (('million', 'CD'), ('dollar', 'NN')),
#  (('an', 'AT'), ('increase', 'NN')),
#  (('the', 'AT'), ('message', 'NN')),
#  (('long', 'JJ'), ('time', 'NN')),
#  (('the', 'AT'), ('NATO', 'NN')),
#  (('the', 'AT'), ('heart', 'NN')),
#  (('the', 'AT'), ('alliance', 'NN')),
#  (('new', 'JJ'), ('administration', 'NN')),
#  (('the', 'AT'), ('maintenance', 'NN')),
#  (('Geneva', 'NP'), ('conference', 'NN')),
#  (('a', 'AT'), ('possibility', 'NN')),
#  (('economic', 'JJ'), ('aid', 'NN')),
#  (('free', 'JJ'), ('world', 'NN')),
#  (('Communist', 'NN-TL'), ('bloc', 'NN')),
#  (('nuclear', 'JJ'), ('test', 'NN')),
#  (('The', 'AT'), ('administration', 'NN')),
#  (('pro-Western', 'JJ'), ('government', 'NN')),
#  (('full-time', 'JJ'), ('director', 'NN')),
#  (('defense', 'NN'), ('program', 'NN')),
#  (('CD', 'NN'), ('director', 'NN')),
#  (('federal', 'JJ'), ('government', 'NN')),
#  (('the', 'AT'), ('study', 'NN')),
#  (('an', 'AT'), ('eye', 'NN')),
#  (('the', 'AT'), ('benefit', 'NN')),
#  (('The', 'AT'), ('council', 'NN')),
#  (('The', 'AT'), ('law', 'NN')),
#  (('charter', 'NN'), ('commission', 'NN')),
#  (('of', 'IN'), ('opinion', 'NN')),
#  (('cocktail', 'NN'), ('party', 'NN')),
#  (('The', 'AT'), ('state', 'NN')),
#  (('gubernatorial', 'JJ'), ('nomination', 'NN')),
#  (('is', 'BEZ'), ('president', 'NN')),
#  (('the', 'AT'), ('loan', 'NN')),
#  (('a', 'AT'), ('lawyer', 'NN')),
#  (('the', 'AT'), ('test', 'NN')),
#  (('no', 'AT'), ('matter', 'NN')),
#  (('his', 'PP$'), ('performance', 'NN')),
#  (('Democratic', 'JJ-TL'), ('leader', 'NN')),
#  (('in', 'IN'), ('touch', 'NN')),
#  (('a', 'AT'), ('discussion', 'NN')),
#  (('the', 'AT'), ('key', 'NN')),
#  (('the', 'AT'), ('report', 'NN')),
#  (('housing', 'VBG'), ('bill', 'NN')),
#  (('an', 'AT'), ('interview', 'NN')),
#  (('the', 'AT'), ('company', 'NN')),
#  (('the', 'AT'), ('service', 'NN')),
#  (('that', 'DT'), ('day', 'NN')),
#  (('presidential', 'JJ'), ('election', 'NN')),
#  (('take', 'VB'), ('part', 'NN')),
#  (('state', 'NN'), ('government', 'NN')),
#  (('in', 'IN'), ('office', 'NN')),
#  (('the', 'AT'), ('pressure', 'NN')),
#  (('Hughes', 'NP'), ('concern', 'NN')),
#  (('full', 'JJ'), ('amount', 'NN')),
#  (('performance', 'NN'), ('bond', 'NN')),
#  (('a', 'AT'), ('period', 'NN')),
#  (('press', 'NN'), ('conference', 'NN')),
#  (('the', 'AT'), ('morning', 'NN')),
#  (('Hughes', 'NP'), ('company', 'NN')),
#  (('and', 'CC'), ('city', 'NN')),
#  (('The', 'AT'), ('contract', 'NN')),
#  (('a', 'AT'), ('hearing', 'NN')),
#  (('wide', 'JJ'), ('variety', 'NN')),
#  (('the', 'AT'), ('remainder', 'NN')),
#  (('on', 'IN'), ('behalf', 'NN')),
#  (('the', 'AT'), ('accident', 'NN')),
#  (('of', 'IN'), ('land', 'NN')),
#  (('fighters', 'NNS'), ('association', 'NN')),
#  (('teamsters', 'NNS'), ('union', 'NN')),
#  (('The', 'AT'), ('fire', 'NN')),
#  (('the', 'AT'), ('job', 'NN')),
#  (('of', 'IN'), ('state', 'NN')),
#  (('annual', 'JJ'), ('meeting', 'NN')),
#  (('the', 'AT'), ('interest', 'NN')),
#  (('the', 'AT'), ('contest', 'NN')),
#  (('last', 'AP'), ('fall', 'NN')),
#  (('the', 'AT'), ('night', 'NN')),
#  (('right', 'JJ'), ('center', 'NN')),
#  (('night', 'NN'), ('game', 'NN')),
#  (('a', 'AT'), ('row', 'NN')),
#  (('last', 'AP'), ('spring', 'NN')),
#  (('the', 'AT'), ('league', 'NN')),
#  (('Last', 'AP'), ('year', 'NN')),
#  (('knee', 'NN'), ('injury', 'NN')),
#  (('the', 'AT'), ('feel', 'NN')),
#  (('that', 'DT'), ('way', 'NN')),
#  (('the', 'AT'), ('stage', 'NN')),
#  (('the', 'AT'), ('score', 'NN')),
#  (('a', 'AT'), ('ball', 'NN')),
#  (('no', 'AT'), ('doubt', 'NN')),
#  (('the', 'AT'), ('clubhouse', 'NN')),
#  (('minor', 'JJ'), ('league', 'NN')),
#  (('League', 'NN-TL'), ('club', 'NN')),
#  (('a', 'AT'), ('spirit', 'NN')),
#  (('a', 'AT'), ('dozen', 'NN')),
#  (('his', 'PP$'), ('way', 'NN')),
#  (('the', 'AT'), ('executive', 'NN')),
#  (('a', 'AT'), ('stroke', 'NN')),
#  (('his', 'PP$'), ('record', 'NN')),
#  (('the', 'AT'), ('news', 'NN')),
#  (('A', 'AT'), ('year', 'NN')),
#  (('a', 'AT'), ('home', 'NN')),
#  (('each', 'DT'), ('month', 'NN')),
#  (('best', 'JJT'), ('man', 'NN')),
#  (('his', 'PP$'), ('bride', 'NN')),
#  (('of', 'IN'), ('publicity', 'NN')),
#  (('a', 'AT'), ('cocktail', 'NN')),
#  (('a', 'AT'), ('dinner', 'NN')),
#  (('the', 'AT'), ('setting', 'NN')),
#  (('the', 'AT'), ('engagement', 'NN')),
#  (('any', 'DTI'), ('time', 'NN')),
#  (('the', 'AT'), ('summer', 'NN')),
#  (('the', 'AT'), ('birth', 'NN')),
#  (('their', 'PP$'), ('home', 'NN')),
#  (('fashion', 'NN'), ('show', 'NN')),
#  (('The', 'AT'), ('event', 'NN')),
#  (('the', 'AT'), ('luncheon', 'NN')),
#  (('his', 'PP$'), ('fellow', 'NN')),
#  (('under', 'IN'), ('way', 'NN')),
#  (('the', 'AT'), ('home', 'NN')),
#  (('the', 'AT'), ('bride', 'NN')),
#  (('the', 'AT'), ('son', 'NN')),
#  (('a', 'AT'), ('reception', 'NN')),
#  (('the', 'AT'), ('admission', 'NN')),
#  (('and', 'CC'), ('daughter', 'NN')),
#  (('The', 'AT'), ('victim', 'NN')),
#  (('a', 'AT'), ('fire', 'NN')),
#  (('the', 'AT'), ('snow', 'NN')),
#  (('the', 'AT'), ('week', 'NN')),
#  (('the', 'AT'), ('kitchen', 'NN')),
#  (('housing', 'VBG'), ('market', 'NN')),
#  ((',', ','), ('vice', 'NN')),
#  (('a', 'AT'), ('house', 'NN')),
#  (('Saturday', 'NR'), ('evening', 'NN')),
#  (('The', 'AT'), ('fact', 'NN')),
#  (('a', 'AT'), ('jury', 'NN')),
#  (('and', 'CC'), ('development', 'NN')),
#  (('the', 'AT'), ('product', 'NN')),
#  (('the', 'AT'), ('indictment', 'NN')),
#  (('the', 'AT'), ('youth', 'NN')),
#  (('the', 'AT'), ('murder', 'NN')),
#  (('high', 'JJ'), ('speed', 'NN')),
#  (('reckless', 'JJ'), ('driving', 'NN')),
#  (('a', 'AT'), ('verdict', 'NN')),
#  (('the', 'AT'), ('farm', 'NN')),
#  (('the', 'AT'), ('evidence', 'NN')),
#  (('first', 'OD'), ('day', 'NN')),
#  (('Kowalski', 'NP'), ('family', 'NN')),
#  ((',', ','), ('color', 'NN')),
#  (('or', 'CC'), ('creed', 'NN')),
#  (('a', 'AT'), ('utility', 'NN')),
#  (('utility', 'NN'), ('pole', 'NN')),
#  ((',', ','), ('NE', 'NN')),
#  (('theater', 'NN'), ('integration', 'NN')),
#  (('his', 'PP$'), ('uncle', 'NN')),
#  (('of', 'IN'), ('assault', 'NN')),
#  (('fire', 'NN'), ('ant', 'NN')),
#  (('the', 'AT'), ('patrol', 'NN')),
#  (('a', 'AT'), ('consultant', 'NN')),
#  (('magnetic', 'JJ'), ('tape', 'NN')),
#  (('the', 'AT'), ('entertainment', 'NN')),
#  (('The', 'AT'), ('award', 'NN')),
#  (('of', 'IN'), ('business', 'NN')),
#  (('grand', 'JJ'), ('champion', 'NN')),
#  (('for', 'IN'), ('use', 'NN')),
#  (('the', 'AT'), ('property', 'NN')),
#  (('the', 'AT'), ('juror', 'NN')),
#  (('a', 'AT'), ('farmer', 'NN')),
#  (('only', 'AP'), ('way', 'NN')),
#  (('the', 'AT'), ('war', 'NN')),
#  (('the', 'AT'), ('missile', 'NN')),
#  (('a', 'AT'), ('family', 'NN')),
#  (('labor', 'NN'), ('consultant', 'NN')),
#  (('Maintenance', 'NN-TL'), ('company', 'NN')),
#  (('an', 'AT'), ('agreement', 'NN')),
#  (('Dallas', 'NP'), ('investment', 'NN')),
#  (('Foods', 'NNS-TL'), ('stock', 'NN')),
#  (('a', 'AT'), ('combination', 'NN')),
#  (('of', 'IN'), ('cotton', 'NN')),
#  (('recent', 'JJ'), ('improvement', 'NN')),
#  (('the', 'AT'), ('beginning', 'NN')),
#  (('this', 'DT'), ('recovery', 'NN')),
#  (('and', 'CC'), ('technology', 'NN')),
#  (('the', 'AT'), ('bank', 'NN')),
#  (('the', 'AT'), ('B', 'NN')),
#  (('&', 'CC'), ('O', 'NN')),
#  ((',', ','), ('farm', 'NN')),
#  (('.', '.'), ('Net', 'NN')),
#  (('the', 'AT'), ('sale', 'NN')),
#  (('the', 'AT'), ('wife', 'NN')),
#  (('third', 'OD'), ('time', 'NN')),
#  (('the', 'AT'), ('violin', 'NN')),
#  (('the', 'AT'), ('puppet', 'NN')),
#  (('the', 'AT'), ('library', 'NN')),
#  (('a', 'AT'), ('library', 'NN')),
#  (('an', 'AT'), ('individual', 'NN')),
#  (('The', 'AT'), ('need', 'NN')),
#  (('foreign', 'JJ'), ('bomb', 'NN')),
#  (('gas', 'NN'), ('station', 'NN')),
#  (('station', 'NN'), ('man', 'NN')),
#  (('The', 'AT'), ('man', 'NN')),
#  (('The', 'AT'), ('AID', 'NN')),
#  (('the', 'AT'), ('music', 'NN')),
#  (("President's", 'NN$-TL'), ('staff', 'NN')),
#  (('the', 'AT'), ('gallery', 'NN')),
#  (('of', 'IN'), ('interest', 'NN')),
#  (('the', 'AT'), ('summit', 'NN')),
#  (('summit', 'NN'), ('meeting', 'NN')),
#  (('``', '``'), ('spirit', 'NN')),
#  (('The', 'AT'), ('question', 'NN')),
#  (('a', 'AT'), ('time', 'NN')),
#  (('school', 'NN'), ('system', 'NN')),
#  (('private', 'JJ'), ('enterprise', 'NN')),
#  (('``', '``'), ('family', 'NN')),
#  (('family', 'NN'), ('business', 'NN')),
#  (('the', 'AT'), ('college', 'NN')),
#  (('of', 'IN'), ('faculty', 'NN')),
#  (('the', 'AT'), ('creation', 'NN')),
#  (('a', 'AT'), ('commodity', 'NN')),
#  (('anti-trust', 'JJ'), ('legislation', 'NN')),
#  (('the', 'AT'), ('prospect', 'NN')),
#  (('under', 'IN'), ('par', 'NN')),
#  (('60', 'CD'), ('home', 'NN')),
#  (("Ruth's", 'NP$'), ('record', 'NN')),
#  (('every', 'AT'), ('day', 'NN')),
#  (('Belgian', 'JJ'), ('government', 'NN')),
#  (('its', 'PP$'), ('independence', 'NN')),
#  (('after', 'IN'), ('independence', 'NN')),
#  (('that', 'DT'), ('road', 'NN')),
#  (('its', 'PP$'), ('interest', 'NN')),
#  (('Welsh', 'JJ'), ('coal', 'NN')),
#  (('The', 'AT'), ('system', 'NN')),
#  (('in', 'IN'), ('member', 'NN')),
#  (('library', 'NN'), ('service', 'NN')),
#  (('primary', 'NN'), ('election', 'NN')),
#  (('no', 'AT'), ('evidence', 'NN')),
#  (('the', 'AT'), ('manner', 'NN')),
#  (('of', 'IN'), ('administration', 'NN')),
#  (('of', 'IN'), ('city', 'NN')),
#  (('general', 'JJ'), ('assistance', 'NN')),
#  (('the', 'AT'), ('exception', 'NN')),
#  (('this', 'DT'), ('program', 'NN')),
#  (('under', 'IN'), ('fire', 'NN')),
#  (('citizens', 'NNS'), ('committee', 'NN')),
#  (('the', 'AT'), ('airport', 'NN')),
#  (('the', 'AT'), ('purpose', 'NN')),
#  (('enabling', 'VBG'), ('legislation', 'NN')),
#  (('and', 'CC'), ('operation', 'NN')),
#  (('The', 'AT'), ('couple', 'NN')),
#  (('The', 'AT'), ('petition', 'NN')),
#  (('political', 'JJ'), ('career', 'NN')),
#  (('the', 'AT'), ('crowd', 'NN')),
#  (('unit', 'NN'), ('system', 'NN')),
#  (('relations', 'NNS'), ('director', 'NN')),
#  (('an', 'AT'), ('assistant', 'NN')),
#  (('a', 'AT'), ('campaign', 'NN')),
#  (('highway', 'NN'), ('bond', 'NN')),
#  (('a', 'AT'), ('study', 'NN')),
#  (('Department', 'NN-TL'), ('source', 'NN')),
#  (('every', 'AT'), ('time', 'NN')),
#  (('by', 'IN'), ('tax', 'NN')),
#  (('the', 'AT'), ('issuance', 'NN')),
#  (('the', 'AT'), ('privilege', 'NN')),
#  (('privilege', 'NN'), ('resolution', 'NN')),
#  (('public', 'JJ'), ('education', 'NN')),
#  (('as', 'CS'), ('state', 'NN')),
#  (('The', 'AT'), ('resolution', 'NN')),
#  (('new', 'JJ'), ('school', 'NN')),
#  (('a', 'AT'), ('pistol', 'NN')),
#  (('a', 'AT'), ('drop', 'NN')),
#  (('of', 'IN'), ('violence', 'NN')),
#  (('to', 'IN'), ('death', 'NN')),
#  (('public', 'JJ'), ('hearing', 'NN')),
#  (('one', 'CD'), ('week', 'NN')),
#  (('fiscal', 'JJ'), ('year', 'NN')),
#  (('escheat', 'NN'), ('law', 'NN')),
#  ((',', ','), ('insurance', 'NN')),
#  (('such', 'JJ'), ('property', 'NN')),
#  (('state', 'NN'), ('treasurer', 'NN')),
#  (('the', 'AT'), ('confidence', 'NN')),
#  ((',', ','), ('sponsor', 'NN')),
#  (('the', 'AT'), ('hearing', 'NN')),
#  (('authorizing', 'VBG'), ('establishment', 'NN')),
#  (('of', 'IN'), ('age', 'NN')),
#  (('on', 'IN'), ('horse', 'NN')),
#  (('horse', 'NN'), ('race', 'NN')),
#  (('The', 'AT'), ('house', 'NN')),
#  (('4', 'CD'), ('ballot', 'NN')),
#  (('the', 'AT'), ('proposal', 'NN')),
#  (('new', 'JJ'), ('president', 'NN')),
#  (('Science', 'NN-TL'), ('degree', 'NN')),
#  (('a', 'AT'), ('football', 'NN')),
#  (('as', 'CS'), ('teacher', 'NN')),
#  (('racial', 'JJ'), ('discrimination', 'NN')),
#  (('the', 'AT'), ('aid', 'NN')),
#  (('the', 'AT'), ('ADC', 'NN')),
#  (('ADC', 'NN'), ('program', 'NN')),
#  (('Cook', 'NP'), ('county', 'NN')),
#  (('of', 'IN'), ('family', 'NN')),
#  (('of', 'IN'), ('ADC', 'NN')),
#  (('committee', 'NN'), ('chairman', 'NN')),
#  (('a', 'AT'), ('quarrel', 'NN')),
#  (('his', 'PP$'), ('client', 'NN')),
#  (('separate', 'JJ'), ('trial', 'NN')),
#  (('fair', 'JJ'), ('trial', 'NN')),
#  (('this', 'DT'), ('case', 'NN')),
#  (('and', 'CC'), ('attention', 'NN')),
#  (('Berlin', 'NP'), ('crisis', 'NN')),
#  (('the', 'AT'), ('week-end', 'NN')),
#  (('summer', 'NN'), ('home', 'NN')),
#  (('his', 'PP$'), ('staff', 'NN')),
#  (('for', 'IN'), ('election', 'NN')),
#  (('58th', 'OD'), ('precinct', 'NN')),
#  (('jury', 'NN'), ('room', 'NN')),
#  (('the', 'AT'), ('authority', 'NN')),
#  (('under', 'IN'), ('advisement', 'NN')),
#  (('medical', 'JJ'), ('care', 'NN')),
#  (('health', 'NN'), ('care', 'NN')),
#  (('medical', 'JJ'), ('research', 'NN')),
#  (('security', 'NN'), ('payroll', 'NN')),
#  (('the', 'AT'), ('railroad', 'NN')),
#  (('that', 'DT'), ('date', 'NN')),
#  (('Full', 'JJ'), ('payment', 'NN')),
#  (('the', 'AT'), ('patient', 'NN')),
#  (('in', 'IN'), ('excess', 'NN')),
#  (('of', 'IN'), ('choice', 'NN')),
#  (('the', 'AT'), ('student', 'NN')),
#  (('in', 'IN'), ('scholarship', 'NN')),
#  (('the', 'AT'), ('child', 'NN')),
#  (('in', 'IN'), ('medicine', 'NN')),
#  (('security', 'NN'), ('system', 'NN')),
#  (('24', 'CD'), ('hour', 'NN')),
#  (('in', 'IN'), ('trouble', 'NN')),
#  (('the', 'AT'), ('track', 'NN')),
#  (('of', 'IN'), ('mind', 'NN')),
#  (('the', 'AT'), ('core', 'NN')),
#  (('of', 'IN'), ('NATO', 'NN')),
#  (('a', 'AT'), ('warning', 'NN')),
#  (('take', 'VB'), ('place', 'NN')),
#  (('without', 'IN'), ('regard', 'NN')),
#  (('the', 'AT'), ('use', 'NN')),
#  (('The', 'AT'), ('inclination', 'NN')),
#  (('the', 'AT'), ('cease-fire', 'NN')),
#  (('the', 'AT'), ('outcome', 'NN')),
#  (('a', 'AT'), ('resumption', 'NN')),
#  (('his', 'PP$'), ('part', 'NN')),
#  (('his', 'PP$'), ('administration', 'NN')),
#  (('Eisenhower', 'NP'), ('administration', 'NN')),
#  (('test', 'NN'), ('ban', 'NN')),
#  (('the', 'AT'), ('removal', 'NN')),
#  (('this', 'DT'), ('field', 'NN')),
#  (('the', 'AT'), ('support', 'NN')),
#  (('the', 'AT'), ('enactment', 'NN')),
#  (('executive', 'NN'), ('director', 'NN')),
#  (('this', 'DT'), ('matter', 'NN')),
#  (('present', 'JJ'), ('city', 'NN')),
#  (('a', 'AT'), ('CD', 'NN')),
#  (('matching', 'VBG'), ('fund', 'NN')),
#  (('fund', 'NN'), ('basis', 'NN')),
#  (('full-time', 'JJ'), ('CD', 'NN')),
#  (('assembly', 'NN'), ('point', 'NN')),
#  (('a', 'AT'), ('committee', 'NN')),
#  (('in', 'IN'), ('time', 'NN')),
#  (('next', 'AP'), ('session', 'NN')),
#  (('the', 'AT'), ('legislature', 'NN')),
#  (('general', 'JJ'), ('public', 'NN')),
#  ((',', ','), ('labor', 'NN')),
#  (('law', 'NN'), ('enforcement', 'NN')),
#  (('and', 'CC'), ('variety', 'NN')),
#  (('do', 'DO'), ('business', 'NN')),
#  (('a', 'AT'), ('chance', 'NN')),
#  (('the', 'AT'), ('local', 'NN')),
#  (('free', 'JJ'), ('enterprise', 'NN')),
#  (('a', 'AT'), ('machinist', 'NN')),
#  (('studied', 'VBD'), ('law', 'NN')),
#  (('national', 'JJ'), ('product', 'NN')),
#  (('a', 'AT'), ('profit', 'NN')),
#  (('a', 'AT'), ('person', 'NN')),
#  (('right', 'JJ'), ('hand', 'NN')),
#  (('the', 'AT'), ('suggestion', 'NN')),
#  (('the', 'AT'), ('chairman', 'NN')),
#  (('Democratic', 'JJ-TL'), ('leadership', 'NN')),
#  (('a', 'AT'), ('factor', 'NN')),
#  (('no', 'AT'), ('tax', 'NN')),
#  (('the', 'AT'), ('carcass', 'NN')),
#  (('this', 'DT'), ('campaign', 'NN')),
#  (('on', 'IN'), ('state', 'NN')),
#  (('the', 'AT'), ('campaign', 'NN')),
#  (('Meyner', 'NP'), ('administration', 'NN')),
#  (('this', 'DT'), ('state', 'NN')),
#  (('or', 'CC'), ('state', 'NN')),
#  (('this', 'DT'), ('time', 'NN')),
#  (('tax', 'NN'), ('issue', 'NN')),
#  (('a', 'AT'), ('statement', 'NN')),
#  (('to', 'IN'), ('victory', 'NN')),
#  (('public', 'JJ'), ('life', 'NN')),
#  (('his', 'PP$'), ('name', 'NN')),
#  (('of', 'IN'), ('world', 'NN')),
#  (('desperate', 'JJ'), ('effort', 'NN')),
#  (('the', 'AT'), ('effort', 'NN')),
#  (('state', 'NN'), ('chairman', 'NN')),
#  (('an', 'AT'), ('end', 'NN')),
#  (('the', 'AT'), ('purchase', 'NN')),
#  (('without', 'IN'), ('interest', 'NN')),
#  (('exclusive', 'JJ'), ('use', 'NN')),
#  (('safety', 'NN'), ('commissioner', 'NN')),
#  (('the', 'AT'), ('office', 'NN')),
#  (('fire', 'NN'), ('warden', 'NN')),
#  (('of', 'IN'), ('service', 'NN')),
#  (('his', 'PP$'), ('supervision', 'NN')),
#  (('the', 'AT'), ('department', 'NN')),
#  (('a', 'AT'), ('degree', 'NN')),
#  (('November', 'NP'), ('election', 'NN')),
#  (('other', 'AP'), ('side', 'NN')),
#  (('of', 'IN'), ('industry', 'NN')),
#  (('in', 'IN'), ('business', 'NN')),
#  (('and', 'CC'), ('industry', 'NN')),
#  (('the', 'AT'), ('good', 'NN')),
#  (('open', 'JJ'), ('land', 'NN')),
#  (('state', 'NN'), ('committee', 'NN')),
#  (('Democratic', 'JJ-TL'), ('district', 'NN')),
#  (('the', 'AT'), ('weakness', 'NN')),
#  (('the', 'AT'), ('candidate', 'NN')),
#  (('the', 'AT'), ('air', 'NN')),
#  (('secret', 'JJ'), ('conspiracy', 'NN')),
#  (('the', 'AT'), ('construction', 'NN')),
#  (('education', 'NN'), ('bill', 'NN')),
#  (('for', 'IN'), ('construction', 'NN')),
#  (('and', 'CC'), ('mathematics', 'NN')),
#  (('an', 'AT'), ('official', 'NN')),
#  (('the', 'AT'), ('corps', 'NN')),
#  (('and', 'CC'), ('community', 'NN')),
#  (('hotel', 'NN'), ('owner', 'NN')),
#  (('military', 'JJ'), ('assistance', 'NN')),
#  (('detailed', 'VBN'), ('report', 'NN')),
#  (('Each', 'DT'), ('member', 'NN')),
#  (('An', 'AT'), ('agreement', 'NN')),
#  (('promotion', 'NN'), ('manager', 'NN')),
#  (('the', 'AT'), ('avenue', 'NN')),
#  (('a', 'AT'), ('block', 'NN')),
#  (('of', 'IN'), ('justice', 'NN')),
#  (('the', 'AT'), ('parade', 'NN')),
#  (('the', 'AT'), ('order', 'NN')),
#  ((';', '.'), ('division', 'NN')),
#  (('the', 'AT'), ('helm', 'NN')),
#  (('legislative', 'JJ'), ('session', 'NN')),
#  (('a', 'AT'), ('session', 'NN')),
#  (('congressional', 'JJ'), ('district', 'NN')),
#  (('no', 'AT'), ('effort', 'NN')),
#  (('the', 'AT'), ('picture', 'NN')),
#  (('Davis', 'NP'), ('administration', 'NN')),
#  (('of', 'IN'), ('peace', 'NN')),
#  (('in', 'IN'), ('state', 'NN')),
#  (('in', 'IN'), ('progress', 'NN')),
#  (('tax', 'NN'), ('proposal', 'NN')),
#  (('of', 'IN'), ('cash', 'NN')),
#  (('major', 'JJ'), ('factor', 'NN')),
#  (('a', 'AT'), ('grant-in-aid', 'NN')),
#  (('grant-in-aid', 'NN'), ('program', 'NN')),
#  (('a', 'AT'), ('part', 'NN')),
#  (('a', 'AT'), ('transition', 'NN')),
#  (('of', 'IN'), ('thing', 'NN')),
#  (('tax', 'NN'), ('measure', 'NN')),
#  (('fiscal', 'JJ'), ('session', 'NN')),
#  (('the', 'AT'), ('advantage', 'NN')),
#  (('a', 'AT'), ('bid', 'NN')),
#  (('the', 'AT'), ('contract', 'NN')),
#  (('the', 'AT'), ('performance', 'NN')),
#  (('the', 'AT'), ('PTC', 'NN')),
#  (('for', 'IN'), ('reorganization', 'NN')),
#  (('.', '.'), ('Business', 'NN')),
#  (('The', 'AT'), ('suit', 'NN')),
#  (('the', 'AT'), ('position', 'NN')),
#  (('per', 'IN'), ('joint', 'NN')),
#  (('The', 'AT'), ('ordinance', 'NN')),
#  (('a', 'AT'), ('room', 'NN')),
#  ((',', ','), ('hotel', 'NN')),
#  (('apartment', 'NN'), ('house', 'NN')),
#  (('The', 'AT'), ('increase', 'NN')),
#  (('a', 'AT'), ('dog', 'NN')),
#  (('animal', 'NN'), ('care', 'NN')),
#  (('under', 'IN'), ('study', 'NN')),
#  (('The', 'AT'), ('commission', 'NN')),
#  (('The', 'AT'), ('corporation', 'NN')),
#  (('The', 'AT'), ('esplanade', 'NN')),
#  (('The', 'AT'), ('president', 'NN')),
#  (('his', 'PP$'), ('car', 'NN')),
#  (('the', 'AT'), ('driveway', 'NN')),
#  (('left', 'JJ'), ('front', 'NN')),
#  (('front', 'NN'), ('wheel', 'NN')),
#  (('the', 'AT'), ('person', 'NN')),
#  (('executive', 'NN'), ('committee', 'NN')),
#  (('the', 'AT'), ('threat', 'NN')),
#  (('military', 'JJ'), ('junta', 'NN')),
#  (('a', 'AT'), ('government', 'NN')),
#  (('assistant', 'NN'), ('secretary', 'NN')),
#  (('of', 'IN'), ('society', 'NN')),
#  (('the', 'AT'), ('opportunity', 'NN')),
#  (('the', 'AT'), ('assistant', 'NN')),
#  (('national', 'JJ'), ('level', 'NN')),
#  (('a', 'AT'), ('stand', 'NN')),
#  (('same', 'AP'), ('date', 'NN')),
#  (('The', 'AT'), ('dinner', 'NN')),
#  (('executive', 'NN'), ('secretary', 'NN')),
#  (('the', 'AT'), ('water', 'NN')),
#  (('two-year', 'JJ'), ('term', 'NN')),
#  (('general', 'JJ'), ('superintendent', 'NN')),
#  (('the', 'AT'), ('list', 'NN')),
#  (('the', 'AT'), ('denomination', 'NN')),
#  (('.', '.'), ('Election', 'NN')),
#  (('the', 'AT'), ('theme', 'NN')),
#  (('religious', 'JJ'), ('life', 'NN')),
#  (('population', 'NN'), ('growth', 'NN')),
#  (('their', 'PP$'), ('support', 'NN')),
#  (('directed', 'VBN'), ('verdict', 'NN')),
#  (('no', 'AT'), ('proof', 'NN')),
#  (('a', 'AT'), ('score', 'NN')),
#  (('the', 'AT'), ('middle', 'NN')),
#  (('a', 'AT'), ('drive', 'NN')),
#  (('the', 'AT'), ('dirt', 'NN')),
#  (('winning', 'VBG'), ('run', 'NN')),
#  (('wild', 'JJ'), ('pitch', 'NN')),
#  (('the', 'AT'), ('mound', 'NN')),
#  (('the', 'AT'), ('fence', 'NN')),
#  (('a', 'AT'), ('bunt', 'NN')),
#  (('a', 'AT'), ('run', 'NN')),
#  (('left', 'JJ'), ('center', 'NN')),
#  (('a', 'AT'), ('hit', 'NN')),
#  (('the', 'AT'), ('expense', 'NN')),
#  (('a', 'AT'), ('night', 'NN')),
#  (('spring', 'NN'), ('training', 'NN')),
#  (('this', 'DT'), ('afternoon', 'NN')),
#  (('a', 'AT'), ('surprise', 'NN')),
#  (('in', 'IN'), ('company', 'NN')),
#  (('the', 'AT'), ('wing', 'NN')),
#  (('straight', 'JJ'), ('victory', 'NN')),
#  (('the', 'AT'), ('wire', 'NN')),
#  (('world', 'NN'), ('record', 'NN')),
#  (('The', 'AT'), ('crowd', 'NN')),
#  (('the', 'AT'), ('clock', 'NN')),
#  (('This', 'DT'), ('year', 'NN')),
#  (('in', 'IN'), ('spring', 'NN')),
#  (('one', 'CD'), ('pass', 'NN')),
#  (('your', 'PP$'), ('timing', 'NN')),
#  (('their', 'PP$'), ('total', 'NN')),
#  (('passing', 'VBG'), ('yardage', 'NN')),
#  (('State', 'NN-TL'), ('game', 'NN')),
#  (('good', 'JJ'), ('feeling', 'NN')),
#  (('the', 'AT'), ('football', 'NN')),
#  (('of', 'IN'), ('action', 'NN')),
#  (('his', 'PP$'), ('knee', 'NN')),
#  (('The', 'AT'), ('game', 'NN')),
#  (('defensive', 'JJ'), ('unit', 'NN')),
#  (('a', 'AT'), ('couple', 'NN')),
#  (('total', 'NN'), ('offense', 'NN')),
#  (('per', 'IN'), ('game', 'NN')),
#  (('a', 'AT'), ('line', 'NN')),
#  (('a', 'AT'), ('double', 'NN')),
#  (('the', 'AT'), ('rightfield', 'NN')),
#  (('third', 'OD'), ('base', 'NN')),
#  (('to', 'IN'), ('center', 'NN')),
#  (('the', 'AT'), ('loss', 'NN')),
#  (('major', 'JJ'), ('league', 'NN')),
#  (('batting', 'VBG'), ('average', 'NN')),
#  ((',', ','), ('baseball', 'NN')),
#  (('big', 'JJ'), ('leaguer', 'NN')),
#  (('new', 'JJ'), ('record', 'NN')),
#  (('the', 'AT'), ('period', 'NN')),
#  (('a', 'AT'), ('baseball', 'NN')),
#  (('any', 'DTI'), ('area', 'NN')),
#  (('world', 'NN'), ('series', 'NN')),
#  (('a', 'AT'), ('parade', 'NN')),
#  (('series', 'NN'), ('game', 'NN')),
#  (('2-run', 'JJ'), ('homer', 'NN')),
#  (('a', 'AT'), ('salary', 'NN')),
#  (('news', 'NN'), ('conference', 'NN')),
#  (("Shaw's", 'NP$'), ('staff', 'NN')),
#  (('a', 'AT'), ('player', 'NN')),
#  (('a', 'AT'), ('ceremony', 'NN')),
#  (('to', 'IN'), ('baseball', 'NN')),
#  (('the', 'AT'), ('formation', 'NN')),
#  (('local', 'JJ'), ('club', 'NN')),
#  (('general', 'JJ'), ('manager', 'NN')),
#  (('in', 'IN'), ('line', 'NN')),
#  (('in', 'IN'), ('golf', 'NN')),
#  (('a', 'AT'), ('shot', 'NN')),
#  (('The', 'AT'), ('ball', 'NN')),
#  (('right', 'JJ'), ('side', 'NN')),
#  (('the', 'AT'), ('fairway', 'NN')),
#  (('of', 'IN'), ('humor', 'NN')),
#  (('the', 'AT'), ('strain', 'NN')),
#  (('provisional', 'JJ'), ('ball', 'NN')),
#  (('a', 'AT'), ('ruling', 'NN')),
#  (('1961', 'CD'), ('schedule', 'NN')),
#  (('of', 'IN'), ('baseball', 'NN')),
#  (('in', 'IN'), ('baseball', 'NN')),
#  (('The', 'AT'), ('desire', 'NN')),
#  (('open', 'JJ'), ('date', 'NN')),
#  (('in', 'IN'), ('center', 'NN')),
#  (('batting', 'VBG'), ('practice', 'NN')),
#  (('a', 'AT'), ('change', 'NN')),
#  (('a', 'AT'), ('race', 'NN')),
#  (('the', 'AT'), ('pennant', 'NN')),
#  (('the', 'AT'), ('coach', 'NN')),
#  (('sports', 'NNS'), ('editor', 'NN')),
#  (('the', 'AT'), ('injury', 'NN')),
#  (('a', 'AT'), ('precedent', 'NN')),
#  (('a', 'AT'), ('tie', 'NN')),
#  (('at', 'IN'), ('bat', 'NN')),
#  (('in', 'IN'), ('action', 'NN')),
#  (('any', 'DTI'), ('period', 'NN')),
#  (('that', 'DT'), ('matter', 'NN')),
#  (('the', 'AT'), ('veteran', 'NN')),
#  ...]

# %%
wsj = nltk.corpus.treebank.tagged_words()
word_tags_fd = nltk.FreqDist(wsj)
set([word+"/"+tag for (word,tag) in word_tags_fd if tag.startswith('V')])
# Out:
# {'signed/VBN',
#  'Declining/VBG',
#  'learned/VBD',
#  'builds/VBZ',
#  'depending/VBG',
#  'withhold/VB',
#  'says/VBZ',
#  'reallocate/VB',
#  'borrowing/VBG',
#  'eased/VBD',
#  'defeats/VBZ',
#  'require/VB',
#  'reduce/VB',
#  'clipped/VBD',
#  'stare/VBP',
#  'subsidize/VB',
#  'fattened/VBN',
#  'jeopardizing/VBG',
#  'total/VB',
#  'attributed/VBN',
#  'contract/VB',
#  'introducing/VBG',
#  'adopted/VBN',
#  'dropped/VBN',
#  'sketching/VBG',
#  'contained/VBD',
#  'propagandizes/VBZ',
#  'grows/VBZ',
#  'admits/VBZ',
#  'chose/VBD',
#  'maintaining/VBG',
#  'discouraging/VBG',
#  'cry/VBP',
#  'bar/VB',
#  'painted/VBN',
#  'proved/VBD',
#  'executed/VBN',
#  'fighting/VBG',
#  'conducted/VBN',
#  'parallel/VB',
#  'assure/VB',
#  'reported/VBD',
#  'denounce/VB',
#  'go/VB',
#  'feel/VBP',
#  'shipped/VBN',
#  'attract/VB',
#  'think/VBP',
#  'avoid/VBP',
#  'Used/VBN',
#  'worry/VB',
#  'fetching/VBG',
#  'scrounge/VBP',
#  'photocopying/VBG',
#  'competed/VBN',
#  'admitting/VBG',
#  'own/VBP',
#  'narrowed/VBD',
#  'print/VBP',
#  'obligated/VBD',
#  'win/VB',
#  'trained/VBN',
#  'cushioned/VBN',
#  'having/VBG',
#  'place/VB',
#  'lacks/VBZ',
#  'published/VBD',
#  'signed/VBD',
#  'Eliminate/VB',
#  'pushes/VBZ',
#  'soaring/VBG',
#  'exhibited/VBN',
#  'stemming/VBG',
#  'extend/VBP',
#  'fainting/VBG',
#  'deliberating/VBG',
#  'feeds/VBZ',
#  'find/VBP',
#  'taught/VBD',
#  'purchase/VB',
#  'sustained/VBN',
#  'owning/VBG',
#  'Reached/VBN',
#  'avoid/VB',
#  'complete/VB',
#  'file/VB',
#  'including/VBG',
#  'killing/VBG',
#  'AGREES/VBZ',
#  'run/VB',
#  'facing/VBG',
#  'direct/VB',
#  'ease/VBP',
#  'bothered/VBD',
#  'muted/VBN',
#  'ended/VBD',
#  'tested/VBN',
#  'intend/VBP',
#  'concerned/VBN',
#  'warrants/VBZ',
#  'killed/VBD',
#  'improve/VBP',
#  'surged/VBN',
#  'announced/VBN',
#  'rationed/VBN',
#  'upsetting/VBG',
#  'decrease/VB',
#  'referred/VBN',
#  'advanced/VBN',
#  'expanding/VBG',
#  'unleashed/VBD',
#  'happens/VBZ',
#  'record/VB',
#  'evoke/VBP',
#  'grown/VBN',
#  'respond/VB',
#  'broke/VBD',
#  'lasted/VBD',
#  'routes/VBZ',
#  'bring/VB',
#  'wait/VB',
#  'noted/VBD',
#  'promote/VB',
#  'rating/VBG',
#  'please/VB',
#  'snapped/VBD',
#  'eating/VBG',
#  'casting/VBG',
#  'quipped/VBD',
#  'tracking/VBG',
#  'slowing/VBG',
#  'postponed/VBN',
#  'contends/VBZ',
#  'involves/VBZ',
#  'Legislating/VBG',
#  'Put/VB',
#  'relieve/VB',
#  'counts/VBZ',
#  'override/VB',
#  'glamorize/VB',
#  "'m/VBP",
#  'talks/VBZ',
#  'gives/VBZ',
#  'draw/VB',
#  'retain/VB',
#  'drooled/VBD',
#  'fare/VBP',
#  'reached/VBN',
#  'differ/VBP',
#  'specialized/VBN',
#  'welcomed/VBD',
#  'doubted/VBD',
#  'exhaust/VBP',
#  'advertise/VB',
#  'pealing/VBG',
#  'gained/VBN',
#  'TRIMMING/VBG',
#  'account/VBP',
#  'refused/VBN',
#  'go/VBP',
#  'preventing/VBG',
#  'load/VB',
#  'stemmed/VBD',
#  'invested/VBN',
#  'fault/VBP',
#  'restructuring/VBG',
#  'founded/VBN',
#  'spoke/VBD',
#  'explained/VBD',
#  'doubled/VBD',
#  'view/VB',
#  'Filmed/VBN',
#  'spent/VBN',
#  'shoring/VBG',
#  'exceeding/VBG',
#  'use/VBP',
#  'hampered/VBD',
#  'told/VBD',
#  'brokering/VBG',
#  'indicating/VBG',
#  'mollified/VBN',
#  'blurred/VBD',
#  'distinguished/VBD',
#  'sue/VB',
#  'invades/VBZ',
#  'drew/VBD',
#  'spent/VBD',
#  'restore/VB',
#  'demand/VB',
#  'comment/VB',
#  'organized/VBN',
#  'afflicted/VBN',
#  'engineered/VBN',
#  'decided/VBD',
#  'works/VBZ',
#  'leaving/VBG',
#  'collecting/VBG',
#  'reported/VBN',
#  'began/VBD',
#  'striving/VBG',
#  'permits/VBZ',
#  'banned/VBN',
#  'paid/VBN',
#  'expelled/VBD',
#  'rescheduled/VBN',
#  'surged/VBD',
#  'argues/VBZ',
#  'adopt/VB',
#  'diversified/VBN',
#  'agrees/VBZ',
#  'recognize/VBP',
#  'obtaining/VBG',
#  'seduce/VB',
#  'tote/VB',
#  'Standing/VBG',
#  'place/VBP',
#  'offers/VBZ',
#  'places/VBZ',
#  'signals/VBZ',
#  'crossing/VBG',
#  'intimidate/VB',
#  'polled/VBD',
#  'quashing/VBG',
#  'punish/VB',
#  'Remember/VB',
#  'wear/VB',
#  'participated/VBD',
#  'jet/VBP',
#  'hampered/VBN',
#  'reminded/VBD',
#  'emasculate/VB',
#  'sweeping/VBG',
#  'decried/VBD',
#  'moves/VBZ',
#  'stand/VBP',
#  'benefited/VBD',
#  'lending/VBG',
#  'assassinated/VBD',
#  'producing/VBG',
#  'tempted/VBD',
#  'appear/VB',
#  'sit/VB',
#  'provide/VBP',
#  'institute/VB',
#  'chilled/VBN',
#  'Depending/VBG',
#  'increased/VBD',
#  'blocks/VBZ',
#  'employs/VBZ',
#  'stepped/VBN',
#  'change/VBP',
#  'combat/VB',
#  'costs/VBZ',
#  'wins/VBZ',
#  'casts/VBZ',
#  'earning/VBG',
#  'put/VB',
#  'justify/VB',
#  'financing/VBG',
#  'design/VB',
#  'acknowledges/VBZ',
#  'loom/VBP',
#  'shaping/VBG',
#  'conducting/VBG',
#  'executes/VBZ',
#  'allocated/VBN',
#  'junk/VB',
#  'featured/VBD',
#  'delay/VB',
#  'split/VBN',
#  'leave/VB',
#  'forcing/VBG',
#  'waive/VB',
#  'blamed/VBN',
#  'endorsed/VBD',
#  'lost/VBD',
#  'contribute/VB',
#  'ripen/VBP',
#  'thinks/VBZ',
#  'watched/VBN',
#  'contributed/VBD',
#  'hope/VB',
#  'rumored/VBN',
#  'aired/VBD',
#  'burned/VBN',
#  'disposed/VBD',
#  'rolling/VBG',
#  'Assuming/VBG',
#  'scaring/VBG',
#  'traced/VBD',
#  'applied/VBN',
#  'become/VB',
#  'frozen/VBN',
#  'fuel/VB',
#  'put/VBD',
#  'pour/VB',
#  'slow/VB',
#  'advancing/VBG',
#  'omitted/VBD',
#  'milked/VBN',
#  'pressed/VBN',
#  'capitalize/VB',
#  'warned/VBN',
#  'studying/VBG',
#  'drafted/VBN',
#  'saying/VBG',
#  'missed/VBN',
#  'generated/VBN',
#  'realized/VBD',
#  'became/VBD',
#  'closing/VBG',
#  'tuck/VB',
#  'SWITCHING/VBG',
#  'pulling/VBG',
#  'worked/VBD',
#  'take/VBP',
#  'expect/VB',
#  'comes/VBZ',
#  'renew/VB',
#  'focused/VBN',
#  'stem/VB',
#  'expanded/VBN',
#  'restructures/VBZ',
#  'dominated/VBN',
#  'averaged/VBD',
#  'crippled/VBN',
#  'earned/VBD',
#  'vested/VBN',
#  'discontinue/VB',
#  'frustrating/VBG',
#  'Compare/VB',
#  'become/VBN',
#  'obtained/VBD',
#  'shake/VB',
#  'involving/VBG',
#  'trailed/VBD',
#  'characterized/VBN',
#  'puzzled/VBN',
#  'raising/VBG',
#  'curled/VBD',
#  'use/VB',
#  'produce/VB',
#  'divided/VBN',
#  'changed/VBN',
#  'curbed/VBN',
#  'collapsed/VBN',
#  'Encouraging/VBG',
#  'controlled/VBD',
#  'Reducing/VBG',
#  'applied/VBD',
#  'copying/VBG',
#  'spur/VB',
#  'Continuing/VBG',
#  'involved/VBD',
#  'tumbled/VBD',
#  'replicate/VB',
#  'ended/VBN',
#  'spending/VBG',
#  'dreamt/VBD',
#  'approach/VBP',
#  'playing/VBG',
#  'promoting/VBG',
#  'limit/VB',
#  'boarding/VBG',
#  'administer/VB',
#  'rallying/VBG',
#  'transferring/VBG',
#  'mulling/VBG',
#  'denied/VBN',
#  'estimate/VB',
#  'think/VB',
#  'give/VBP',
#  'helped/VBN',
#  'test/VBP',
#  'compressed/VBN',
#  'blip/VBP',
#  'attempting/VBG',
#  'sorting/VBG',
#  'threatened/VBN',
#  'shoot/VB',
#  'telling/VBG',
#  'curtail/VB',
#  'blip/VB',
#  'quoted/VBD',
#  'enhances/VBZ',
#  'played/VBN',
#  'abating/VBG',
#  'altered/VBN',
#  'mature/VBP',
#  'reclaimed/VBN',
#  'halted/VBN',
#  'hold/VBP',
#  'avoiding/VBG',
#  'transcribe/VBP',
#  'referring/VBG',
#  'stirred/VBD',
#  'points/VBZ',
#  'command/VB',
#  'transfers/VBZ',
#  'aimed/VBN',
#  'turns/VBZ',
#  'try/VB',
#  'improves/VBZ',
#  'derived/VBN',
#  'prohibits/VBZ',
#  'conclude/VBP',
#  'insinuating/VBG',
#  'export/VB',
#  'championing/VBG',
#  'represent/VBP',
#  "C'mon/VB",
#  'comments/VBZ',
#  'intended/VBN',
#  'returned/VBN',
#  'firmed/VBD',
#  'brightened/VBD',
#  'pass/VB',
#  'bolstered/VBN',
#  'figure/VBP',
#  'retraced/VBD',
#  'run/VBN',
#  'factors/VBZ',
#  'transacting/VBG',
#  'Continued/VBN',
#  'spurred/VBN',
#  'capitalized/VBN',
#  'copy/VB',
#  'dismiss/VBP',
#  'single/VB',
#  'upset/VBN',
#  'muffled/VBN',
#  'PORTING/VBG',
#  'lead/VBP',
#  'heating/VBG',
#  'rebounding/VBG',
#  'covering/VBG',
#  'break/VB',
#  'removed/VBN',
#  'dumped/VBD',
#  'hired/VBN',
#  'preapproved/VBN',
#  'damaged/VBN',
#  'expressed/VBD',
#  'rarefied/VBN',
#  'am/VBP',
#  'live/VBP',
#  'valued/VBN',
#  'operate/VBP',
#  'offered/VBN',
#  'containing/VBG',
#  'arranged/VBD',
#  'disagree/VBP',
#  'prompts/VBZ',
#  'provide/VB',
#  'plan/VBP',
#  'blamed/VBD',
#  'appearing/VBG',
#  'restructure/VB',
#  'come/VB',
#  'filed/VBD',
#  'meets/VBZ',
#  'declined/VBD',
#  'reshaping/VBG',
#  'feared/VBN',
#  'reflect/VB',
#  'authorizing/VBG',
#  'hear/VB',
#  'share/VB',
#  'murdered/VBN',
#  'Founded/VBN',
#  'bludgeon/VB',
#  'kept/VBN',
#  'convert/VB',
#  'concede/VBP',
#  'polled/VBN',
#  'hauled/VBD',
#  'expect/VBP',
#  'has/VBZ',
#  'doing/VBG',
#  'respond/VBP',
#  'favors/VBZ',
#  'force/VBP',
#  'extending/VBG',
#  'worries/VBZ',
#  'shut/VB',
#  'posing/VBG',
#  'gored/VBN',
#  'limiting/VBG',
#  'reviewed/VBD',
#  'folded/VBD',
#  'uttering/VBG',
#  'eases/VBZ',
#  "'ve/VBP",
#  'double/VB',
#  'colored/VBN',
#  'referred/VBD',
#  'building/VBG',
#  'apologize/VB',
#  'fought/VBD',
#  'convince/VB',
#  'lure/VB',
#  'praised/VBD',
#  'nominate/VB',
#  'drinking/VBG',
#  'printed/VBN',
#  'possess/VBP',
#  'conduct/VBP',
#  'jump/VB',
#  'underperforming/VBG',
#  'appear/VBP',
#  'tripled/VBN',
#  'launch/VB',
#  'sleep/VB',
#  'finds/VBZ',
#  'nonrecurring/VBG',
#  'whipsaw/VB',
#  'encourage/VBP',
#  'barking/VBG',
#  'deliver/VB',
#  'free/VB',
#  'asking/VBG',
#  'mount/VB',
#  'expires/VBZ',
#  'agreed/VBD',
#  'weather/VB',
#  'selected/VBN',
#  'ushering/VBG',
#  'orchestrated/VBN',
#  'chase/VB',
#  'tip/VB',
#  'sued/VBD',
#  'tolerate/VB',
#  'pulled/VBD',
#  'begin/VB',
#  'dismissed/VBN',
#  'string/VB',
#  'underline/VB',
#  'functioning/VBG',
#  'accommodate/VB',
#  'advocated/VBD',
#  'trading/VBG',
#  'operating/VBG',
#  'scared/VBN',
#  'craft/VB',
#  'ordering/VBG',
#  'backed/VBN',
#  'winning/VBG',
#  'hurt/VBN',
#  'enabled/VBD',
#  'embroiled/VBN',
#  'throws/VBZ',
#  'annoyed/VBD',
#  'Earns/VBZ',
#  'help/VB',
#  'question/VB',
#  'built/VBN',
#  'treats/VBZ',
#  'filled/VBN',
#  'find/VB',
#  'finalized/VBN',
#  'Bucking/VBG',
#  'clear/VB',
#  'surfaced/VBN',
#  'voice/VBP',
#  'believe/VB',
#  'delivering/VBG',
#  'represented/VBD',
#  'entrench/VB',
#  'proposing/VBG',
#  'hit/VB',
#  'tracks/VBZ',
#  'pointing/VBG',
#  'Starting/VBG',
#  'yield/VB',
#  'inserted/VBN',
#  'requested/VBN',
#  'honor/VB',
#  'filed/VBN',
#  'taking/VBG',
#  'resume/VB',
#  'propose/VBP',
#  'ignoring/VBG',
#  'set/VBN',
#  'carry/VB',
#  'abolishing/VBG',
#  'succeeds/VBZ',
#  'sold/VBD',
#  'impart/VB',
#  'ranged/VBD',
#  'purrs/VBZ',
#  'stressed/VBN',
#  'accumulated/VBN',
#  'entrenched/VBN',
#  'quips/VBZ',
#  'refitting/VBG',
#  'examine/VBP',
#  'contacted/VBN',
#  'refile/VB',
#  'existing/VBG',
#  'teaches/VBZ',
#  'causes/VBZ',
#  'entitles/VBZ',
#  'strengthened/VBD',
#  'determined/VBD',
#  'cause/VB',
#  'directed/VBN',
#  'implies/VBZ',
#  'trail/VB',
#  'reward/VB',
#  'underscore/VBP',
#  'slip/VB',
#  'draw/VBP',
#  'studied/VBD',
#  'amend/VB',
#  'promise/VBP',
#  'turn/VB',
#  'Asked/VBN',
#  'hamstrung/VBP',
#  'manage/VBP',
#  'pointed/VBN',
#  'exceed/VBP',
#  'billed/VBD',
#  'slipped/VBD',
#  'raised/VBD',
#  'restructured/VBN',
#  'structured/VBN',
#  'recycled/VBN',
#  'restricting/VBG',
#  'produces/VBZ',
#  'color/VB',
#  'let/VBD',
#  'undo/VB',
#  'close/VB',
#  'last/VB',
#  'converting/VBG',
#  'advertised/VBN',
#  'seeing/VBG',
#  'ventilated/VBD',
#  'feeling/VBG',
#  'revised/VBN',
#  'clicked/VBD',
#  'searched/VBD',
#  'breaks/VBZ',
#  'deemed/VBD',
#  'lost/VBN',
#  'cut/VB',
#  'brought/VBD',
#  'circulated/VBD',
#  'waiting/VBG',
#  'ease/VB',
#  'surrendered/VBD',
#  'resign/VB',
#  'CHANGED/VBD',
#  'mentioned/VBN',
#  'curbing/VBG',
#  'downgraded/VBD',
#  'engaging/VBG',
#  'cites/VBZ',
#  'ranging/VBG',
#  'hunker/VB',
#  'neighboring/VBG',
#  'emigrate/VB',
#  'want/VBP',
#  'admitted/VBD',
#  'answer/VB',
#  'kill/VBP',
#  'muscling/VBG',
#  'raise/VB',
#  'soliciting/VBG',
#  'apply/VB',
#  'gauges/VBZ',
#  'resists/VBZ',
#  'clobbered/VBN',
#  'sends/VBZ',
#  'recovered/VBD',
#  'choose/VB',
#  'backed/VBD',
#  'sending/VBG',
#  'fired/VBD',
#  'mailed/VBN',
#  'house/VB',
#  'supplies/VBZ',
#  'entrusted/VBN',
#  'sells/VBZ',
#  'reflected/VBN',
#  'boosts/VBZ',
#  'slide/VB',
#  'removed/VBD',
#  'augment/VB',
#  'migrate/VB',
#  'shot/VBD',
#  'describe/VBP',
#  'delivered/VBN',
#  'knew/VBD',
#  'rectified/VBN',
#  'heading/VBG',
#  'unveiled/VBD',
#  'deny/VB',
#  'tempts/VBZ',
#  'evaluating/VBG',
#  'harmed/VBN',
#  'prefer/VBP',
#  'limping/VBG',
#  'sneaked/VBD',
#  'recommending/VBG',
#  'announced/VBD',
#  'despise/VB',
#  'reprint/VB',
#  'cut/VBN',
#  'assumed/VBD',
#  'suffer/VB',
#  'disseminating/VBG',
#  'walking/VBG',
#  'caused/VBN',
#  'confirmed/VBN',
#  'facilitate/VB',
#  'thumbing/VBG',
#  'act/VB',
#  'exuded/VBD',
#  'hire/VB',
#  'replicated/VBN',
#  'paying/VBG',
#  'stresses/VBZ',
#  'boost/VB',
#  'replicating/VBG',
#  'plan/VB',
#  'rings/VBZ',
#  'aims/VBZ',
#  'pointed/VBD',
#  'defying/VBG',
#  'clarified/VBN',
#  'educated/VBN',
#  'gotten/VBN',
#  'UPHELD/VBN',
#  'maturing/VBG',
#  'realestate/VB',
#  'depleted/VBN',
#  'deserve/VB',
#  'charges/VBZ',
#  'accused/VBN',
#  'study/VBP',
#  'existed/VBN',
#  'forced/VBD',
#  'lease/VB',
#  'classified/VBN',
#  'monopolize/VB',
#  'considered/VBN',
#  'riding/VBG',
#  'Funded/VBN',
#  'lent/VBD',
#  'coordinate/VB',
#  'Arbitraging/VBG',
#  'entering/VBG',
#  'mating/VBG',
#  'committed/VBN',
#  'falls/VBZ',
#  'limited/VBD',
#  'forecast/VBD',
#  'gather/VB',
#  'secede/VB',
#  'Observing/VBG',
#  'disputed/VBN',
#  'oppose/VB',
#  'pegged/VBN',
#  'wanting/VBG',
#  'caught/VBN',
#  'laid/VBN',
#  'expunged/VBN',
#  'swap/VB',
#  'tendered/VBN',
#  'spurring/VBG',
#  'push/VBP',
#  'complained/VBN',
#  'alarmed/VBN',
#  'speaking/VBG',
#  'remain/VB',
#  'clarify/VB',
#  'rung/VBN',
#  'befuddled/VBD',
#  'Named/VBN',
#  'detailed/VBN',
#  'responds/VBZ',
#  'ending/VBG',
#  'orders/VBZ',
#  'handle/VB',
#  'hire/VBP',
#  'determine/VB',
#  'asserts/VBZ',
#  'suspend/VB',
#  'enhanced/VBN',
#  'cranked/VBD',
#  'cater/VBP',
#  'divest/VB',
#  'allow/VBP',
#  'transformed/VBN',
#  'inhibit/VB',
#  'deter/VB',
#  'awaits/VBZ',
#  'cruising/VBG',
#  'accounting/VBG',
#  'cast/VBN',
#  'managed/VBD',
#  'kicked/VBD',
#  'surveyed/VBN',
#  'discussed/VBD',
#  'eyeing/VBG',
#  'pay/VBP',
#  'pursue/VBP',
#  'read/VBD',
#  'proposed/VBD',
#  'exceeds/VBZ',
#  'suing/VBG',
#  'disclosing/VBG',
#  'propagandize/VB',
#  'question/VBP',
#  'outnumbered/VBD',
#  'varied/VBD',
#  'floated/VBN',
#  'fretted/VBD',
#  'tender/VB',
#  'justifying/VBG',
#  'Performing/VBG',
#  'Kill/VB',
#  'expire/VBP',
#  'underlying/VBG',
#  'display/VB',
#  'moderated/VBN',
#  'used/VBD',
#  'obsessed/VBN',
#  'bolster/VB',
#  'had/VBN',
#  'receives/VBZ',
#  'Takes/VBZ',
#  'gauge/VB',
#  'lying/VBG',
#  'believed/VBN',
#  'projects/VBZ',
#  'dismissed/VBD',
#  'calculated/VBN',
#  'produced/VBN',
#  'borrowed/VBN',
#  'exposed/VBN',
#  'testify/VB',
#  'viewed/VBD',
#  'notify/VB',
#  'duck/VB',
#  'distributed/VBN',
#  'replacing/VBG',
#  'searching/VBG',
#  'devise/VB',
#  'expects/VBZ',
#  'read/VB',
#  'dividing/VBG',
#  'oppose/VBP',
#  'plunged/VBN',
#  'granted/VBN',
#  'attached/VBD',
#  'acquired/VBD',
#  'discredit/VB',
#  'conclude/VB',
#  'nurtured/VBN',
#  'elaborate/VB',
#  'sense/VBP',
#  'inching/VBG',
#  'contains/VBZ',
#  'licensed/VBN',
#  'attempted/VBN',
#  'outranks/VBZ',
#  'waiving/VBG',
#  'specify/VB',
#  'total/VBP',
#  'looming/VBG',
#  'states/VBZ',
#  'posted/VBD',
#  'ship/VB',
#  'struggled/VBD',
#  'increase/VB',
#  'impressed/VBN',
#  'entered/VBN',
#  'forgotten/VBN',
#  'unsettled/VBN',
#  'reacted/VBD',
#  'turned/VBN',
#  'paid/VBD',
#  'sign/VB',
#  'retard/VB',
#  'needs/VBZ',
#  'maintain/VB',
#  'needed/VBN',
#  'signifying/VBG',
#  'worried/VBN',
#  'changed/VBD',
#  'sold/VBN',
#  'assume/VBP',
#  'inform/VB',
#  'released/VBN',
#  'answered/VBN',
#  'CLEARS/VBZ',
#  'pumping/VBG',
#  'sleeping/VBG',
#  'abandoned/VBN',
#  'live/VB',
#  'Buying/VBG',
#  'decide/VBP',
#  'named/VBD',
#  'suspended/VBN',
#  'Excluding/VBG',
#  'aimed/VBD',
#  'accepting/VBG',
#  'let/VB',
#  'issued/VBN',
#  'drawn/VBN',
#  'include/VBP',
#  'sounded/VBD',
#  'treating/VBG',
#  'convinced/VBN',
#  'scrambled/VBD',
#  'notched/VBD',
#  'skyrocketed/VBN',
#  'Judging/VBG',
#  'commit/VB',
#  'terminated/VBD',
#  'publishes/VBZ',
#  'parched/VBN',
#  'sell/VBP',
#  'sees/VBZ',
#  'twinned/VBN',
#  'agree/VB',
#  'sew/VB',
#  'imposed/VBN',
#  'appeal/VBP',
#  'grant/VB',
#  'understood/VBD',
#  'requires/VBZ',
#  'negotiating/VBG',
#  'cleared/VBD',
#  'fled/VBD',
#  'gains/VBZ',
#  'consider/VB',
#  'reach/VB',
#  'abandon/VB',
#  'subscribe/VB',
#  'qualify/VB',
#  'has/VBP',
#  'rebound/VB',
#  'fumes/VBZ',
#  'have/VBP',
#  'classed/VBN',
#  'remarked/VBD',
#  'explains/VBZ',
#  'increases/VBZ',
#  'scrutinizing/VBG',
#  'leveraging/VBG',
#  'attracting/VBG',
#  'broadcasts/VBZ',
#  'eliminates/VBZ',
#  'implement/VB',
#  'had/VBD',
#  'done/VBN',
#  'received/VBN',
#  'considering/VBG',
#  'Being/VBG',
#  'ignored/VBD',
#  'vote/VB',
#  'seized/VBD',
#  'meet/VBP',
#  'excise/VB',
#  'meet/VB',
#  'remaining/VBG',
#  'keeps/VBZ',
#  'recruit/VB',
#  'skidded/VBD',
#  'beat/VBD',
#  'acknowledge/VB',
#  'resulted/VBN',
#  'exploit/VB',
#  'expressed/VBN',
#  'thwart/VB',
#  'preclude/VB',
#  'seems/VBZ',
#  'see/VB',
#  'released/VBD',
#  'cared/VBD',
#  'inherited/VBD',
#  'convey/VBP',
#  'entertain/VB',
#  'arrived/VBD',
#  'present/VB',
#  'outbid/VB',
#  'asked/VBN',
#  'stuck/VBD',
#  'established/VBD',
#  'reimbursed/VBN',
#  'passed/VBN',
#  'merged/VBN',
#  'try/VBP',
#  'opened/VBD',
#  'secured/VBD',
#  'appropriated/VBN',
#  'treat/VB',
#  ...}

# %%
set([word+"/"+tag for (word,tag) in word_tags_fd])
# Out:
# {'Average/NNP',
#  '1976/CD',
#  'Midvale/NNP',
#  '6.25/CD',
#  'carillons/NNS',
#  '2163.2/CD',
#  '*T*-147/-NONE-',
#  'COPPER/NNP',
#  'starters/NNS',
#  'after/RB',
#  'stock-market/NN',
#  'subscription/NN',
#  'withhold/VB',
#  'builds/VBZ',
#  'counterattack/NN',
#  'short/JJ',
#  'eased/VBD',
#  'defeats/VBZ',
#  'Messrs./NNPS',
#  'midtown/NN',
#  'unlike/IN',
#  '*-165/-NONE-',
#  'banking/NN',
#  'settlement/NN',
#  'change-ringing/NN',
#  '38.875/CD',
#  '*T*-56/-NONE-',
#  'colleges/NNS',
#  'forum/NN',
#  'beaten/JJ',
#  'introducing/VBG',
#  'Insurance/NNP',
#  'Ms./NNP',
#  'Labor/NNP',
#  'sketching/VBG',
#  'tissue/NN',
#  'grows/VBZ',
#  'goblins/NNS',
#  'admits/VBZ',
#  'maintaining/VBG',
#  'Westborough/NNP',
#  'lifes/NNS',
#  'Teacher/NN',
#  'fighting/VBG',
#  '&/CC',
#  'conducted/VBN',
#  'triple-C/NN',
#  'Lyn/NNP',
#  'reported/VBD',
#  'protocols/NNS',
#  'Controls/NNP',
#  'attract/VB',
#  'judge/NN',
#  'plaintiffs/NNS',
#  'mailing/NN',
#  'think/VBP',
#  'well/RB',
#  'illegal/JJ',
#  'Mutual/NNP',
#  'worry/VB',
#  'photocopying/VBG',
#  'admitting/VBG',
#  'underwriters/NNS',
#  'print/VBP',
#  'seasonal/JJ',
#  'sign/NN',
#  'Those/DT',
#  'month/NN',
#  'disk/NN',
#  'Nelms/NNP',
#  'involvement/NN',
#  'pricings/NNS',
#  'contests/NNS',
#  'deliberating/VBG',
#  'brakes/NNS',
#  'find/VBP',
#  'taught/VBD',
#  'sustained/VBN',
#  'familiarization/NN',
#  'treatment/NN',
#  '154.2/CD',
#  'Moon/NNP',
#  'including/VBG',
#  'monthly/RB',
#  'Brunswick/NNP',
#  'extremely/RB',
#  'indexes/NNS',
#  'AGREES/VBZ',
#  'cancer/NN',
#  'run/VB',
#  'put/NN',
#  'explanatory/JJ',
#  'firm/JJ',
#  'Sterling/NNP',
#  'differently/RB',
#  '86.12/CD',
#  'muted/VBN',
#  'interested/JJ',
#  'intend/VBP',
#  'disarray/NN',
#  'curses/NNS',
#  'concerned/VBN',
#  'officers/NNS',
#  'Wilmington/NNP',
#  'USIA/NNP',
#  'logic/NN',
#  '1.8/CD',
#  'ton/NN',
#  '150-point/JJ',
#  'upsetting/VBG',
#  'advanced/VBN',
#  '*T*-254/-NONE-',
#  'respond/VB',
#  'Heating/NN',
#  'broke/VBD',
#  'routes/VBZ',
#  'food/NN',
#  'leasing/NN',
#  'Soviets/NNPS',
#  'eating/VBG',
#  'malnutrition/NN',
#  'silicon/NN',
#  'bushels/NNS',
#  'growth/NN',
#  'quipped/VBD',
#  'basically/RB',
#  'contends/VBZ',
#  '*-62/-NONE-',
#  'ordinary/JJ',
#  'collar/NN',
#  'inspirational/JJ',
#  'LSI/NNP',
#  '722/CD',
#  '2.65/CD',
#  'simple/JJ',
#  'override/VB',
#  'book/NN',
#  '1903/CD',
#  'receivers/NNS',
#  'glamorize/VB',
#  'draw/VB',
#  'drooled/VBD',
#  'AC-130U/NN',
#  'fare/VBP',
#  'sentiment/NN',
#  'suffering/NN',
#  'boost/NN',
#  'Miss./NNP',
#  'specialized/VBN',
#  'McGovern/NNP',
#  'privately/RB',
#  'chauffeur/NN',
#  'derivative/JJ',
#  'payrolls/NNS',
#  'rivals/NNS',
#  'TRIMMING/VBG',
#  'gains/NNS',
#  'gained/VBN',
#  'Japanese/NNP',
#  'diagram/NN',
#  'high-priced/JJ',
#  'Ill./NNP',
#  'refused/VBN',
#  'Whether/IN',
#  'POP/NNP',
#  'go/VBP',
#  'marketer/NN',
#  'cheerleaders/NNS',
#  'TWO/CD',
#  'stemmed/VBD',
#  'NASD/NNP',
#  'Funny/NNP',
#  'personnel/NNS',
#  'fault/VBP',
#  'systems/NNS',
#  'founded/VBN',
#  'brain/NN',
#  'loans/NNS',
#  'Artist/NNP',
#  'high-flying/JJ',
#  'duly/RB',
#  'view/VB',
#  'buy-out/NN',
#  'increases/NNS',
#  'drink/NN',
#  'application/NN',
#  'exceeding/VBG',
#  'ball/NN',
#  'brilliant/JJ',
#  'use/VBP',
#  'told/VBD',
#  'DiLoreto/NNP',
#  '1.8500/CD',
#  'brokering/VBG',
#  'vagabond/NN',
#  'chefs/NNS',
#  'reflection/NN',
#  '1956/CD',
#  'demand/VB',
#  'comment/VB',
#  'complex/JJ',
#  'Elco/NNP',
#  'collecting/VBG',
#  'newspapers/NNS',
#  'began/VBD',
#  'Nesconset/NNP',
#  'quarterly/JJ',
#  'permits/VBZ',
#  'banned/VBN',
#  'rescheduled/VBN',
#  'argues/VBZ',
#  'address/NN',
#  'poor/NNP',
#  'Philip/NNP',
#  'export/NN',
#  'robotic/JJ',
#  'Explorer/NNP',
#  'taste/NN',
#  '6.50/CD',
#  'session/NN',
#  'successful/JJ',
#  'U.S.A./NNP',
#  'places/VBZ',
#  'next/JJ',
#  '2,500/CD',
#  'why/WRB',
#  'Long/NNP',
#  '2.62/CD',
#  'crossing/VBG',
#  'tight/JJ',
#  'Crum/NNP',
#  'Remember/VB',
#  'examples/NNS',
#  'jet/VBP',
#  '*T*-99/-NONE-',
#  'reminded/VBD',
#  '29.9/CD',
#  '*T*-19/-NONE-',
#  'moves/VBZ',
#  'stand/VBP',
#  'lending/VBG',
#  'independent/JJ',
#  'employee/NN',
#  'Minneapolis-based/JJ',
#  'Nemeth/NNP',
#  'diethylstilbestrol/NN',
#  'nuclear/JJ',
#  '*T*-216/-NONE-',
#  'days/NNS',
#  'markup/NN',
#  'unsettling/JJ',
#  'Plantation/NNP',
#  'wave/NN',
#  'car-safety/JJ',
#  'institute/VB',
#  'chilled/VBN',
#  'nondurable/JJ',
#  'change/VBP',
#  'Wilbur/NNP',
#  'Kenneth/NNP',
#  '@/IN',
#  'McCormick/NNP',
#  'Hugo/NNP',
#  'debenture/NN',
#  'Goode/NNP',
#  'polyester/NN',
#  'particular/JJ',
#  '672/CD',
#  'logjam/NN',
#  '``/``',
#  'allocated/VBN',
#  'featured/VBD',
#  '*T*-152/-NONE-',
#  'leave/VB',
#  'we-Japanese/JJ',
#  'cost-benefit/JJ',
#  'he/PRP',
#  'Drink/NN',
#  'Proponents/NNS',
#  'record/JJ',
#  'Chinese/NNP',
#  'acting/JJ',
#  'contributed/VBD',
#  '1.92/CD',
#  'OK/UH',
#  'disposed/VBD',
#  'non-U.S./NNP',
#  'leader/NN',
#  'Brenda/NNP',
#  'Unitholders/NNS',
#  'clear/JJ',
#  'Prime/NNP',
#  'U.S./JJ',
#  'inches/NNS',
#  'entertaining/JJ',
#  'Senior/NNP',
#  'truck/NN',
#  '18.6/CD',
#  '190/CD',
#  'princely/JJ',
#  'Smaby/NNP',
#  'friend/NN',
#  'omitted/VBD',
#  'rate-sensitive/JJ',
#  'Sale/NNP',
#  '%/JJ',
#  'again/RB',
#  'drafted/VBN',
#  'worker/NN',
#  'anemic/JJ',
#  'limited-partnership/NN',
#  'three-quarters/NNS',
#  'downtown/NN',
#  'reporter/NN',
#  'American/NNP',
#  'filters/NNS',
#  'generated/VBN',
#  'realized/VBD',
#  'Securities/NNPS',
#  'pulling/VBG',
#  'relocate/NN',
#  'Trailer/NNP',
#  'renew/VB',
#  'incest/NN',
#  'creation/NN',
#  'criteria/NNS',
#  'Mikhail/NNP',
#  'centimeter/NN',
#  'institutions/NNS',
#  'question/NN',
#  'Salty/NNP',
#  'reduction/NN',
#  'freeway/NN',
#  'exhaust/NN',
#  'periodontal/JJ',
#  'safe-deposit/JJ',
#  'puzzled/VBN',
#  'Appropriations/NNS',
#  'curbed/VBN',
#  'use/VB',
#  '374.20/CD',
#  'Noble/NNP',
#  'Hanover/NNP',
#  'interesting/JJ',
#  '45/CD',
#  'INTERPUBLIC/NNP',
#  '*T*-63/-NONE-',
#  'one-hour/JJ',
#  'Writers/NNPS',
#  'involved/VBD',
#  'mergers/NNS',
#  'regrettable/JJ',
#  'superpremiums/NNS',
#  'ended/VBN',
#  '35.2/CD',
#  'discussion/NN',
#  'administer/VB',
#  'rallying/VBG',
#  'spokewoman/NN',
#  'transferring/VBG',
#  'flim-flammery/NN',
#  'Frank/NNP',
#  'endless/JJ',
#  '30-point/JJ',
#  'necessary/JJ',
#  '100,980/CD',
#  'It/PRP',
#  'hearings/NNS',
#  'test/VBP',
#  'Deane/NNP',
#  'Frances/NNP',
#  'willing/JJ',
#  '59.6/CD',
#  'wild/JJ',
#  'Argentine/JJ',
#  '250,000/CD',
#  'day/NN',
#  'telling/VBG',
#  'curtail/VB',
#  'Marina/NNP',
#  'latter/NN',
#  'neutrons/NNS',
#  'complexes/NNS',
#  'Moreover/JJR',
#  '*T*-76/-NONE-',
#  'compound/NN',
#  '*-53/-NONE-',
#  'arbitragers/NNS',
#  'unjustified/JJ',
#  '26.2/CD',
#  'effects/NNS',
#  'mature/VBP',
#  'halted/VBN',
#  'hold/VBP',
#  'Confidence/NNP',
#  'Hans/NNP',
#  'appeals/NNS',
#  'when/WRB',
#  'Hammond/NNP',
#  '*T*-42/-NONE-',
#  'Electronics/NNP',
#  'longest/JJS',
#  'lotions/NNS',
#  '59/CD',
#  '445/CD',
#  'stirred/VBD',
#  'low-ball/JJ',
#  'useful/JJ',
#  'aimed/VBN',
#  '*T*-108/-NONE-',
#  'try/VB',
#  'open/JJ',
#  'That/IN',
#  'Orleans-based/JJ',
#  '57.7/CD',
#  'Speedway/NNP',
#  "C'mon/VB",
#  'octogenarians/NNS',
#  'Criminal/NNP',
#  'healthy/JJ',
#  'buttoned-down/JJ',
#  'one-newspaper/JJ',
#  'intended/VBN',
#  'fine/RB',
#  'Mitsui/NNP',
#  'Reddington/NNP',
#  'pass/VB',
#  'law/NN',
#  'excision/NN',
#  'trains/NNS',
#  'jurisdictional/JJ',
#  'cheerleading/NN',
#  'Jacobs/NNP',
#  'TREASURY/NNP',
#  'Biscayne/NNP',
#  'snow/NN',
#  'retraced/VBD',
#  'Monday/NNP',
#  'fourth/JJ',
#  'computer-assisted/JJ',
#  'businesses/NNS',
#  'boys/NNS',
#  'copy/VB',
#  '0.2/CD',
#  'fringe/NN',
#  'stock-price/NN',
#  'Friedrichs/NNP',
#  'six-packs/NNS',
#  'winter/NN',
#  'Luce/NNP',
#  '415.6/CD',
#  'Stevenson/NNP',
#  'Babcock/NNP',
#  'wo/MD',
#  'dumped/VBD',
#  'serious/JJ',
#  'preapproved/VBN',
#  'scandal/NN',
#  'expressed/VBD',
#  'High-grade/JJ',
#  'live/VBP',
#  'drums/NNS',
#  'Metal/NNP',
#  'Yesterday/NN',
#  'Allied/NNP',
#  'containing/VBG',
#  'returns/NNS',
#  'Linden/NNP',
#  'N.Y./NNP',
#  'contemporary/JJ',
#  'disease/NN',
#  'plan/VBP',
#  'restructure/VB',
#  'Economic/JJ',
#  'second/JJ',
#  'come/VB',
#  'standing/NN',
#  '16.09/CD',
#  'meets/VBZ',
#  'direct-mail/JJ',
#  '6.21/CD',
#  'liberals/NNS',
#  'authorizing/VBG',
#  'it/PRP',
#  'building/NN',
#  'ambitions/NNS',
#  'convert/VB',
#  'special/JJ',
#  'troubled/JJ',
#  'Barnett/NNP',
#  'Garrison/NNP',
#  'Class/NNP',
#  '72.7/CD',
#  'odd-year/JJ',
#  '4.75/CD',
#  'Section/NN',
#  'cumbersome/JJ',
#  'through/IN',
#  'Bates/NNP',
#  'counterweight/NN',
#  'respond/VBP',
#  '36.9/CD',
#  'force/VBP',
#  'semiliterate/JJ',
#  'Lids/NNS',
#  'small-company/NN',
#  'That/WDT',
#  'neighborhood/NN',
#  '40.21/CD',
#  'fewer/JJR',
#  'theme/NN',
#  'worth/NN',
#  'bout/NN',
#  'Division/NNP',
#  'sheaf/NN',
#  'Arbitrage/NN',
#  'Preston/NNP',
#  'folded/VBD',
#  'highs/NNS',
#  'Veraldi/NNP',
#  'eases/VBZ',
#  'Nearby/JJ',
#  'Child/NNP',
#  'Fe/NNP',
#  'travel/NN',
#  'Palestine/NNP',
#  'apologize/VB',
#  'transaction/NN',
#  'Atsushi/NNP',
#  'consequences/NNS',
#  '*-102/-NONE-',
#  'LANDOR/NNP',
#  'underperforming/VBG',
#  '*T*-183/-NONE-',
#  'offenders/NNS',
#  'Marubeni/NNP',
#  'Eveready/NNP',
#  '1.28/CD',
#  'scarcely/RB',
#  'whipsaw/VB',
#  'Desai/NNP',
#  'Futures/NNPS',
#  'deliver/VB',
#  'officer/NN',
#  'Erbamont/NNP',
#  'In/NNP',
#  'job/NN',
#  'weather/VB',
#  'selected/VBN',
#  'orchestrated/VBN',
#  'sued/VBD',
#  '5.7/CD',
#  '321/CD',
#  'Futures/NNP',
#  'external/JJ',
#  'Savings/NNP',
#  'advocated/VBD',
#  'destination/NN',
#  'operating/VBG',
#  'drop-off/JJ',
#  'capitalist/JJ',
#  'sensational/JJ',
#  'winning/VBG',
#  'midnight/NN',
#  'enabled/VBD',
#  'annoyed/VBD',
#  'pennies/NNS',
#  'throws/VBZ',
#  'chatter/NN',
#  'Saturday/NNP',
#  'Unless/IN',
#  'Zicklin/NNP',
#  'waters/NNS',
#  'announcer/NN',
#  'triple-A-rated/JJ',
#  'Commonwealth/NNP',
#  'Commerce/NNP',
#  'clear/VB',
#  'Futures/NNS',
#  'European/NNP',
#  'surfaced/VBN',
#  'that/RB',
#  'voice/VBP',
#  'Clara/NNP',
#  'Indonesia/NNP',
#  'Joel/NNP',
#  'plight/NN',
#  'On/IN',
#  'tremendous/JJ',
#  'presidents/NNS',
#  'proposing/VBG',
#  'Institutes/NNPS',
#  'favorite/JJ',
#  'balls/NNS',
#  'But/CC',
#  'mid-size/JJ',
#  'classroom/NN',
#  'mechanisms/NNS',
#  'batting/NN',
#  'sterling/NN',
#  'requested/VBN',
#  'broad-based/JJ',
#  '9.37/CD',
#  'Customers/NNS',
#  'almost/RB',
#  'Zuckerman/NNP',
#  '13.5/CD',
#  '29year/JJ',
#  'succeeds/VBZ',
#  'sold/VBD',
#  'Savings/NNPS',
#  'profitability/NN',
#  '177/CD',
#  'Guffey/NNP',
#  'Wall/NNP',
#  'downturn/NN',
#  'gentle/JJ',
#  '1.17/CD',
#  'milk/NN',
#  'Visa/NNP',
#  'cue/NN',
#  'firm/NN',
#  'contacted/VBN',
#  'refile/VB',
#  'packed/JJ',
#  'teaches/VBZ',
#  'entitles/VBZ',
#  'cutthroat/JJ',
#  'Next/JJ',
#  'printing-press/NN',
#  'tallies/NNS',
#  'analyst/NN',
#  'Interviews/NNS',
#  'immune/JJ',
#  'cause/VB',
#  'directed/VBN',
#  'Little/RB',
#  'ideological/JJ',
#  'behalf/NN',
#  'Stadiums/NNS',
#  'trail/VB',
#  'TRIAL/NN',
#  'in-store/JJ',
#  'vast/JJ',
#  'Uzi-model/JJ',
#  'Scannell/NNP',
#  'graphs/NNS',
#  '*-10/-NONE-',
#  'As/IN',
#  'hamstrung/VBP',
#  'meaningful/JJ',
#  'Motor/NNP',
#  'milestones/NNS',
#  'liable/JJ',
#  'North/NNP',
#  'restricting/VBG',
#  'Experts/NNS',
#  'substitute/NN',
#  'entertainment/NN',
#  'character/NN',
#  'asset-valuation/NN',
#  'mesothelioma/NN',
#  'population/NN',
#  'Ore./NNP',
#  'sides/NNS',
#  'impatient/NN',
#  'dusty/JJ',
#  'female/JJ',
#  'revised/VBN',
#  '*T*-22/-NONE-',
#  'lot/NN',
#  'custom-chip/JJ',
#  'automatic/JJ',
#  '*T*-86/-NONE-',
#  'deemed/VBD',
#  'premiere/NN',
#  'Graham/NNP',
#  'light-truck/JJ',
#  'further/RB',
#  'pharaohs/NNS',
#  'tablets/NNS',
#  'Revenue/NNP',
#  'peddling/NN',
#  'waiting/VBG',
#  'candidates/NNS',
#  'unconstitutional/JJ',
#  'pressured/JJ',
#  'mentioned/VBN',
#  'unwary/JJ',
#  'Conference/NNP',
#  'unfair/JJ',
#  'IRS/NNP',
#  'copyrights/NNS',
#  'ranging/VBG',
#  'issuers/NNS',
#  'M./NNP',
#  'March/NNP',
#  'over/JJ',
#  'architect/NN',
#  'want/VBP',
#  'even/JJ',
#  'copper/NN',
#  'muscling/VBG',
#  'gunship/NN',
#  'Or/CC',
#  'All/DT',
#  '43-year-old/JJ',
#  '3,500/CD',
#  'gauges/VBZ',
#  'auspices/NNS',
#  'Romanee-Conti/NNP',
#  '2.15/CD',
#  'drop-in/JJ',
#  'Business/NNP',
#  'Citicorp/NNP',
#  'low/JJ',
#  'choose/VB',
#  'sending/VBG',
#  '*T*-110/-NONE-',
#  'struggle/NN',
#  'sulfur-dioxide/NN',
#  'IX/CD',
#  'Phelan/NNP',
#  '*-28/-NONE-',
#  'Dollar-yen/JJ',
#  'Tache/NNP',
#  'vintages/NNS',
#  'chiefly/RB',
#  'personal/JJ',
#  'non-encapsulating/JJ',
#  'semesters/NNS',
#  'institutional/JJ',
#  'retail/NN',
#  'augment/VB',
#  'Stock-index/NN',
#  'shot/VBD',
#  'migrate/VB',
#  'bidding/NN',
#  'surgeon/NN',
#  'Lindner/NNP',
#  'bottlenecks/NNS',
#  'Panama/NNP',
#  'spouse/NN',
#  'rare/JJ',
#  'evenly/RB',
#  'Germans/NNPS',
#  'tax/NN',
#  'symmetry/NN',
#  'Chandler/NNP',
#  'bank-backed/JJ',
#  'Cabernet/NNP',
#  'top-selling/JJ',
#  'understatement/NN',
#  'Designated/NNP',
#  'Lebanon/NNP',
#  'Oy/NNP',
#  'novelist/NN',
#  'despise/VB',
#  'reprint/VB',
#  'available/JJ',
#  'Olsen/NNP',
#  'mortgage/NN',
#  'framers/NNS',
#  'Tailors/NNP',
#  'unwashed/JJ',
#  'succession/NN',
#  'His/PRP$',
#  'HHS/NNP',
#  'professionals/NNS',
#  'caused/VBN',
#  'Late/RB',
#  'intraocular/JJ',
#  'facilitate/VB',
#  'thumbing/VBG',
#  'planned/JJ',
#  '*-151/-NONE-',
#  'native/JJ',
#  '2019/CD',
#  'electrical/JJ',
#  'herself/PRP',
#  '87-store/JJ',
#  '*ICH*-2/-NONE-',
#  '*T*-69/-NONE-',
#  'paying/VBG',
#  'boost/VB',
#  'replicating/VBG',
#  'though/RB',
#  'modern-day/JJ',
#  'Practical/NNP',
#  'troubles/NNS',
#  'dust-up/NN',
#  'personally/RB',
#  'period/NN',
#  'educated/VBN',
#  'maturing/VBG',
#  '*T*-251/-NONE-',
#  'depleted/VBN',
#  'land-idling/JJ',
#  'charges/VBZ',
#  'Yasuda/NNP',
#  'Floyd/NNP',
#  'newest/JJS',
#  'margins/NNS',
#  'adults/NNS',
#  'classified/VBN',
#  'monopolize/VB',
#  'Arbitraging/VBG',
#  'F./NNP',
#  'off/JJ',
#  'insurance/NN',
#  'falls/VBZ',
#  'competition/NN',
#  '38.5/CD',
#  'forecast/VBD',
#  'for/IN',
#  'secede/VB',
#  'sad/JJ',
#  'disputed/VBN',
#  'deserving/JJ',
#  'upset/JJ',
#  'Mercer/NNP',
#  'Troubled/NNP',
#  'telephone/NN',
#  'Wellcome/NNP',
#  'less/RBR',
#  'subject/JJ',
#  'copper-rich/JJ',
#  '26.5/CD',
#  'WTVJ/NNP',
#  'sports/NNS',
#  'convertible/JJ',
#  'wife/NN',
#  '*T*-130/-NONE-',
#  'history/NN',
#  'costs/NNS',
#  '280/CD',
#  'push/VBP',
#  'greater/JJR',
#  'pediatrician/NN',
#  'Woodrow/NNP',
#  'year-earlier/JJ',
#  'vague/JJ',
#  'Named/VBN',
#  'befuddled/VBD',
#  'Singapore/NNP',
#  'stark/JJ',
#  'orders/VBZ',
#  'Islamic/NNP',
#  'Kappa/NNP',
#  'During/IN',
#  'materials/NNS',
#  'suspend/VB',
#  'diabetes/NN',
#  'cater/VBP',
#  'transformed/VBN',
#  'inhibit/VB',
#  'audience/NN',
#  'emergency/NN',
#  'overcapacity/NN',
#  'Jr./NNP',
#  'managed/VBD',
#  'cast/VBN',
#  'Educational/NNP',
#  'Olympic/NNP',
#  'novel/NN',
#  'starts/NNS',
#  'outlook/NN',
#  'below/RB',
#  'life/NN',
#  'K./NNP',
#  '14,821/CD',
#  'Park/NNP',
#  'Dorothy/NNP',
#  'thousands/NNS',
#  'read/VBD',
#  '11,000/CD',
#  'Sir/NNP',
#  'safety/NN',
#  'propagandize/VB',
#  'floated/VBN',
#  'gradual/JJ',
#  'computer-driven/JJ',
#  'remarks/NNS',
#  'Exxon/NNP',
#  'embarrassing/JJ',
#  '51.6/CD',
#  'geography/NN',
#  'Mo.-based/JJ',
#  'Aquino/NNP',
#  'Akerfeldt/NNP',
#  'wholesaler/NN',
#  'Pictures/NNP',
#  'microcomputers/NNS',
#  'obsessed/VBN',
#  'had/VBN',
#  'earnings/NNS',
#  'million-a-year/JJ',
#  'alert/NN',
#  'sights/NNS',
#  'Great/NNP',
#  'believed/VBN',
#  'crime/NN',
#  'reality/NN',
#  '6,500/CD',
#  '1961/CD',
#  '75-year-old/CD',
#  '570/CD',
#  'unresolved/JJ',
#  'Nuys/NNP',
#  'households/NNS',
#  'severe/JJ',
#  'fetal-tissue/JJ',
#  'Pretoria/NNP',
#  'notify/VB',
#  'lobbies/NNS',
#  'duck/VB',
#  'final/JJ',
#  'fatalities/NNS',
#  '608,413/CD',
#  '93,000/CD',
#  'profession/NN',
#  'deficit/NN',
#  'pro-choice/JJ',
#  'the/CD',
#  '*-126/-NONE-',
#  'ascendency/NN',
#  'nameplate/NN',
#  'voluntary/JJ',
#  'Nipponese/JJ',
#  'ChemPlus/NNP',
#  'powerhouse/NN',
#  'JUDICIAL/JJ',
#  'evil/NN',
#  'expectation/NN',
#  'expects/VBZ',
#  'Hong/NNP',
#  'high-technology/NN',
#  'approval/NN',
#  'Critics/NNS',
#  'Index/NN',
#  'tentatively/RB',
#  'plunged/VBN',
#  'Atlanta/NNP',
#  'Lt./NNP',
#  'Philippine/NNP',
#  'speeches/NNS',
#  '1990s/CD',
#  'situations/NNS',
#  'T-shirts/NNS',
#  'worst/JJS',
#  'Recess/NN',
#  'loose/JJ',
#  'favor/NN',
#  'nurtured/VBN',
#  'Israel/NNP',
#  'web/NN',
#  'elaborate/VB',
#  '1980s/NN',
#  'inching/VBG',
#  'contains/VBZ',
#  'sense/VBP',
#  'licensed/VBN',
#  'Haut-Brion/NNP',
#  'outranks/VBZ',
#  'specify/VB',
#  'moratorium/NN',
#  '12.09/CD',
#  'marriages/NNS',
#  'Mattress/NNP',
#  'Jon/NNP',
#  'Glenn/NNP',
#  'Platt/NNP',
#  'strains/NNS',
#  '25.6/CD',
#  'creditor/NN',
#  'states/VBZ',
#  'cancellation/NN',
#  'Toronto-based/JJ',
#  'Sasaki/NNP',
#  '11.10/CD',
#  'high/JJ',
#  'Chinese/NN',
#  'gain/NN',
#  '18,444/CD',
#  '1.49/CD',
#  'males/NNS',
#  '8300/JJ',
#  'sexy/JJ',
#  'entered/VBN',
#  'essentially/RB',
#  'filling/NN',
#  'item/NN',
#  'battery/NN',
#  'Kaminski/NNP',
#  'allegedly/RB',
#  'Byron/NNP',
#  'environmentalists/NNS',
#  '115/CD',
#  'Caldor/NNP',
#  'Soups/NNP',
#  ...}

# %%
cfd1 = nltk.ConditionalFreqDist(wsj)
cfd1['yield'].keys()
# Out:
# dict_keys(['NN', 'VB'])

# %%
cfd1['cut'].keys()
# Out:
# dict_keys(['VBD', 'VB', 'VBN', 'NN'])

# %%
dict(cfd1)
# Out:
# {'Pierre': FreqDist({'NNP': 1}),
#  'Vinken': FreqDist({'NNP': 2}),
#  ',': FreqDist({',': 4885}),
#  '61': FreqDist({'CD': 5}),
#  'years': FreqDist({'NNS': 115}),
#  'old': FreqDist({'JJ': 24}),
#  'will': FreqDist({'MD': 280, 'NN': 1}),
#  'join': FreqDist({'VB': 4}),
#  'the': FreqDist({'DT': 4038, 'JJ': 5, 'NNP': 1, 'CD': 1}),
#  'board': FreqDist({'NN': 30}),
#  'as': FreqDist({'IN': 333, 'RB': 52}),
#  'a': FreqDist({'DT': 1874, 'JJ': 2, 'IN': 1, 'LS': 1}),
#  'nonexecutive': FreqDist({'JJ': 5}),
#  'director': FreqDist({'NN': 32}),
#  'Nov.': FreqDist({'NNP': 23, 'NN': 1}),
#  '29': FreqDist({'CD': 5}),
#  '.': FreqDist({'.': 3828}),
#  'Mr.': FreqDist({'NNP': 375}),
#  'is': FreqDist({'VBZ': 671}),
#  'chairman': FreqDist({'NN': 45}),
#  'of': FreqDist({'IN': 2319}),
#  'Elsevier': FreqDist({'NNP': 1}),
#  'N.V.': FreqDist({'NNP': 3}),
#  'Dutch': FreqDist({'JJ': 2, 'NNP': 1}),
#  'publishing': FreqDist({'NN': 9, 'VBG': 4}),
#  'group': FreqDist({'NN': 43}),
#  'Rudolph': FreqDist({'NNP': 3}),
#  'Agnew': FreqDist({'NNP': 1}),
#  '55': FreqDist({'CD': 10}),
#  'and': FreqDist({'CC': 1505, 'JJ': 3, 'NN': 2, 'IN': 1}),
#  'former': FreqDist({'JJ': 19}),
#  'Consolidated': FreqDist({'NNP': 2}),
#  'Gold': FreqDist({'NNP': 2}),
#  'Fields': FreqDist({'NNP': 2}),
#  'PLC': FreqDist({'NNP': 13}),
#  'was': FreqDist({'VBD': 367}),
#  'named': FreqDist({'VBN': 20, 'VBD': 2}),
#  '*-1': FreqDist({'-NONE-': 1123}),
#  'this': FreqDist({'DT': 184}),
#  'British': FreqDist({'JJ': 7, 'NNP': 4}),
#  'industrial': FreqDist({'JJ': 18}),
#  'conglomerate': FreqDist({'NN': 3}),
#  'A': FreqDist({'DT': 105, 'NN': 3, 'NNP': 2}),
#  'form': FreqDist({'NN': 16, 'VB': 1}),
#  'asbestos': FreqDist({'NN': 11}),
#  'once': FreqDist({'RB': 13, 'IN': 1}),
#  'used': FreqDist({'VBN': 26, 'VBD': 4, 'JJ': 2}),
#  '*': FreqDist({'-NONE-': 965}),
#  'to': FreqDist({'TO': 2161, 'IN': 2, 'JJ': 1}),
#  'make': FreqDist({'VB': 63, 'VBP': 10}),
#  'Kent': FreqDist({'NNP': 8}),
#  'cigarette': FreqDist({'NN': 4}),
#  'filters': FreqDist({'NNS': 7}),
#  'has': FreqDist({'VBZ': 338, 'VBP': 1}),
#  'caused': FreqDist({'VBN': 9, 'VBD': 4}),
#  'high': FreqDist({'JJ': 26, 'NN': 3, 'RB': 2}),
#  'percentage': FreqDist({'NN': 11}),
#  'cancer': FreqDist({'NN': 7}),
#  'deaths': FreqDist({'NNS': 6}),
#  'among': FreqDist({'IN': 31}),
#  'workers': FreqDist({'NNS': 20}),
#  'exposed': FreqDist({'VBN': 2}),
#  'it': FreqDist({'PRP': 476}),
#  'more': FreqDist({'JJR': 111, 'RBR': 86, 'JJ': 1}),
#  'than': FreqDist({'IN': 180}),
#  '30': FreqDist({'CD': 47}),
#  'ago': FreqDist({'IN': 22, 'RB': 16}),
#  'researchers': FreqDist({'NNS': 13}),
#  'reported': FreqDist({'VBD': 25, 'VBN': 12}),
#  '0': FreqDist({'-NONE-': 1099}),
#  '*T*-1': FreqDist({'-NONE-': 806}),
#  'The': FreqDist({'DT': 713, 'NNP': 4}),
#  'fiber': FreqDist({'NN': 1}),
#  'crocidolite': FreqDist({'NN': 5}),
#  'unusually': FreqDist({'RB': 2}),
#  'resilient': FreqDist({'JJ': 1}),
#  'enters': FreqDist({'VBZ': 4}),
#  'lungs': FreqDist({'NNS': 1}),
#  'with': FreqDist({'IN': 387}),
#  'even': FreqDist({'RB': 64, 'JJ': 3, 'VB': 1}),
#  'brief': FreqDist({'JJ': 4, 'VB': 1}),
#  'exposures': FreqDist({'NNS': 3}),
#  'causing': FreqDist({'VBG': 5}),
#  'symptoms': FreqDist({'NNS': 1}),
#  'that': FreqDist({'IN': 513, 'WDT': 214, 'DT': 77, 'RB': 3}),
#  'show': FreqDist({'NN': 7, 'VBP': 4, 'VB': 2}),
#  'up': FreqDist({'RP': 77, 'RB': 49, 'IN': 27}),
#  'decades': FreqDist({'NNS': 3}),
#  'later': FreqDist({'JJ': 11, 'RBR': 2}),
#  'said': FreqDist({'VBD': 614, 'VBN': 14}),
#  '*T*-2': FreqDist({'-NONE-': 345}),
#  'Lorillard': FreqDist({'NNP': 4, 'NN': 1}),
#  'Inc.': FreqDist({'NNP': 97}),
#  'unit': FreqDist({'NN': 36}),
#  'New': FreqDist({'NNP': 159, 'JJ': 6}),
#  'York-based': FreqDist({'JJ': 4, 'NNP': 1}),
#  'Loews': FreqDist({'NNP': 1}),
#  'Corp.': FreqDist({'NNP': 117}),
#  'makes': FreqDist({'VBZ': 11}),
#  'cigarettes': FreqDist({'NNS': 6}),
#  'stopped': FreqDist({'VBD': 4, 'VBN': 3}),
#  'using': FreqDist({'VBG': 16}),
#  'in': FreqDist({'IN': 1554, 'RP': 15, 'RB': 2, 'NN': 1}),
#  'its': FreqDist({'PRP$': 332}),
#  'Micronite': FreqDist({'NN': 1}),
#  '1956': FreqDist({'CD': 2}),
#  'Although': FreqDist({'IN': 14}),
#  'preliminary': FreqDist({'JJ': 5}),
#  'findings': FreqDist({'NNS': 8}),
#  'were': FreqDist({'VBD': 197}),
#  '*-2': FreqDist({'-NONE-': 372}),
#  'year': FreqDist({'NN': 212}),
#  'latest': FreqDist({'JJS': 22}),
#  'results': FreqDist({'NNS': 21}),
#  'appear': FreqDist({'VBP': 3, 'VB': 1}),
#  'today': FreqDist({'NN': 22}),
#  "'s": FreqDist({'POS': 761, 'VBZ': 103}),
#  'England': FreqDist({'NNP': 23}),
#  'Journal': FreqDist({'NNP': 10}),
#  'Medicine': FreqDist({'NNP': 5}),
#  'forum': FreqDist({'NN': 2}),
#  'likely': FreqDist({'JJ': 20, 'RB': 2}),
#  'bring': FreqDist({'VB': 9}),
#  'new': FreqDist({'JJ': 162}),
#  'attention': FreqDist({'NN': 8}),
#  'problem': FreqDist({'NN': 30}),
#  'spokewoman': FreqDist({'NN': 1}),
#  '``': FreqDist({'``': 702}),
#  'This': FreqDist({'DT': 40}),
#  'an': FreqDist({'DT': 316}),
#  'story': FreqDist({'NN': 6}),
#  'We': FreqDist({'PRP': 47}),
#  "'re": FreqDist({'VBP': 29}),
#  'talking': FreqDist({'VBG': 4}),
#  'about': FreqDist({'IN': 176, 'RB': 27, 'RP': 3}),
#  'before': FreqDist({'IN': 42, 'RB': 6}),
#  'anyone': FreqDist({'NN': 6}),
#  'heard': FreqDist({'VBN': 3, 'VBD': 1}),
#  'having': FreqDist({'VBG': 11}),
#  'any': FreqDist({'DT': 103, 'RB': 2}),
#  'questionable': FreqDist({'JJ': 3}),
#  'properties': FreqDist({'NNS': 1}),
#  'There': FreqDist({'EX': 32}),
#  'no': FreqDist({'DT': 76, 'RB': 10, 'UH': 1}),
#  'our': FreqDist({'PRP$': 26}),
#  'products': FreqDist({'NNS': 32}),
#  'now': FreqDist({'RB': 61}),
#  "''": FreqDist({"''": 684}),
#  'Neither': FreqDist({'DT': 5}),
#  'nor': FreqDist({'CC': 11}),
#  'who': FreqDist({'WP': 163}),
#  '*T*-3': FreqDist({'-NONE-': 97}),
#  'studied': FreqDist({'VBN': 4, 'VBD': 1}),
#  'aware': FreqDist({'JJ': 3}),
#  'research': FreqDist({'NN': 33}),
#  'on': FreqDist({'IN': 483, 'RP': 6, 'RB': 1}),
#  'smokers': FreqDist({'NNS': 2}),
#  'have': FreqDist({'VBP': 221, 'VB': 101, 'VBD': 1}),
#  'useful': FreqDist({'JJ': 2}),
#  'information': FreqDist({'NN': 26}),
#  'whether': FreqDist({'IN': 28}),
#  'users': FreqDist({'NNS': 2}),
#  'are': FreqDist({'VBP': 367, 'NN': 1, 'IN': 1}),
#  'at': FreqDist({'IN': 402}),
#  'risk': FreqDist({'NN': 7, 'VB': 5}),
#  'James': FreqDist({'NNP': 22}),
#  'A.': FreqDist({'NNP': 16, 'NN': 2}),
#  'Talcott': FreqDist({'NNP': 4}),
#  'Boston': FreqDist({'NNP': 17}),
#  'Dana-Farber': FreqDist({'NNP': 1}),
#  'Cancer': FreqDist({'NNP': 2}),
#  'Institute': FreqDist({'NNP': 15}),
#  'Dr.': FreqDist({'NNP': 13}),
#  'led': FreqDist({'VBN': 9, 'VBD': 7}),
#  'team': FreqDist({'NN': 17}),
#  'from': FreqDist({'IN': 386}),
#  'National': FreqDist({'NNP': 20}),
#  'medical': FreqDist({'JJ': 7}),
#  'schools': FreqDist({'NNS': 9}),
#  'Harvard': FreqDist({'NNP': 3}),
#  'University': FreqDist({'NNP': 22}),
#  'spokeswoman': FreqDist({'NN': 8}),
#  'very': FreqDist({'RB': 28, 'JJ': 3}),
#  'modest': FreqDist({'JJ': 3}),
#  'amounts': FreqDist({'NNS': 5, 'VBZ': 1}),
#  'making': FreqDist({'VBG': 20}),
#  'paper': FreqDist({'NN': 28}),
#  'for': FreqDist({'IN': 815, 'RB': 1, 'RP': 1}),
#  'early': FreqDist({'JJ': 29, 'RB': 14}),
#  '1950s': FreqDist({'CD': 2}),
#  'replaced': FreqDist({'VBN': 5, 'VBD': 1}),
#  'different': FreqDist({'JJ': 21}),
#  'type': FreqDist({'NN': 11}),
#  'filter': FreqDist({'NN': 1}),
#  'From': FreqDist({'IN': 5}),
#  '1953': FreqDist({'CD': 1}),
#  '1955': FreqDist({'CD': 1}),
#  '9.8': FreqDist({'CD': 2}),
#  'billion': FreqDist({'CD': 159}),
#  'sold': FreqDist({'VBN': 25, 'VBD': 14}),
#  '*-3': FreqDist({'-NONE-': 130}),
#  'company': FreqDist({'NN': 260}),
#  'Among': FreqDist({'IN': 13}),
#  '33': FreqDist({'CD': 7}),
#  'men': FreqDist({'NNS': 10}),
#  '*T*-4': FreqDist({'-NONE-': 23}),
#  'worked': FreqDist({'VBD': 5, 'VBN': 2}),
#  'closely': FreqDist({'RB': 15}),
#  'substance': FreqDist({'NN': 5}),
#  '28': FreqDist({'CD': 4}),
#  '*ICH*-1': FreqDist({'-NONE-': 70}),
#  'died': FreqDist({'VBD': 2, 'VBN': 1}),
#  '--': FreqDist({':': 230}),
#  'three': FreqDist({'CD': 48}),
#  'times': FreqDist({'NNS': 16}),
#  'expected': FreqDist({'VBN': 52}),
#  'number': FreqDist({'NN': 45}),
#  'Four': FreqDist({'CD': 1}),
#  'five': FreqDist({'CD': 29}),
#  'surviving': FreqDist({'VBG': 3}),
#  'asbestos-related': FreqDist({'JJ': 3}),
#  'diseases': FreqDist({'NNS': 7}),
#  'including': FreqDist({'VBG': 38, 'IN': 1}),
#  'recently': FreqDist({'RB': 25}),
#  'diagnosed': FreqDist({'VBN': 1}),
#  'total': FreqDist({'JJ': 11, 'NN': 9, 'VBP': 2, 'VB': 2}),
#  '18': FreqDist({'CD': 18}),
#  'malignant': FreqDist({'JJ': 1}),
#  'mesothelioma': FreqDist({'NN': 1}),
#  'lung': FreqDist({'NN': 2}),
#  'asbestosis': FreqDist({'NN': 1}),
#  'far': FreqDist({'RB': 28, 'JJ': 3, 'IN': 1}),
#  'higher': FreqDist({'JJR': 47, 'RBR': 2}),
#  '*?*': FreqDist({'-NONE-': 45}),
#  'morbidity': FreqDist({'NN': 1}),
#  'rate': FreqDist({'NN': 41, 'VB': 1}),
#  'striking': FreqDist({'JJ': 2}),
#  'finding': FreqDist({'NN': 4, 'VBG': 2}),
#  'those': FreqDist({'DT': 55}),
#  'us': FreqDist({'PRP': 26}),
#  '*T*-5': FreqDist({'-NONE-': 5}),
#  'study': FreqDist({'NN': 10, 'VB': 2, 'VBP': 1}),
#  'West': FreqDist({'NNP': 10, 'JJ': 2, 'NN': 1}),
#  'Groton': FreqDist({'NNP': 1}),
#  'Mass.': FreqDist({'NNP': 8}),
#  'factory': FreqDist({'NN': 12}),
#  'appears': FreqDist({'VBZ': 8}),
#  'be': FreqDist({'VB': 356}),
#  'highest': FreqDist({'JJS': 8}),
#  'Western': FreqDist({'NNP': 7, 'JJ': 6}),
#  'industrialized': FreqDist({'VBN': 2}),
#  'countries': FreqDist({'NNS': 21}),
#  'he': FreqDist({'PRP': 230}),
#  'plant': FreqDist({'NN': 21}),
#  'which': FreqDist({'WDT': 224, 'IN': 1}),
#  'owned': FreqDist({'VBN': 6}),
#  '*-4': FreqDist({'-NONE-': 34}),
#  'by': FreqDist({'IN': 427, 'RB': 1, 'RP': 1}),
#  'Hollingsworth': FreqDist({'NNP': 2}),
#  '&': FreqDist({'CC': 85, 'SYM': 1}),
#  'Vose': FreqDist({'NNP': 2}),
#  'Co.': FreqDist({'NNP': 74}),
#  'under': FreqDist({'IN': 60}),
#  'contract': FreqDist({'NN': 36, 'VB': 1}),
#  '*ICH*-2': FreqDist({'-NONE-': 34}),
#  'probably': FreqDist({'RB': 14}),
#  'support': FreqDist({'NN': 12, 'VB': 10}),
#  '*T*-6': FreqDist({'-NONE-': 2}),
#  'argue': FreqDist({'VBP': 5, 'VB': 1}),
#  'U.S.': FreqDist({'NNP': 220, 'JJ': 1}),
#  'should': FreqDist({'MD': 38}),
#  'regulate': FreqDist({'VB': 2}),
#  'class': FreqDist({'NN': 8}),
#  'stringently': FreqDist({'RB': 1}),
#  'common': FreqDist({'JJ': 54, 'NN': 3}),
#  'kind': FreqDist({'NN': 12, 'JJ': 2}),
#  'chrysotile': FreqDist({'NN': 2}),
#  'found': FreqDist({'VBD': 13, 'VBN': 10}),
#  'most': FreqDist({'JJS': 42, 'RBS': 33}),
#  'other': FreqDist({'JJ': 134}),
#  'buildings': FreqDist({'NNS': 3}),
#  'one': FreqDist({'CD': 121, 'NN': 9, 'PRP': 2}),
#  'few': FreqDist({'JJ': 33}),
#  'nations': FreqDist({'NNS': 15}),
#  '*T*-7': FreqDist({'-NONE-': 2}),
#  'does': FreqDist({'VBZ': 54}),
#  "n't": FreqDist({'RB': 325}),
#  'standard': FreqDist({'JJ': 5, 'NN': 2}),
#  'regulation': FreqDist({'NN': 3}),
#  'smooth': FreqDist({'JJ': 1}),
#  'needle-like': FreqDist({'JJ': 1}),
#  'fibers': FreqDist({'NNS': 4}),
#  'such': FreqDist({'JJ': 82, 'PDT': 5}),
#  'classified': FreqDist({'VBN': 1}),
#  '*-5': FreqDist({'-NONE-': 11}),
#  'amphobiles': FreqDist({'NNS': 1}),
#  'according': FreqDist({'VBG': 34}),
#  'Brooke': FreqDist({'NNP': 1}),
#  'T.': FreqDist({'NNP': 11}),
#  'Mossman': FreqDist({'NNP': 2}),
#  'professor': FreqDist({'NN': 8}),
#  'pathlogy': FreqDist({'NN': 1}),
#  'Vermont': FreqDist({'NNP': 1}),
#  'College': FreqDist({'NNP': 6}),
#  'More': FreqDist({'JJR': 4, 'RBR': 2}),
#  'curly': FreqDist({'JJ': 1}),
#  'easily': FreqDist({'RB': 6}),
#  'rejected': FreqDist({'VBD': 7, 'VBN': 4}),
#  'body': FreqDist({'NN': 2}),
#  'explained': FreqDist({'VBD': 3}),
#  'In': FreqDist({'IN': 195, 'NNP': 2}),
#  'July': FreqDist({'NNP': 8}),
#  'Environmental': FreqDist({'NNP': 1}),
#  'Protection': FreqDist({'NNP': 1}),
#  'Agency': FreqDist({'NNP': 5}),
#  'imposed': FreqDist({'VBD': 2, 'VBN': 1}),
#  'gradual': FreqDist({'JJ': 1}),
#  'ban': FreqDist({'NN': 10, 'VB': 2}),
#  'virtually': FreqDist({'RB': 6}),
#  'all': FreqDist({'DT': 86, 'PDT': 14, 'RB': 3}),
#  'uses': FreqDist({'NNS': 4, 'VBZ': 4}),
#  'By': FreqDist({'IN': 11}),
#  '1997': FreqDist({'CD': 1}),
#  'almost': FreqDist({'RB': 22}),
#  'remaining': FreqDist({'VBG': 9}),
#  'cancer-causing': FreqDist({'JJ': 1}),
#  'outlawed': FreqDist({'VBN': 1}),
#  '*-6': FreqDist({'-NONE-': 4}),
#  'About': FreqDist({'IN': 6}),
#  '160': FreqDist({'CD': 1}),
#  '*T*-8': FreqDist({'-NONE-': 2}),
#  'made': FreqDist({'VBN': 33, 'VBD': 23}),
#  '*-7': FreqDist({'-NONE-': 4}),
#  'Areas': FreqDist({'NNS': 1}),
#  'particularly': FreqDist({'RB': 17}),
#  'dusty': FreqDist({'JJ': 1}),
#  'where': FreqDist({'WRB': 34}),
#  '*-8': FreqDist({'-NONE-': 2}),
#  'Workers': FreqDist({'NNS': 2}),
#  'dumped': FreqDist({'VBD': 2, 'VBN': 2}),
#  'large': FreqDist({'JJ': 29}),
#  'burlap': FreqDist({'NN': 1}),
#  'sacks': FreqDist({'NNS': 1}),
#  'imported': FreqDist({'VBN': 2, 'VBD': 2}),
#  'material': FreqDist({'NN': 10}),
#  'into': FreqDist({'IN': 87}),
#  'huge': FreqDist({'JJ': 14}),
#  'bin': FreqDist({'NN': 1}),
#  'poured': FreqDist({'VBD': 1}),
#  'cotton': FreqDist({'NN': 1}),
#  'acetate': FreqDist({'NN': 1}),
#  'mechanically': FreqDist({'RB': 1}),
#  'mixed': FreqDist({'VBN': 7, 'VBD': 1}),
#  'dry': FreqDist({'JJ': 4}),
#  'process': FreqDist({'NN': 13}),
#  'described': FreqDist({'VBD': 4, 'VBN': 4}),
#  'clouds': FreqDist({'NNS': 1}),
#  'blue': FreqDist({'JJ': 5}),
#  'dust': FreqDist({'NN': 1}),
#  'hung': FreqDist({'VBD': 1}),
#  'over': FreqDist({'IN': 72, 'RP': 7, 'RB': 2, 'JJ': 1}),
#  'parts': FreqDist({'NNS': 7}),
#  'though': FreqDist({'IN': 25, 'RB': 4}),
#  'exhaust': FreqDist({'NN': 1, 'VBP': 1}),
#  'fans': FreqDist({'NNS': 2}),
#  'ventilated': FreqDist({'VBD': 1}),
#  'area': FreqDist({'NN': 9}),
#  'question': FreqDist({'NN': 12, 'VBP': 1, 'VB': 1}),
#  'some': FreqDist({'DT': 122}),
#  'managers': FreqDist({'NNS': 40}),
#  'contracted': FreqDist({'VBD': 2}),
#  'Darrell': FreqDist({'NNP': 1}),
#  'Phillips': FreqDist({'NNP': 2}),
#  'vice': FreqDist({'NN': 43, 'RB': 1}),
#  'president': FreqDist({'NN': 133}),
#  'human': FreqDist({'JJ': 4}),
#  'resources': FreqDist({'NNS': 5}),
#  'But': FreqDist({'CC': 157, 'IN': 1}),
#  'you': FreqDist({'PRP': 70}),
#  'recognize': FreqDist({'VB': 2, 'VBP': 1}),
#  'these': FreqDist({'DT': 55}),
#  'events': FreqDist({'NNS': 3}),
#  'took': FreqDist({'VBD': 28}),
#  'place': FreqDist({'NN': 17, 'VB': 1, 'VBP': 1}),
#  '35': FreqDist({'CD': 7}),
#  'It': FreqDist({'PRP': 100}),
#  'bearing': FreqDist({'VBG': 2, 'NN': 1}),
#  'work': FreqDist({'NN': 19, 'VB': 7, 'VBP': 1}),
#  'force': FreqDist({'NN': 16, 'VB': 6, 'VBP': 1}),
#  'Yields': FreqDist({'NNS': 1}),
#  'money-market': FreqDist({'JJ': 3}),
#  'mutual': FreqDist({'JJ': 8}),
#  'funds': FreqDist({'NNS': 67}),
#  'continued': FreqDist({'VBD': 8, 'VBN': 6}),
#  'slide': FreqDist({'NN': 4, 'VB': 1}),
#  'amid': FreqDist({'IN': 4}),
#  'signs': FreqDist({'NNS': 8}),
#  'portfolio': FreqDist({'NN': 9}),
#  'expect': FreqDist({'VBP': 6, 'VB': 2}),
#  'further': FreqDist({'JJ': 10, 'RB': 4, 'RBR': 2, 'JJR': 1}),
#  'declines': FreqDist({'NNS': 5, 'VBZ': 2}),
#  'interest': FreqDist({'NN': 53}),
#  'rates': FreqDist({'NNS': 49, 'VBZ': 1}),
#  'average': FreqDist({'JJ': 22, 'NN': 10}),
#  'seven-day': FreqDist({'JJ': 3}),
#  'compound': FreqDist({'NN': 4}),
#  'yield': FreqDist({'VB': 28, 'NN': 20}),
#  '400': FreqDist({'CD': 7}),
#  'taxable': FreqDist({'JJ': 2}),
#  'tracked': FreqDist({'VBN': 1}),
#  'IBC': FreqDist({'NNP': 1}),
#  'Money': FreqDist({'NNP': 3, 'NN': 3}),
#  'Fund': FreqDist({'NNP': 12}),
#  'Report': FreqDist({'NNP': 8}),
#  'eased': FreqDist({'VBD': 3}),
#  'fraction': FreqDist({'NN': 1}),
#  'point': FreqDist({'NN': 26, 'VBP': 2, 'VB': 1}),
#  '8.45': FreqDist({'CD': 2}),
#  '%': FreqDist({'NN': 445, 'JJ': 1}),
#  '8.47': FreqDist({'CD': 2}),
#  'week': FreqDist({'NN': 55}),
#  'ended': FreqDist({'VBD': 21, 'VBN': 3}),
#  'Tuesday': FreqDist({'NNP': 46}),
#  'Compound': FreqDist({'NN': 1}),
#  'yields': FreqDist({'NNS': 7}),
#  'assume': FreqDist({'VBP': 2, 'VB': 2}),
#  'reinvestment': FreqDist({'NN': 1}),
#  'dividends': FreqDist({'NNS': 21}),
#  'current': FreqDist({'JJ': 30, 'NN': 2}),
#  'continues': FreqDist({'VBZ': 13}),
#  'Average': FreqDist({'NNP': 6, 'JJ': 4}),
#  'maturity': FreqDist({'NN': 3}),
#  "'": FreqDist({'POS': 63, "''": 10}),
#  'investments': FreqDist({'NNS': 17}),
#  'lengthened': FreqDist({'VBD': 1}),
#  'day': FreqDist({'NN': 23}),
#  '41': FreqDist({'CD': 4}),
#  'days': FreqDist({'NNS': 51}),
#  'longest': FreqDist({'JJS': 1}),
#  'since': FreqDist({'IN': 50}),
#  'August': FreqDist({'NNP': 18}),
#  'Donoghue': FreqDist({'NNP': 1}),
#  'Longer': FreqDist({'JJR': 1}),
#  'maturities': FreqDist({'NNS': 3}),
#  'thought': FreqDist({'VBD': 5, 'VBN': 2, 'NN': 1}),
#  'indicate': FreqDist({'VB': 2, 'VBP': 1}),
#  'declining': FreqDist({'VBG': 4}),
#  'because': FreqDist({'IN': 116, 'RB': 2}),
#  'they': FreqDist({'PRP': 210}),
#  'permit': FreqDist({'VB': 2, 'VBP': 1}),
#  'retain': FreqDist({'VB': 3}),
#  'relatively': FreqDist({'RB': 11}),
#  'longer': FreqDist({'JJR': 4, 'RBR': 4, 'RB': 1}),
#  'period': FreqDist({'NN': 25}),
#  'Shorter': FreqDist({'JJR': 1}),
#  'considered': FreqDist({'VBN': 9}),
#  '*-9': FreqDist({'-NONE-': 2}),
#  'sign': FreqDist({'NN': 9, 'VB': 3}),
#  'rising': FreqDist({'VBG': 11}),
#  'can': FreqDist({'MD': 93, 'NN': 1}),
#  'capture': FreqDist({'VB': 4}),
#  'sooner': FreqDist({'RB': 1, 'RBR': 1}),
#  'open': FreqDist({'JJ': 7, 'VB': 2}),
#  'only': FreqDist({'RB': 68, 'JJ': 10}),
#  'institutions': FreqDist({'NNS': 18}),
#  'stronger': FreqDist({'JJR': 5}),
#  'indicator': FreqDist({'NN': 4}),
#  'watch': FreqDist({'NN': 4, 'VB': 4, 'VBP': 3}),
#  'market': FreqDist({'NN': 176}),
#  'reached': FreqDist({'VBN': 13, 'VBD': 4}),
#  'Nevertheless': FreqDist({'RB': 2}),
#  'Brenda': FreqDist({'NNP': 1}),
#  'Malizia': FreqDist({'NNP': 1}),
#  'Negus': FreqDist({'NNP': 1}),
#  'editor': FreqDist({'NN': 11}),
#  'may': FreqDist({'MD': 70}),
#  'blip': FreqDist({'VB': 1, 'VBP': 1}),
#  'again': FreqDist({'RB': 14}),
#  'down': FreqDist({'RB': 22, 'IN': 19, 'RP': 14, 'NN': 1}),
#  'recent': FreqDist({'JJ': 72}),
#  'rises': FreqDist({'NNS': 1}),
#  'short-term': FreqDist({'JJ': 14}),
#  'six-month': FreqDist({'JJ': 6}),
#  'Treasury': FreqDist({'NNP': 41}),
#  'bills': FreqDist({'NNS': 19}),
#  'Monday': FreqDist({'NNP': 12}),
#  'auction': FreqDist({'NN': 5}),
#  'example': FreqDist({'NN': 27}),
#  'rose': FreqDist({'VBD': 61}),
#  '8.04': FreqDist({'CD': 2}),
#  '7.90': FreqDist({'CD': 4}),
#  'Despite': FreqDist({'IN': 11}),
#  'investors': FreqDist({'NNS': 63}),
#  'continue': FreqDist({'VB': 13, 'VBP': 7}),
#  'pour': FreqDist({'VB': 1}),
#  'cash': FreqDist({'NN': 43}),
#  'money': FreqDist({'NN': 53}),
#  'Assets': FreqDist({'NNS': 1}),
#  'grew': FreqDist({'VBD': 4}),
#  '$': FreqDist({'$': 718}),
#  '1.5': FreqDist({'CD': 7}),
#  '*U*': FreqDist({'-NONE-': 744}),
#  'during': FreqDist({'IN': 38}),
#  '352.7': FreqDist({'CD': 1}),
#  'Typically': FreqDist({'RB': 2}),
#  'money-fund': FreqDist({'NN': 1}),
#  'beat': FreqDist({'VB': 4, 'VBP': 1, 'VBD': 1}),
#  'comparable': FreqDist({'JJ': 3}),
#  'vary': FreqDist({'VB': 2}),
#  'go': FreqDist({'VB': 18, 'VBP': 4}),
#  'after': FreqDist({'IN': 77, 'RB': 1}),
#  'top': FreqDist({'JJ': 10, 'VB': 1, 'NN': 1}),
#  'currently': FreqDist({'RB': 22}),
#  'yielding': FreqDist({'VBG': 3, 'JJ': 1, 'NN': 1}),
#  'well': FreqDist({'RB': 46}),
#  '9': FreqDist({'CD': 18}),
#  'Dreyfus': FreqDist({'NNP': 1}),
#  'World-Wide': FreqDist({'NNP': 1}),
#  'Dollar': FreqDist({'NNP': 1, 'NN': 1}),
#  'top-yielding': FreqDist({'JJ': 1}),
#  'fund': FreqDist({'NN': 11, 'VB': 2}),
#  'had': FreqDist({'VBD': 160, 'VBN': 5}),
#  '9.37': FreqDist({'CD': 1}),
#  '9.45': FreqDist({'CD': 1}),
#  'earlier': FreqDist({'JJR': 34, 'RBR': 11, 'RB': 3}),
#  'invests': FreqDist({'VBZ': 1}),
#  'heavily': FreqDist({'RB': 7}),
#  'dollar-denominated': FreqDist({'JJ': 3}),
#  'securities': FreqDist({'NNS': 33}),
#  'overseas': FreqDist({'JJ': 7, 'RB': 4}),
#  'waiving': FreqDist({'VBG': 1}),
#  'management': FreqDist({'NN': 22}),
#  'fees': FreqDist({'NNS': 19}),
#  '*T*-9': FreqDist({'-NONE-': 2}),
#  'boosts': FreqDist({'VBZ': 3, 'NNS': 1}),
#  'simple': FreqDist({'JJ': 4}),
#  '8.12': FreqDist({'CD': 1}),
#  '8.14': FreqDist({'CD': 1}),
#  '30-day': FreqDist({'JJ': 8}),
#  'fell': FreqDist({'VBD': 32}),
#  '8.19': FreqDist({'CD': 1}),
#  '8.22': FreqDist({'CD': 1}),
#  ';': FreqDist({':': 171}),
#  'slid': FreqDist({'VBD': 2}),
#  '8.53': FreqDist({'CD': 1}),
#  '8.56': FreqDist({'CD': 1}),
#  'J.P.': FreqDist({'NNP': 1}),
#  'Bolduc': FreqDist({'NNP': 1}),
#  'W.R.': FreqDist({'NNP': 3}),
#  'Grace': FreqDist({'NNP': 4}),
#  '*T*-10': FreqDist({'-NONE-': 2}),
#  'holds': FreqDist({'VBZ': 4}),
#  '83.4': FreqDist({'CD': 1}),
#  'energy-services': FreqDist({'JJ': 1}),
#  'elected': FreqDist({'VBN': 6}),
#  '*-10': FreqDist({'-NONE-': 2}),
#  'He': FreqDist({'PRP': 73}),
#  'succeeds': FreqDist({'VBZ': 2}),
#  'Terrence': FreqDist({'NNP': 1}),
#  'D.': FreqDist({'NNP': 15}),
#  'Daniels': FreqDist({'NNP': 1}),
#  'formerly': FreqDist({'RB': 3}),
#  '*T*-11': FreqDist({'-NONE-': 2}),
#  'resigned': FreqDist({'VBD': 5, 'JJ': 1}),
#  'Energy': FreqDist({'NNP': 6}),
#  'seven': FreqDist({'CD': 9}),
#  'seats': FreqDist({'NNS': 7}),
#  'Pacific': FreqDist({'NNP': 10}),
#  'First': FreqDist({'NNP': 35, 'JJ': 3}),
#  'Financial': FreqDist({'NNP': 14, 'JJ': 2}),
#  'shareholders': FreqDist({'NNS': 20}),
#  'approved': FreqDist({'VBD': 14, 'VBN': 11}),
#  'acquisition': FreqDist({'NN': 15}),
#  'Royal': FreqDist({'NNP': 1}),
#  'Trustco': FreqDist({'NNP': 1}),
#  'Ltd.': FreqDist({'NNP': 19}),
#  'Toronto': FreqDist({'NNP': 5}),
#  '27': FreqDist({'CD': 5}),
#  'share': FreqDist({'NN': 116, 'VB': 3}),
#  'or': FreqDist({'CC': 291}),
#  '212': FreqDist({'CD': 1}),
#  'million': FreqDist({'CD': 383}),
#  'thrift': FreqDist({'NN': 18}),
#  'holding': FreqDist({'VBG': 17, 'NN': 3}),
#  'expects': FreqDist({'VBZ': 19}),
#  'obtain': FreqDist({'VB': 3}),
#  'regulatory': FreqDist({'JJ': 8}),
#  'approval': FreqDist({'NN': 10}),
#  'complete': FreqDist({'VB': 6, 'JJ': 1}),
#  'transaction': FreqDist({'NN': 20}),
#  'year-end': FreqDist({'NN': 2}),
#  'McDermott': FreqDist({'NNP': 1}),
#  'International': FreqDist({'NNP': 33}),
#  'Babcock': FreqDist({'NNP': 1}),
#  'Wilcox': FreqDist({'NNP': 1}),
#  'completed': FreqDist({'VBD': 9, 'VBN': 6}),
#  'sale': FreqDist({'NN': 27}),
#  'Bailey': FreqDist({'NNP': 3}),
#  'Controls': FreqDist({'NNP': 2}),
#  'Operations': FreqDist({'NNP': 1, 'NNPS': 1}),
#  'Finmeccanica': FreqDist({'NNP': 2}),
#  'S.p': FreqDist({'NNP': 1}),
#  '295': FreqDist({'CD': 1}),
#  'Italian': FreqDist({'JJ': 4}),
#  'state-owned': FreqDist({'JJ': 2}),
#  'interests': FreqDist({'NNS': 7}),
#  'mechanical': FreqDist({'JJ': 4}),
#  'engineering': FreqDist({'NN': 8, 'VBG': 1}),
#  'industry': FreqDist({'NN': 41}),
#  'based': FreqDist({'VBN': 31}),
#  'Wickliffe': FreqDist({'NNP': 1}),
#  'Ohio': FreqDist({'NNP': 9}),
#  'computerized': FreqDist({'JJ': 1}),
#  'controls': FreqDist({'NNS': 3, 'VBZ': 1}),
#  'systems': FreqDist({'NNS': 6}),
#  'employs': FreqDist({'VBZ': 3}),
#  '2,700': FreqDist({'CD': 1}),
#  'people': FreqDist({'NNS': 56}),
#  'annual': FreqDist({'JJ': 17}),
#  'revenue': FreqDist({'NN': 11}),
#  '370': FreqDist({'CD': 1}),
#  'federal': FreqDist({'JJ': 51}),
#  'government': FreqDist({'NN': 83}),
#  'suspended': FreqDist({'VBN': 7, 'VBD': 2}),
#  'sales': FreqDist({'NNS': 59}),
#  'savings': FreqDist({'NNS': 10, 'NN': 3}),
#  'bonds': FreqDist({'NNS': 59}),
#  'Congress': FreqDist({'NNP': 46}),
#  'lifted': FreqDist({'VBN': 1, 'VBD': 1}),
#  'ceiling': FreqDist({'NN': 10}),
#  'debt': FreqDist({'NN': 46}),
#  'Until': FreqDist({'IN': 5}),
#  'acts': FreqDist({'VBZ': 2, 'NNS': 1}),
#  'authority': FreqDist({'NN': 12}),
#  'issue': FreqDist({'NN': 54, 'VB': 6}),
#  'obligations': FreqDist({'NNS': 2}),
#  'borrowing': FreqDist({'NN': 3, 'VBG': 1}),
#  'dropped': FreqDist({'VBD': 12, 'VBN': 1}),
#  'midnight': FreqDist({'NN': 2}),
#  '2.80': FreqDist({'CD': 1}),
#  'trillion': FreqDist({'CD': 5}),
#  '2.87': FreqDist({'CD': 2}),
#  'Legislation': FreqDist({'NN': 1}),
#  'lift': FreqDist({'VB': 4}),
#  'ensnarled': FreqDist({'VBN': 1}),
#  '*-11': FreqDist({'-NONE-': 2}),
#  'fight': FreqDist({'NN': 3}),
#  'cutting': FreqDist({'VBG': 5}),
#  'capital-gains': FreqDist({'JJ': 1, 'NNS': 1}),
#  'taxes': FreqDist({'NNS': 4}),
#  'House': FreqDist({'NNP': 55}),
#  'voted': FreqDist({'VBD': 3, 'VBN': 2}),
#  'raise': FreqDist({'VB': 17, 'VBP': 3, 'NN': 1}),
#  '3.1': FreqDist({'CD': 5}),
#  'but': FreqDist({'CC': 150, 'RB': 1}),
#  'Senate': FreqDist({'NNP': 18}),
#  'act': FreqDist({'VB': 6, 'NN': 6}),
#  'until': FreqDist({'IN': 31}),
#  'next': FreqDist({'JJ': 58, 'IN': 9}),
#  'earliest': FreqDist({'JJS': 1}),
#  'default': FreqDist({'NN': 4, 'VB': 1}),
#  'if': FreqDist({'IN': 80, 'JJ': 1}),
#  'then': FreqDist({'RB': 27}),
#  'Clark': FreqDist({'NNP': 1}),
#  'J.': FreqDist({'NNP': 15}),
#  'Vitulli': FreqDist({'NNP': 2}),
#  '*-12': FreqDist({'-NONE-': 2}),
#  'senior': FreqDist({'JJ': 18, 'NN': 2}),
#  '*RNR*-1': FreqDist({'-NONE-': 34}),
#  'general': FreqDist({'JJ': 19, 'NN': 2}),
#  'manager': FreqDist({'NN': 27}),
#  'marketing': FreqDist({'NN': 14, 'VBG': 3}),
#  'arm': FreqDist({'NN': 3}),
#  'Japanese': FreqDist({'JJ': 80, 'NNP': 5, 'NNS': 4, 'NN': 2}),
#  'auto': FreqDist({'NN': 13}),
#  'maker': FreqDist({'NN': 28}),
#  'Mazda': FreqDist({'NNP': 2}),
#  'Motor': FreqDist({'NNP': 7}),
#  'Corp': FreqDist({'NNP': 11}),
#  'position': FreqDist({'NN': 12, 'VB': 1}),
#  'oversee': FreqDist({'VB': 1}),
#  'service': FreqDist({'NN': 24}),
#  'operations': FreqDist({'NNS': 29}),
#  'Previously': FreqDist({'RB': 4}),
#  '43': FreqDist({'CD': 3}),
#  'Chrysler': FreqDist({'NNP': 6}),
#  'division': FreqDist({'NN': 24}),
#  'been': FreqDist({'VBN': 150}),
#  'executive': FreqDist({'NN': 40, 'JJ': 28}),
#  '20': FreqDist({'CD': 25}),
#  'When': FreqDist({'WRB': 21}),
#  'time': FreqDist({'NN': 62, 'VB': 1}),
#  'their': FreqDist({'PRP$': 181}),
#  'biannual': FreqDist({'JJ': 1}),
#  'powwow': FreqDist({'NN': 1}),
#  'nation': FreqDist({'NN': 25}),
#  'manufacturing': FreqDist({'NN': 14, 'VBG': 8}),
#  'titans': FreqDist({'NNS': 1}),
#  'typically': FreqDist({'RB': 3}),
#  'jet': FreqDist({'NN': 2, 'VBP': 1}),
#  'off': FreqDist({'RP': 27, 'IN': 12, 'RB': 4, 'JJ': 2}),
#  'sunny': FreqDist({'JJ': 1}),
#  'confines': FreqDist({'NNS': 1}),
#  'resort': FreqDist({'NN': 2}),
#  'towns': FreqDist({'NNS': 2}),
#  'like': FreqDist({'IN': 44, 'VB': 8, 'VBP': 4, 'JJ': 1}),
#  'Boca': FreqDist({'NNP': 3}),
#  'Raton': FreqDist({'NNP': 2}),
#  'Hot': FreqDist({'NNP': 1, 'JJ': 1}),
#  'Springs': FreqDist({'NNP': 2, 'NNPS': 1}),
#  'Not': FreqDist({'RB': 7}),
#  'Association': FreqDist({'NNP': 21}),
#  'Manufacturers': FreqDist({'NNP': 1, 'NNS': 1, 'NNPS': 1}),
#  'settled': FreqDist({'VBD': 3, 'VBN': 2}),
#  'Hoosier': FreqDist({'NNP': 1}),
#  'capital': FreqDist({'NN': 32}),
#  'Indianapolis': FreqDist({'NNP': 4}),
#  'fall': FreqDist({'NN': 15, 'VB': 6, 'VBP': 3}),
#  'meeting': FreqDist({'NN': 16}),
#  'And': FreqDist({'CC': 44}),
#  'city': FreqDist({'NN': 17}),
#  'decided': FreqDist({'VBD': 13, 'VBN': 3}),
#  'treat': FreqDist({'VB': 4}),
#  'guests': FreqDist({'NNS': 3}),
#  'royalty': FreqDist({'NN': 1}),
#  'rock': FreqDist({'NN': 1}),
#  'stars': FreqDist({'NNS': 2}),
#  'owners': FreqDist({'NNS': 4}),
#  'idea': FreqDist({'NN': 11}),
#  'course': FreqDist({'NN': 11}),
#  ':': FreqDist({':': 142}),
#  'prove': FreqDist({'VB': 8, 'VBP': 1}),
#  '125': FreqDist({'CD': 4}),
#  'corporate': FreqDist({'JJ': 25}),
#  'decision': FreqDist({'NN': 19}),
#  'makers': FreqDist({'NNS': 12}),
#  'buckle': FreqDist({'NN': 1}),
#  'Rust': FreqDist({'NNP': 1}),
#  'Belt': FreqDist({'NNP': 3}),
#  'so': FreqDist({'RB': 55, 'IN': 16}),
#  'rusty': FreqDist({'JJ': 1}),
#  'good': FreqDist({'JJ': 40, 'NN': 2}),
#  'expand': FreqDist({'VB': 5}),
#  'On': FreqDist({'IN': 17}),
#  'receiving': FreqDist({'VBG': 4}),
#  'end': FreqDist({'NN': 23, 'VB': 7}),
#  'message': FreqDist({'NN': 4}),
#  'officials': FreqDist({'NNS': 47}),
#  'giants': FreqDist({'NNS': 2}),
#  'Du': FreqDist({'NNP': 2}),
#  'Pont': FreqDist({'NNP': 2}),
#  'Maytag': FreqDist({'NNP': 1}),
#  'along': FreqDist({'IN': 6}),
#  'lesser': FreqDist({'JJR': 1}),
#  'knowns': FreqDist({'NNS': 1}),
#  'Trojan': FreqDist({'NNP': 1}),
#  'Steel': FreqDist({'NNP': 5}),
#  'Valley': FreqDist({'NNP': 12}),
#  'Queen': FreqDist({'NNP': 1}),
#  'Cheese': FreqDist({'NNP': 1}),
#  'Factory': FreqDist({'NN': 3, 'NNP': 1}),
#  'For': FreqDist({'IN': 36}),
#  'starters': FreqDist({'NNS': 1}),
#  'executives': FreqDist({'NNS': 19}),
#  'joined': FreqDist({'VBD': 4}),
#  'Mayor': FreqDist({'NNP': 2}),
#  'William': FreqDist({'NNP': 23}),
#  'H.': FreqDist({'NNP': 4, 'NN': 1}),
#  'Hudnut': FreqDist({'NNP': 1}),
#  'III': FreqDist({'NNP': 3}),
#  'evening': FreqDist({'NN': 4}),
#  'Symphony': FreqDist({'NNP': 1}),
#  'Orchestra': FreqDist({'NNP': 1}),
#  'guest': FreqDist({'NN': 1}),
#  'pianist-comedian': FreqDist({'NN': 1}),
#  'Victor': FreqDist({'NNP': 2}),
#  'Borge': FreqDist({'NNP': 1}),
#  'Champagne': FreqDist({'NNP': 3, 'NN': 1}),
#  'dessert': FreqDist({'NN': 1}),
#  'followed': FreqDist({'VBD': 6, 'VBN': 6}),
#  'morning': FreqDist({'NN': 4}),
#  'police': FreqDist({'NNS': 3, 'NN': 2}),
#  'escort': FreqDist({'NN': 1}),
#  'busloads': FreqDist({'NNS': 1}),
#  'wives': FreqDist({'NNS': 1}),
#  'raced': FreqDist({'VBD': 1}),
#  'Speedway': FreqDist({'NNP': 1}),
#  'unimpeded': FreqDist({'JJ': 1}),
#  'traffic': FreqDist({'NN': 1}),
#  'red': FreqDist({'JJ': 2, 'NN': 1}),
#  'lights': FreqDist({'NNS': 2}),
#  'governor': FreqDist({'NN': 3}),
#  'could': FreqDist({'MD': 120}),
#  'lieutenant': FreqDist({'NN': 1}),
#  'welcomed': FreqDist({'VBD': 1, 'VBN': 1}),
#  'special': FreqDist({'JJ': 15}),
#  'buffet': FreqDist({'NN': 1, 'VB': 1}),
#  'breakfast': FreqDist({'NN': 1}),
#  'held': FreqDist({'VBN': 18, 'VBD': 3}),
#  'museum': FreqDist({'NN': 2}),
#  'food': FreqDist({'NN': 16}),
#  'drinks': FreqDist({'NNS': 1}),
#  'banned': FreqDist({'VBN': 2, 'VBD': 1}),
#  'everyday': FreqDist({'JJ': 1}),
#  'visitors': FreqDist({'NNS': 2}),
#  'Then': FreqDist({'RB': 7}),
#  'honor': FreqDist({'VB': 3, 'NN': 2}),
#  'speedway': FreqDist({'NN': 1}),
#  'hauled': FreqDist({'VBD': 1}),
#  'out': FreqDist({'RP': 47, 'IN': 28, 'RB': 3}),
#  'four': FreqDist({'CD': 20}),
#  'drivers': FreqDist({'NNS': 3}),
#  'crews': FreqDist({'NNS': 1}),
#  'official': FreqDist({'NN': 17, 'JJ': 3}),
#  '500': FreqDist({'CD': 38}),
#  'announcer': FreqDist({'NN': 5}),
#  '10-lap': FreqDist({'JJ': 1}),
#  'exhibition': FreqDist({'NN': 2}),
#  'race': FreqDist({'NN': 3}),
#  'After': FreqDist({'IN': 10, 'RB': 1}),
#  'Fortune': FreqDist({'NNP': 1}),
#  'drooled': FreqDist({'VBD': 1}),
#  'schoolboys': FreqDist({'NNS': 1}),
#  'cars': FreqDist({'NNS': 19}),
#  'No': FreqDist({'DT': 10, 'RB': 1}),
#  'dummies': FreqDist({'NNS': 1}),
#  'pointed': FreqDist({'VBD': 2, 'VBN': 1}),
#  'still': FreqDist({'RB': 36}),
#  'space': FreqDist({'NN': 9}),
#  'machines': FreqDist({'NNS': 2}),
#  'another': FreqDist({'DT': 42}),
#  'sponsor': FreqDist({'NN': 2}),
#  'name': FreqDist({'NN': 7, 'VB': 1}),
#  'two': FreqDist({'CD': 103}),
#  'Back': FreqDist({'RB': 1}),
#  'downtown': FreqDist({'NN': 2}),
#  'execs': FreqDist({'NNS': 1}),
#  'squeezed': FreqDist({'VBD': 1, 'VBN': 1}),
#  'meetings': FreqDist({'NNS': 6}),
#  'hotel': FreqDist({'NN': 3}),
#  'boarding': FreqDist({'VBG': 1}),
#  'buses': FreqDist({'NNS': 3}),
#  'dinner': FreqDist({'NN': 2}),
#  'dancing': FreqDist({'NN': 1}),
#  'block': FreqDist({'VB': 6, 'NN': 3}),
#  'away': FreqDist({'RB': 13, 'RP': 4}),
#  'Under': FreqDist({'IN': 14}),
#  'moons': FreqDist({'NNS': 1}),
#  'renovated': FreqDist({'VBN': 1}),
#  'Indiana': FreqDist({'NNP': 5}),
#  'Roof': FreqDist({'NNP': 1}),
#  'ballroom': FreqDist({'NN': 1}),
#  'nine': FreqDist({'CD': 12}),
#  'hottest': FreqDist({'JJS': 1}),
#  'chefs': FreqDist({'NNS': 2}),
#  'town': FreqDist({'NN': 3}),
#  'fed': FreqDist({'VBD': 1, 'VBN': 1}),
#  'them': FreqDist({'PRP': 70}),
#  'duckling': FreqDist({'NN': 1}),
#  'mousseline': FreqDist({'NN': 1}),
#  'lobster': FreqDist({'NN': 1}),
#  'consomme': FreqDist({'NN': 1}),
#  'veal': FreqDist({'NN': 1}),
#  'mignon': FreqDist({'NN': 1}),
#  'chocolate': FreqDist({'JJ': 1}),
#  'terrine': FreqDist({'NN': 1}),
#  'raspberry': FreqDist({'NN': 1}),
#  'sauce': FreqDist({'NN': 1}),
#  'Knowing': FreqDist({'VBG': 1}),
#  'tasty': FreqDist({'JJ': 1}),
#  'free': FreqDist({'JJ': 13, 'RB': 1, 'VB': 1}),
#  'meal': FreqDist({'NN': 2}),
#  'when': FreqDist({'WRB': 77}),
#  'eat': FreqDist({'VBP': 1}),
#  'gave': FreqDist({'VBD': 10}),
#  'standing': FreqDist({'NN': 5, 'JJ': 1}),
#  'ovation': FreqDist({'NN': 1}),
#  'CEOs': FreqDist({'NNS': 2}),
#  'say': FreqDist({'VBP': 56, 'VB': 19}),
#  'red-carpet': FreqDist({'JJ': 1}),
#  'treatment': FreqDist({'NN': 9}),
#  'tempts': FreqDist({'VBZ': 1}),
#  'return': FreqDist({'NN': 22, 'VB': 5, 'VBP': 1}),
#  'heartland': FreqDist({'NN': 1}),
#  'future': FreqDist({'JJ': 18, 'NN': 8}),
#  'looking': FreqDist({'VBG': 9}),
#  'forward': FreqDist({'RB': 4}),
#  'winter': FreqDist({'NN': 1}),
#  'February': FreqDist({'NNP': 3}),
#  'South': FreqDist({'NNP': 39, 'JJ': 1}),
#  'Korea': FreqDist({'NNP': 19}),
#  'registered': FreqDist({'VBN': 5, 'VBD': 1}),
#  'trade': FreqDist({'NN': 38, 'VB': 7, 'VBP': 5}),
#  'deficit': FreqDist({'NN': 6}),
#  '101': FreqDist({'CD': 2}),
#  'October': FreqDist({'NNP': 61}),
#  'reflecting': FreqDist({'VBG': 4}),
#  'country': FreqDist({'NN': 46}),
#  'economic': FreqDist({'JJ': 41}),
#  'sluggishness': FreqDist({'NN': 1}),
#  'figures': FreqDist({'NNS': 12}),
#  'released': FreqDist({'VBD': 2, 'VBN': 2}),
#  'Wednesday': FreqDist({'NNP': 16}),
#  'Preliminary': FreqDist({'JJ': 1}),
#  'tallies': FreqDist({'NNS': 1}),
#  'Trade': FreqDist({'NNP': 14}),
#  'Industry': FreqDist({'NNP': 4}),
#  'Ministry': FreqDist({'NNP': 10}),
#  'showed': FreqDist({'VBD': 13}),
#  'fifth': FreqDist({'JJ': 7}),
#  'monthly': FreqDist({'JJ': 7, 'RB': 1}),
#  'setback': FreqDist({'NN': 2}),
#  'casting': FreqDist({'VBG': 2}),
#  'cloud': FreqDist({'NN': 1}),
#  'export-oriented': FreqDist({'JJ': 1}),
#  'economy': FreqDist({'NN': 26}),
#  'Exports': FreqDist({'NNS': 1}),
#  'stood': FreqDist({'VBD': 5}),
#  '5.29': FreqDist({'CD': 1}),
#  'mere': FreqDist({'JJ': 2}),
#  '0.7': FreqDist({'CD': 1}),
#  'increase': FreqDist({'NN': 20, 'VB': 11}),
#  'while': FreqDist({'IN': 47, 'NN': 2}),
#  'imports': FreqDist({'NNS': 12}),
#  'increased': FreqDist({'VBN': 14, 'VBD': 9}),
#  'sharply': FreqDist({'RB': 11}),
#  '5.39': FreqDist({'CD': 1}),
#  'last': FreqDist({'JJ': 86, 'VB': 2, 'RB': 1, 'NN': 1}),
#  'boom': FreqDist({'NN': 2}),
#  '*T*-12': FreqDist({'-NONE-': 2}),
#  'began': FreqDist({'VBD': 32}),
#  '1986': FreqDist({'CD': 10}),
#  'prolonged': FreqDist({'VBN': 2}),
#  'labor': FreqDist({'NN': 5}),
#  'disputes': FreqDist({'NNS': 3}),
#  'conflicts': FreqDist({'NNS': 2}),
#  'sluggish': FreqDist({'JJ': 8}),
#  'exports': FreqDist({'NNS': 11}),
#  'Government': FreqDist({'NN': 2, 'NNP': 2}),
#  'would': FreqDist({'MD': 209}),
#  'remain': FreqDist({'VB': 12}),
#  'target': FreqDist({'NN': 8, 'VB': 2}),
#  '68': FreqDist({'CD': 2}),
#  'gloomy': FreqDist({'JJ': 1}),
#  'forecast': FreqDist({'NN': 4, 'VBP': 1, 'VBD': 1, 'VBN': 1}),
#  'recorded': FreqDist({'VBN': 1, 'VBD': 1}),
#  'surplus': FreqDist({'NN': 2}),
#  '71': FreqDist({'CD': 3}),
#  'January': FreqDist({'NNP': 12}),
#  'accumulated': FreqDist({'VBN': 1}),
#  '4': FreqDist({'CD': 15, 'LS': 1}),
#  'same': FreqDist({'JJ': 37}),
#  '50.45': FreqDist({'CD': 1}),
#  'Imports': FreqDist({'NNS': 3}),
#  '50.38': FreqDist({'CD': 1}),
#  '19': FreqDist({'CD': 8}),
#  'Newsweek': FreqDist({'NNP': 10}),
#  'trying': FreqDist({'VBG': 22}),
#  'keep': FreqDist({'VB': 15, 'VBP': 1}),
#  'pace': FreqDist({'NN': 6}),
#  'rival': FreqDist({'NN': 4, 'JJ': 1}),
#  'Time': FreqDist({'NNP': 8}),
#  'magazine': FreqDist({'NN': 23}),
#  'announced': FreqDist({'VBD': 14, 'VBN': 3}),
#  'advertising': FreqDist({'NN': 10, 'VBG': 3}),
#  '1990': FreqDist({'CD': 43}),
#  'introduce': FreqDist({'VB': 7}),
#  'incentive': FreqDist({'NN': 4}),
#  'plan': FreqDist({'NN': 45, 'VBP': 2, 'VB': 1}),
#  'advertisers': FreqDist({'NNS': 13}),
#  'ad': FreqDist({'NN': 28}),
#  'Washington': FreqDist({'NNP': 23}),
#  'Post': FreqDist({'NNP': 1}),
#  'second': FreqDist({'JJ': 14}),
#  'offered': FreqDist({'VBD': 16, 'VBN': 10}),
#  'Plans': FreqDist({'NNS': 2}),
#  '*T*-13': FreqDist({'-NONE-': 2}),
#  'give': FreqDist({'VB': 15, 'VBP': 6}),
#  'discounts': FreqDist({'NNS': 1}),
#  'maintaining': FreqDist({'VBG': 4}),
#  'increasing': FreqDist({'VBG': 18}),
#  'spending': FreqDist({'NN': 24, 'VBG': 2}),
#  'become': FreqDist({'VB': 15, 'VBN': 7, 'VBP': 1}),
#  'permanent': FreqDist({'JJ': 2}),
#  'fixtures': FreqDist({'NNS': 1}),
#  'news': FreqDist({'NN': 24}),
#  'weeklies': FreqDist({'NNS': 2}),
#  'underscore': FreqDist({'VBP': 1}),
#  'fierce': FreqDist({'JJ': 2}),
#  'competition': FreqDist({'NN': 10}),
#  'between': FreqDist({'IN': 36}),
#  'Warner': FreqDist({'NNP': 3}),
#  'Mortimer': FreqDist({'NNP': 1}),
#  'B.': FreqDist({'NNP': 7}),
#  'Zuckerman': FreqDist({'NNP': 1}),
#  'News': FreqDist({'NNP': 6}),
#  'World': FreqDist({'NNP': 13, 'NN': 2}),
#  'Alan': FreqDist({'NNP': 3}),
#  'Spoon': FreqDist({'NNP': 3}),
#  '5': FreqDist({'CD': 18, 'LS': 1}),
#  ...}

# %%
cfd2 = nltk.ConditionalFreqDist((tag,word) for (word,tag) in wsj)
cfd2['VB'].keys()
# Out:
# dict_keys(['join', 'make', 'bring', 'be', 'support', 'regulate', 'have', 'recognize', 'slide', 'indicate', 'retain', 'capture', 'blip', 'pour', 'vary', 'go', 'obtain', 'complete', 'issue', 'lift', 'raise', 'act', 'default', 'oversee', 'treat', 'prove', 'expand', 'return', 'remain', 'keep', 'introduce', 'increase', 'cost', 'announce', 'reward', 'shore', 'justify', 'acquire', 'suffer', 'come', 'take', 'withdraw', 'speed', 'refile', 'refund', 'begin', 'entertain', 'block', 'force', 'slash', 'pay', 'audit', 'set', 'rule', 'manufacture', 'help', 'meet', 'produce', 'depend', 'want', 'fund', 'include', 'jump', 'close', 'link', 'complicate', 'do', 'require', 'contain', 'face', 'roll', 'compete', 'receive', 'occur', 'leave', 'decide', 'trade', 'report', 'work', 'continue', 'succeed', 'honor', 'improve', 'pursue', 'aid', 'protect', 'compel', 'enact', 'apply', 'pose', 'craft', 'merit', 'ask', 'halve', 'reach', 'use', 'store', 'share', 'offer', 'start', 'divest', 'grant', 'watch', 'turn', 'direct', 'reduce', 'curb', 'seek', 'resume', 'cut', 'eliminate', 'redeploy', 'extend', 'file', 'expire', 'Pick', 'stake', 'find', 'sell', 'diversify', 'hold', 'get', 'whipsaw', 'swing', 'see', 'buy', 'clear', 'say', 'happen', 'open', 'settle', 'rise', 'remove', 'taper', 'revive', 'pick', 'slip', 'provoke', 'lead', 'last', 'boost', 'change', 'handle', 'suspect', 'put', 'read', 'belong', 'call', 'abide', 'wear', 'stand', 'talk', 'invent', 'ban', 'build', 'draw', 'back', 'win', 'name', 'compensate', 'modify', 'elaborate', 'cure', 'tuck', 'load', 'resonate', 'glamorize', 'seem', 'deserve', 'recommend', 'celebrate', 'die', 'hit', 'attack', 'worry', 'Take', 'wait', 'prosecute', 'exist', 'Compare', 'choose', 'fail', 'know', 'give', 'launch', 'shake', "C'mon", 'pass', 'devote', 'Remember', 'Consider', 'provide', 'spur', 'move', 'accommodate', 'offend', 'parallel', 'assemble', 'export', 'pull', 'consider', 'discuss', 'play', 'step', 'ease', 'try', 'slow', 'monopolize', 'sew', 'believe', 'display', 'underline', 'breach', 'teach', 'cheat', 'enforce', 'bolster', 'beat', 'concentrate', 'mean', 'look', 'clean', 'restore', 'encourage', 'become', 'pair', 'prepare', 'polish', 'earn', 'demand', 'prevent', 'avoid', 'save', 'testify', 'explain', 'add', 'defeat', 'gauge', 'rate', 'replicate', 'deny', 'discontinue', 'stop', 'involve', 'implant', 'oppose', 'recruit', 'fill', 'serve', 'defuse', 'head', 'discourage', 'result', 'regenerate', 'allow', 'permit', 'merge', 'approve', 'uptick', 'favor', 'achieve', 'resolve', 'post', 'wish', 'red-flag', 'tip', 'spark', 'deal', 'submit', 'end', 'develop', 'test', 'harass', 'punish', 'comment', 'bar', 'violate', 'discredit', 'review', 'impose', 'manipulate', 'specialize', 'like', 'apologize', 'hurt', 'design', 'map', 'plan', 'emerge', 'total', 'cover', 'switch', 'phase', 'fabricate', 'speculate', 'underpin', 'erode', 'lock', 'sign', 'risk', 'persuade', 'negotiate', 'drop', 'renew', 'survive', 'identify', 'advertise', 'spend', 'care', 'sleep', 'supply', 'ward', 'top', 'entrench', 'confuse', 'stem', 'place', 'equip', 'promote', 'address', 'withstand', 'single', 'boast', 'crack', 'steal', 'command', 'check', 'push', 'decline', 'tilt', 'think', 'exercise', 'reject', 'expect', 'cause', 'redeem', 'consist', 'mature', 'aim', 'book', 'contract', 'study', 'own', 'finance', 'answer', 'respond', 'gain', 'license', 'combat', 'color', 'pressure', 'highlight', 'clarify', 'agree', 'trust', 'penetrate', 'touch', 'catch', 'generate', 'double', 'lure', 'qualify', 'charge', 'computerize', 'target', 'analyze', 'define', 'spread', 'flourish', 'split', 'realize', 'amend', 'delete', 'resubmit', 'Buy', 'Send', 'Make', 'experience', 'mention', 'Think', 'send', 'institute', 'execute', 'lessen', 'shut', 'let', 'carry', 'offset', 'chat', 'herald', 'ring', 'scrape', 'train', 'diminish', 'time', 'advance', 'retard', 'swap', 'sit', 'attend', 'reopen', 'speak', 'publish', 'live', 'attract', 'faint', 'bless', 'breathe', 'signal', 'run', 'declare', 'measure', 'deliver', ...

# %%
[w for w in cfd1.conditions() if 'VB' in cfd1[w] and 'VBN' in cfd1[w]]
# Out:
# ['become',
#  'come',
#  'set',
#  'own',
#  'cut',
#  'put',
#  'read',
#  'run',
#  'hit',
#  'split',
#  'hurt',
#  'offset',
#  'spread',
#  'shut',
#  'Put',
#  'overcome']

# %%
idx1 = wsj.index(('become','VB'))
idx1
# Out:
# 18689

# %%
wsj[idx1-4:idx1+1]
# Out:
# [('is', 'VBZ'),
#  ('studying', 'VBG'),
#  ('*-1', '-NONE-'),
#  ('to', 'TO'),
#  ('become', 'VB')]
