# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %% [markdown]
# concorance shows us every occurence of a given word, together with some context. You can see size and pictures from the context demonstrating its context. what other words have similar contexts?

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %% [markdown]
# Common contexts allow us to examine just the contexts that are shared between two or more words.

# %%
text2.common_contexts(["monstrous","very"])
# Out:
# am_glad a_pretty a_lucky is_pretty be_glad

# %% [markdown]
# disperson plots;
#
# We can represent the location of a word in the text, how many words from the beginning it appears

# %%
text4.dispersion_plot(["citizens","democracy","freedom","duties","America"])

# %%
text3.generate()
# Out:
# Building ngram index...
# laid by her , and said unto Cain , Where art thou , and said , Go to ,
# I will not do it for ten ' s sons ; we dreamed each man according to
# their generatio the firstborn said unto Laban , Because I said , Nay ,
# but Sarah shall her name be . , duke Elah , duke Shobal , and Akan .
# and looked upon my affliction . Bashemath Ishmael ' s blood , but Isra
# for as a prince hast thou found of all the cattle in the valley , and
# the wo The
# "laid by her , and said unto Cain , Where art thou , and said , Go to ,\nI will not do it for ten ' s sons ; we dreamed each man according to\ntheir generatio the firstborn said unto Laban , Because I said , Nay ,\nbut Sarah shall her name be . , duke Elah , duke Shobal , and Akan .\nand looked upon my affliction . Bashemath Ishmael ' s blood , but Isra\nfor as a prince hast thou found of all the cattle in the valley , and\nthe wo The"

# %%
text5.generate()
# Out:
# Building ngram index...
# he 's a good one is pathetic , just finish yout whereabouts no I had
# no choice but to let the kid out ! , me , hate to tell us she was
# innocent promise ? PART at least 3 girls per day please come on then
# you mean lucifer hi U120 PART :P hi U7 LOl U62 ... PART im so addicted
# to her beuty touch U101 , I forgot how many LIX DOES it take for a
# quarrel , turn your back itches and you pull out a case up rum soaked
# pineapples * this morning PART PART
# "he 's a good one is pathetic , just finish yout whereabouts no I had\nno choice but to let the kid out ! , me , hate to tell us she was\ninnocent promise ? PART at least 3 girls per day please come on then\nyou mean lucifer hi U120 PART :P hi U7 LOl U62 ... PART im so addicted\nto her beuty touch U101 , I forgot how many LIX DOES it take for a\nquarrel , turn your back itches and you pull out a case up rum soaked\npineapples * this morning PART PART"

# %%
len(text3)
# Out:
# 44764

# %% [markdown]
# a token is the technical name for a sequence of characters such as hairy, his or ':)'

# %% [markdown]
# measure the lexical richness of a text

# %%
len(text3)/len(set(text3))
# Out:
# 16.050197203298673

# %%
text3.count('smote')
# Out:
# 5

# %%
100*text4.count('a')/len(text4)
# Out:
# 1.457806031353621

# %%
def lexical_diversity(text):
    return len(text)/len(set(text))

def percentage(count,total):
    return 100*count/total

# %%
sent1 = ['Call','me','Ishmael','.']

lexical_diversity(sent1)
# Out:
# 1.0

# %%
sent2 = ['the','family','of','Dashwood','had','long','been','settled','in','the','city','of','Sussex','.']

lexical_diversity(sent2)
# Out:
# 1.1666666666666667

# %% [markdown]
# The `FreqDist()` function tells the frequency of each vocabulary item in the text. It tells how the total number of word tokens in the text are distributed across the vocab items.

# %%
fdist1 = FreqDist(text1)
fdist1
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
fdist1.keys()
# Out:
# dict_keys(['[', 'Moby', 'Dick', 'by', 'Herman', 'Melville', '1851', ']', 'ETYMOLOGY', '.', '(', 'Supplied', 'a', 'Late', 'Consumptive', 'Usher', 'to', 'Grammar', 'School', ')', 'The', 'pale', '--', 'threadbare', 'in', 'coat', ',', 'heart', 'body', 'and', 'brain', ';', 'I', 'see', 'him', 'now', 'He', 'was', 'ever', 'dusting', 'his', 'old', 'lexicons', 'grammars', 'with', 'queer', 'handkerchief', 'mockingly', 'embellished', 'all', 'the', 'gay', 'flags', 'of', 'known', 'nations', 'world', 'loved', 'dust', 'it', 'somehow', 'mildly', 'reminded', 'mortality', '"', 'While', 'you', 'take', 'hand', 'school', 'others', 'teach', 'them', 'what', 'name', 'whale', '-', 'fish', 'is', 'be', 'called', 'our', 'tongue', 'leaving', 'out', 'through', 'ignorance', 'letter', 'H', 'which', 'almost', 'alone', 'maketh', 'signification', 'word', 'deliver', 'that', 'not', 'true', '."', 'HACKLUYT', 'WHALE', '...', 'Sw', 'Dan', 'HVAL', 'This', 'animal', 'named', 'from', 'roundness', 'or', 'rolling', 'for', 'HVALT
# ...

# %%
fdist1.plot(50,cumulative=True)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Cumulative Counts'>

# %%
#
#words that appear only once
fdist1.hapaxes()
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %%
#here are all the words from the chat corpus that are longer than 7 characters and occur more than 7 times

fdist5 = FreqDist(text5)
sorted([w for w in set(text5) if len(w)>7 and fdist5[w]>7])
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %%
#A collocation is a sequence of words that occur together usually often.
text4.collocations()
# Out:
# United States; fellow citizens; years ago; four years; Federal
# Government; General Government; American people; Vice President; God
# bless; Chief Justice; one another; fellow Americans; Old World;
# Almighty God; Fellow citizens; Chief Magistrate; every citizen; Indian
# tribes; public debt; foreign nations

# %%
bigrams(['more','is','said','than','done'])
# Out:
# <generator object bigrams at 0x7feddf6c53c0>

# %%
fdist = FreqDist([len(w) for w in text1])
fdist.keys()
# Out:
# dict_keys([1, 4, 2, 6, 8, 9, 11, 5, 7, 3, 10, 12, 13, 14, 16, 15, 17, 18, 20])

# %%
fdist.items()
# Out:
# dict_items([(1, 47933), (4, 42345), (2, 38513), (6, 17111), (8, 9966), (9, 6428), (11, 1873), (5, 26597), (7, 14399), (3, 50223), (10, 3528), (12, 1053), (13, 567), (14, 177), (16, 22), (15, 70), (17, 12), (18, 1), (20, 1)])

# %%
fdist[3]
# Out:
# 50223

# %%
sorted([w for w in set(text1) if w.endswith('ableness')])
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
sorted([term for term in set(text4) if 'gnt' in term])
# Out:
# ['Sovereignty', 'sovereignties', 'sovereignty']

# %%
sorted([item for item in set(text6) if item.istitle()])
# Out:
# ['A',
#  'Aaaaaaaaah',
#  'Aaaaaaaah',
#  'Aaaaaah',
#  'Aaaah',
#  'Aaaaugh',
#  'Aaagh',
#  'Aaah',
#  'Aaauggh',
#  'Aaaugh',
#  'Aaauugh',
#  'Aagh',
#  'Aah',
#  'Aauuggghhh',
#  'Aauuugh',
#  'Aauuuuugh',
#  'Aauuuves',
#  'Action',
#  'Actually',
#  'African',
#  'Ages',
#  'Aggh',
#  'Agh',
#  'Ah',
#  'Ahh',
#  'Alice',
#  'All',
#  'Allo',
#  'Almighty',
#  'Alright',
#  'Am',
#  'Amen',
#  'An',
#  'Anarcho',
#  'And',
#  'Angnor',
#  'Anthrax',
#  'Antioch',
#  'Anybody',
#  'Anyway',
#  'Apples',
#  'Aramaic',
#  'Are',
#  'Arimathea',
#  'Armaments',
#  'Arthur',
#  'As',
#  'Ask',
#  'Assyria',
#  'At',
#  'Attila',
#  'Augh',
#  'Autumn',
#  'Auuuuuuuugh',
#  'Away',
#  'Ay',
#  'Ayy',
#  'B',
#  'Back',
#  'Bad',
#  'Badon',
#  'Battle',
#  'Be',
#  'Beast',
#  'Bedevere',
#  'Bedwere',
#  'Behold',
#  'Between',
#  'Beyond',
#  'Black',
#  'Bloody',
#  'Blue',
#  'Bon',
#  'Bones',
#  'Book',
#  'Bors',
#  'Brave',
#  'Bravely',
#  'Bravest',
#  'Bread',
# ...

# %% [markdown]
# # problems with NLP
#
# word sense disambiguation: we want to work out which sense of a word was intended in a given context. Consider the ambiguouus words
#
# Serve: help with food/drink, hold an office, put a ball into play
#
# dish: plate, course of a meal, communications device
#
# the sentence; he served the dish - you can detect meaning through the context and how the words relate
#
#
# #pronoun resolution
#
# #another kind of language understanding is : who did what to whom; detecting subjects and objects of verbs
#
# #consider the following sentence and try to determine what was sold, caught and found
#
# a. the thieves stole the paintings. they were subsequently sold.
#
# b. the thieves sold the paintings. They we subsequently caught.
#
# C. the thieves sold the paintings. They were subsequently found.
#
#
# answering what was sold caught and found involves finding the
#
# * antecendent: pronoun they computation techniqiues for tackling this problem include
# * anaphora resolution - identifying what a pronoun or noun phrase refers to and
# * semantic role labeling - identifying how a noun phrae relates to the verb (as agent, patient, intrument etc)
#
#
#
# # Recognizing Textual Entailment (RTE)
#
# Consider an example;
#
# Text: "David Golinkin is the editor or author of 18 books and over 150 responsa, articles, sermons and books."
#
# Hypothesis: Golinkin has written 18 books.
#
# In order to determine whether the hypothesis is supported by the text, the system needs the following background knowledge;
#
# i. If someone is an author of a book, then they have written that book
#
# ii. If someone is an editor of a book, then they have not written all of that book
#
# iii. If someone is the editor or author of 18 book, then one cannot conclude that they are the author of 18 books.
#
#
# The general idea is to form a hypothesis and use text to validate the hypothesis.

# %% [markdown]
# # Problem 4

# %%
print(len(text2))
# Out:
# 141576

# %%
print(len(set(text2)))
# Out:
# 6833

# %% [markdown]
# # Problem 12
#
# Consider the following expressions - which is more relevant in NLP? Why?
#
# a. `"Monty Python"[6:12]`
# b. `["Monty","Python"][1]`
#
# Expression b: this is because this expression extracts a specific token that can be used in boolean systems to identify if the token is present or not. Expression a does not seperate the text into it's token components.

# %% [markdown]
# # Problem 15

# %%
sorted([w for w in set(text5) if 'b' in w])
# Out:
# ['*blush*',
#  '//www.wunderground.com/cgi-bin/findweather/getForecast?query=95953#FIR',
#  ':beer:',
#  ':blush:',
#  'Aberdeen',
#  'About',
#  'Albany',
#  'Barbieee',
#  'Bible',
#  'Considerably',
#  'Cyber',
#  'Fairbanks',
#  'G-Mobile',
#  'Jonesboro',
#  'Maybe',
#  'Nickelback',
#  'Observed',
#  'Obviously',
#  'October',
#  'Remember',
#  'Reub',
#  'Rothlisburger',
#  'Salisbury',
#  'T-Mobile',
#  'UnScramble',
#  'Unboring',
#  'Wb',
#  'Web',
#  'Wellbutrin',
#  'Whereabouts',
#  'Zebrahead',
#  'Zyban',
#  'aberdeen',
#  'abide',
#  'able',
#  'abortions',
#  'abou',
#  'abourted',
#  'about',
#  'above',
#  'abs',
#  'agaibn',
#  'agurlwithbigguns',
#  'albert',
#  'anybody',
#  'azerbaijan',
#  'b',
#  'b-day',
#  'b/c',
#  'b4',
#  'babay',
#  'babble',
#  'babblein',
#  'babe',
#  'babes',
#  'babi',
#  'babies',
#  'babiess',
#  'baby',
#  'babycakeses',
#  'bachelorette',
#  'back',
#  'backatchya',
#  'backfrontsidewaysandallaroundtheworld',
#  'backroom',
# ...

# %% [markdown]
# # Problem 17

# %%
text9.index('sunset')
# Out:
# 629

# %%
text9[629]
# Out:
# 'sunset'

# %%
for i in range(1,20,2):
    s = ' '.join(text9[text9.index('sunset')-i:text9.index('sunset')+i])
    print(i,' ',s)
    print('\n')
# Out:
# 1   the sunset
#
#
# 3   lay on the sunset side of
#
#
# 5   Saffron Park lay on the sunset side of London ,
#
#
# 7   suburb of Saffron Park lay on the sunset side of London , as red
#
#
# 9   PARK THE suburb of Saffron Park lay on the sunset side of London , as red and ragged
#
#
# 11   OF SAFFRON PARK THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a
#
#
# 13   TWO POETS OF SAFFRON PARK THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of
#
#
# 15   I THE TWO POETS OF SAFFRON PARK THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .
#
#
# 17   . CHAPTER I THE TWO POETS OF SAFFRON PARK THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset . It was
#
#
# ...

# %% [markdown]
# # Problem 19

# %%
one = sorted(set([w.lower() for w in text1]))
print(len(one))
# Out:
# 17231

# %%
two = sorted([w.lower() for w in set(text1)])
print(len(two))
# Out:
# 19317

# %%
set(one).difference(set(two))
# Out:
# set()

# %%
def func(text):
    one = sorted(set([w.lower() for w in text]))
    print(len(one))
    
    two = sorted([w.lower() for w in set(text)])
    print(len(two))

# %%
func(text1)
# Out:
# 17231
# 19317

# %%
func(text2)
# Out:
# 6403
# 6833

# %%
func(text3)
# Out:
# 2628
# 2789

# %%
'!'.lower()
# Out:
# '!'
