# %% [markdown]
# # Problem 3
#
# ## Processing Raw Text
#
#
# Chapter Goals;
#
# 1. How can we write programs to access text from local files and from the web in order to get ahold of an unlimited range of language material?
#
# 2. How can we split documents up into individual words and punctuation symbols so we can carry out the same kinds of analysis we did with text corpora in earlier chapters?
#
# 3. How can we write programs to produce formatted output and save it in a file?

# %% [markdown]
# # electronic book access

# %%
from urllib.request import urlopen

url = "http://www.gutenberg.org/files/2554/2554-0.txt"
raw = urlopen(url).read()

print(type(raw))
print(len(raw))
raw[:75]

# %%
import nltk

tokens = nltk.word_tokenize(str(raw))
print(type(tokens))
print(len(tokens))
tokens[:10]
# Out:
# <class 'list'>
# 225147
# ["b'\\xef\\xbb\\xbfThe",
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'Crime',
#  'and',
#  'Punishment',
#  ',',
#  'by']

# %%
text = nltk.Text(tokens)
print(type(text),'\n')
print(text[1020:1060],'\n')
print(text.collocations())
# Out:
# <class 'nltk.text.Text'>
#
# ['The', 'landlady', 'who', 'provided', 'him', 'with', 'garret', ',', '\\r\\ndinners', ',', 'and', 'attendance', ',', 'lived', 'on', 'the', 'floor', 'below', ',', 'and', 'every', 'time\\r\\nhe', 'went', 'out', 'he', 'was', 'obliged', 'to', 'pass', 'her', 'kitchen', ',', 'the', 'door', 'of', 'which\\r\\ninvariably', 'stood', 'open', '.', 'And']
#
# Katerina Ivanovna; Pyotr Petrovitch; Avdotya Romanovna; Pulcheria
# Alexandrovna; Rodion Romanovitch; Marfa Petrovna; \xe2\x80\x9d cried;
# Sofya Semyonovna; \xe2\x80\x9d said; old woman; \xe2\x80\x9d
# Raskolnikov; Porfiry Petrovitch; Project Gutenberg-tm;
# don\xe2\x80\x99t know; great deal; Amalia Ivanovna; young man; Project
# Gutenberg; Hay Market; police station
# None

# %%
#find
str(raw).find("PART I")
# Out:
# 6105

# %%
#reverse find
str(raw).rfind("all those dark mysterious rumours")
# Out:
# 1157681

# %%
str(raw)[1157681:1157681+50]
# Out:
# 'all those dark mysterious rumours that were\\r\\ncur'

# %%
from urllib.request import urlopen

url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
html = urlopen(url).read()
html[:60]
# Out:
# b'<!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN'

# %%
import requests
from bs4 import BeautifulSoup
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
response = requests.get(url)
html_content = response.content

soup = BeautifulSoup(html_content,'html.parser')
text = soup.get_text()
tokens = nltk.word_tokenize(text)
tokens[:20]
# Out:
# ['BBC',
#  'NEWS',
#  '|',
#  'Health',
#  '|',
#  'Blondes',
#  "'to",
#  'die',
#  'out',
#  'in',
#  '200',
#  "years'",
#  'CATEGORIES',
#  'TV',
#  'RADIO',
#  'COMMUNICATE',
#  'WHERE',
#  'I',
#  'LIVE',
#  'INDEX']

# %%
# !pip install BeautifulSoup4

# %%
tokens = tokens[96:399]
text = nltk.Text(tokens)
text.concordance('gene')
# Out:
# Displaying 5 of 5 matches:
# hey say too few people now carry the gene for blondes to last beyond the next
# blonde hair is caused by a recessive gene . In order for a child to have blond
#  have blonde hair , it must have the gene on both sides of the family in the g
# ere is a disadvantage of having that gene or by chance . They do n't disappear
# des would disappear is if having the gene was a disadvantage and I do not thin

# %%
import feedparser
llog = feedparser.parse("http://languagelog.ldc.upenn.edu/nll/?feed=atom")
llog['feed']['title']
# Out:
# 'Language Log'

# %%
len(llog.entries)
# Out:
# 13

# %%
post = llog.entries[2]
post
# Out:
# {'authors': [{'name': 'Victor Mair',
#    'href': 'https://ealc.sas.upenn.edu/people/victor-h-mair'}],
#  'author_detail': {'name': 'Victor Mair',
#   'href': 'https://ealc.sas.upenn.edu/people/victor-h-mair'},
#  'href': 'https://ealc.sas.upenn.edu/people/victor-h-mair',
#  'author': 'Victor Mair',
#  'title': 'CCP scamming with a Taiwanese-like accent',
#  'title_detail': {'type': 'text/html',
#   'language': 'en-US',
#   'base': 'https://languagelog.ldc.upenn.edu/nll/?feed=atom',
#   'value': 'CCP scamming with a Taiwanese-like accent'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://languagelog.ldc.upenn.edu/nll/?p=58702&utm_source=rss&utm_medium=rss&utm_campaign=ccp-scamming-with-a-taiwanese-like-accent'},
#   {'rel': 'replies',
#    'type': 'text/html',
#    'href': 'https://languagelog.ldc.upenn.edu/nll/?p=58702&utm_source=rss&utm_medium=rss&utm_campaign=ccp-scamming-with-a-taiwanese-like-accent#comments',
#    'count': '2',
# ...

# %%
post.title
# Out:
# 'Clean Up After Your Dog'

# %%
content= post.content[0].value
content[:70]
# Out:
# '<p>Sign in Hong Kong:</p>\n<p align="center"><a href="http://languagelo'

# %%
from bs4 import BeautifulSoup
nltk.word_tokenize(BeautifulSoup(content,'html.parser').get_text())
# Out:
# ['Sign',
#  'in',
#  'Hong',
#  'Kong',
#  ':',
#  'fàng',
#  'gǒu',
#  'hòu',
#  'qǐng',
#  'lìjí',
#  'qīnglǐ',
#  '放狗後請立即清理',
#  "''",
#  'Please',
#  'clean',
#  'up',
#  'immediately',
#  'after',
#  'letting',
#  'your',
#  'dog',
#  'out',
#  "''",
#  'This',
#  'is',
#  'a',
#  'case',
#  'where',
#  'the',
#  'English',
#  'and',
#  'the',
#  'Chinese',
#  'both',
#  'make',
#  'sense',
#  ',',
#  'and',
#  'the',
#  'one',
#  'is',
#  'a',
#  'rough',
#  'approximation',
#  'of',
#  'the',
#  'other',
#  ',',
#  'but',
#  'the',
#  'English',
#  'is',
#  'not',
#  'an',
#  'exact',
#  'translation',
#  'of',
#  'the',
#  'Chinese',
#  '.',
#  'Selected',
#  'readings',
#  "''",
#  'Scoop',
#  'the',
#  'poop',
#  "''",
#  '(',
#  '4/15/15',
#  ')',
#  "''",
#  'No',
#  'shitting',
#  'here',
#  "''",
#  '(',
#  '9/10/15',
#  ')',
#  "''",
#  'Mandarin',
#  'morphosyllabic',
#  'annotation',
#  'of',
#  'a',
#  'Taiwanese',
#  'sign',
#  "''",
#  '(',
#  '5/13/19',
#  ')',
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
response = requests.get(url)
html_content = response.content

soup = BeautifulSoup(html_content,'html.parser')
text = soup.get_text()
tokens = nltk.wordpunct_tokenize(text)
text = nltk.Text(tokens)
words = [w.lower() for w in text if w.lower().isalpha()]
vocab = sorted(set(words))
vocab
# Out:
# ['a',
#  'about',
#  'aid',
#  'alert',
#  'also',
#  'alzheimer',
#  'an',
#  'and',
#  'ann',
#  'apr',
#  'are',
#  'as',
#  'at',
#  'attractive',
#  'babies',
#  'back',
#  'ban',
#  'bbc',
#  'be',
#  'become',
#  'bed',
#  'believe',
#  'below',
#  'beyond',
#  'big',
#  'blame',
#  'block',
#  'blonde',
#  'blondes',
#  'blood',
#  'born',
#  'both',
#  'bottle',
#  'brain',
#  'business',
#  'but',
#  'by',
#  'called',
#  'campaign',
#  'cancer',
#  'care',
#  'carry',
#  'case',
#  'categories',
#  'caused',
#  'centuries',
#  'challenge',
#  'chance',
#  'change',
#  'child',
#  'choose',
#  'climbdown',
#  'co',
#  'communicate',
#  'completely',
#  'confirmed',
#  'congo',
#  'content',
#  'counter',
#  'country',
#  'cuts',
#  'd',
#  'daily',
#  'damages',
#  'deadly',
#  'defeat',
#  'defect',
#  'delay',
#  'demise',
#  'depth',
#  'dermatology',
#  'diabetics',
#  'die',
#  'disadvantage',
#  'disappear',
#  'disease',
#  'do',
#  'doctors',
#  'document',
# ...

# %% [markdown]
# Basic string operations

# %%
monty = 'Monty Python'

# %%
circus = "Monty Python's Flying Circus"

monty + circus
# Out:
# "Monty PythonMonty Python's Flying Circus"

# %%
couplet = "Shall I compare thee to a Summer's date"\
        "Thou are more lovely and more temperate:"
print(couplet)
# Out:
# Shall I compare thee to a Summer's dateThou are more lovely and more temperate:

# %% [markdown]
# # Extracting Unicode from text files

# %%
from urllib.request import urlopen

link = 'https://raw.githubusercontent.com/teropa/nlp/master/resources/corpora/unicode_samples/polish-lat2.txt'
raw = urlopen(link).read()
path = nltk.data.find('corpora/unicode_samples/polish-lat2.txt')
print(path)
s = str(raw)
print(s)
# Out:
# /Users/teaching/nltk_data/corpora/unicode_samples/polish-lat2.txt
# b'Pruska Biblioteka Pa\xf1stwowa. Jej dawne zbiory znane pod nazw\xb1\n"Berlinka" to skarb kultury i sztuki niemieckiej. Przewiezione przez\nNiemc\xf3w pod koniec II wojny \xb6wiatowej na Dolny \xa6l\xb1sk, zosta\xb3y\nodnalezione po 1945 r. na terytorium Polski. Trafi\xb3y do Biblioteki\nJagiello\xf1skiej w Krakowie, obejmuj\xb1 ponad 500 tys. zabytkowych\narchiwali\xf3w, m.in. manuskrypty Goethego, Mozarta, Beethovena, Bacha.\n'

# %%
import codecs
#encoding="latin2"
encoding="utf-8"
#encoding = 'unicode_escape'
f = codecs.open(path,encoding=encoding).readlines()
for line in s:
    #line = line.strip()
    #print(line)
    print(line.decode(encoding))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/hj/xyjyq1ds11n1ycjbp53_4svw0000gp/T/ipykernel_8193/2764102345.py in <module>
#       7     #line = line.strip()
#       8     #print(line)
# ----> 9     print(line.decode(encoding))
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
raw.decode(encoding)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/hj/xyjyq1ds11n1ycjbp53_4svw0000gp/T/ipykernel_8193/367146862.py in <module>
# ----> 1 raw.decode(encoding)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 20: invalid continuation byte

# %%
import requests
import nltk
import unicodedata
nltk.download('punkt')

# URL of the XML file to download
url = 'https://ftp.gnu.org/gnu/grep/grep-2.5.1a.tar.gz'

# Download the file
response = requests.get(url)

# Save the file locally
with open('polish_text.txt', 'wb') as f:
    f.write(response.content)
    
with open('polish_text.txt',encoding='latin2') as f:
    for line in f:
        print(line.encode('utf-8').decode('latin2'),'\n'*2)
        print(line.encode('unicode_escape'))
# Out:
# [nltk_data] Downloading package punkt to /Users/teaching/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
with open('polish_text.txt',encoding='latin2') as f:
    for line in f:
        print(line.encode('utf-8').decode('latin2'),'\n'*2)
        print(line.encode('unicode_escape'))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # 3.4 RegEx for detecting word patterns

# %%
import re
wordlist = [w for w in nltk.corpus.words.words('en') if w.islower()]

#lets find words ending with 'ed' using the regex 'ed$'
[w for w in wordlist if re.search('ed$',w)]
# Out:
# ['abaissed',
#  'abandoned',
#  'abased',
#  'abashed',
#  'abatised',
#  'abed',
#  'aborted',
#  'abridged',
#  'abscessed',
#  'absconded',
#  'absorbed',
#  'abstracted',
#  'abstricted',
#  'accelerated',
#  'accepted',
#  'accidented',
#  'accoladed',
#  'accolated',
#  'accomplished',
#  'accosted',
#  'accredited',
#  'accursed',
#  'accused',
#  'accustomed',
#  'acetated',
#  'acheweed',
#  'aciculated',
#  'aciliated',
#  'acknowledged',
#  'acorned',
#  'acquainted',
#  'acquired',
#  'acquisited',
#  'acred',
#  'aculeated',
#  'addebted',
#  'added',
#  'addicted',
#  'addlebrained',
#  'addleheaded',
#  'addlepated',
#  'addorsed',
#  'adempted',
#  'adfected',
#  'adjoined',
#  'admired',
#  'admitted',
#  'adnexed',
#  'adopted',
#  'adossed',
#  'adreamed',
#  'adscripted',
#  'aduncated',
#  'advanced',
#  'advised',
#  'aeried',
#  'aethered',
#  'afeared',
#  'affected',
#  'affectioned',
#  'affined',
#  'afflicted',
#  'affricated',
#  'affrighted',
# ...

# %% [markdown]
# # the wildcard smybol matches any singal character. suppose we have room in a crossword puzzle for an eight letter word with j as its third letter an t as its sixth letter

# %%
#the wildcard smybol matches any singal character. suppose we have room in a crossword puzzle for an eight letter word with j as its third letter an t as its sixth letter

[w for w in wordlist if re.search('^..j..t..$',w)]
# Out:
# ['abjectly',
#  'adjuster',
#  'dejected',
#  'dejectly',
#  'injector',
#  'majestic',
#  'objectee',
#  'objector',
#  'rejecter',
#  'rejector',
#  'unjilted',
#  'unjolted',
#  'unjustly']

# %% [markdown]
# # Ranges & Closures
#
# The T9 system is used for entering text on mobile pohnes. Two or more words that are entered with the same sequence of keystrokes are known as textonyms.
#
# For example, `hole` and `golf` are entered by pressing the sequence `4653`. What other words might be produced using the same sequence?

# %%
[w for w in wordlist if re.search('^[ghi][gmo][jlk][def]$',w)]
# Out:
# ['gold', 'golf', 'hold', 'hole']

# %%
[w for w in wordlist if re.search('^[fs][uh][ic][tk]$',w)]
# Out:
# ['suck', 'suit']

# %% [markdown]
# `+` means "one or more instances like the preceding item"

# %%
chat_words = sorted(set(w for w in nltk.corpus.nps_chat.words()))
[w for w in chat_words if re.search('^[ha]+$',w)]
# Out:
# ['a',
#  'aaaaaaaaaaaaaaaaa',
#  'aaahhhh',
#  'ah',
#  'ahah',
#  'ahahah',
#  'ahh',
#  'ahhahahaha',
#  'ahhh',
#  'ahhhh',
#  'ahhhhhh',
#  'ahhhhhhhhhhhhhh',
#  'h',
#  'ha',
#  'haaa',
#  'hah',
#  'haha',
#  'hahaaa',
#  'hahah',
#  'hahaha',
#  'hahahaa',
#  'hahahah',
#  'hahahaha',
#  'hahahahaaa',
#  'hahahahahaha',
#  'hahahahahahaha',
#  'hahahahahahahahahahahahahahahaha',
#  'hahahhahah',
#  'hahhahahaha']

# %% [markdown]
# `*` means "zero or more instances of the preceding item"

# %%
[w for w in chat_words if re.search('^m*i*n*e*$',w)]
# Out:
# ['',
#  'e',
#  'i',
#  'in',
#  'm',
#  'me',
#  'meeeeeeeeeeeee',
#  'mi',
#  'miiiiiiiiiiiiinnnnnnnnnnneeeeeeeeee',
#  'miiiiiinnnnnnnnnneeeeeeee',
#  'min',
#  'mine',
#  'mm',
#  'mmm',
#  'mmmm',
#  'mmmmm',
#  'mmmmmm',
#  'mmmmmmmmiiiiiiiiinnnnnnnnneeeeeeee',
#  'mmmmmmmmmm',
#  'mmmmmmmmmmmmm',
#  'mmmmmmmmmmmmmm',
#  'n',
#  'ne']

# %% [markdown]
# `Kleene closures` are the symbols `+` and `*`

# %% [markdown]
# * `.` matches any character
# * ^abc matches some pattern at the start of a string
# * abc$ matches some pattern at the end of a string
# * [abc] matches one of a set of characters
# * [A-Z0-9] matches one of aa range of characters
# * `ed|ing|s` matches one of the specified strings
# * `*` matchez zero or more of the previous items
# * `? matches zero or on of the previous item
# * {n} exactly n repeats where n is a non negative integer
# * {n,} at least n repeats
# * {,n} no more than n repeats
# * {m,n} at least m and no more than n repeats
# * a(b|c)+ paranthesis that indicate the scope of the operators

# %%
wsj = sorted(set(nltk.corpus.treebank.words()))
[w for w in wsj if re.search('^[0-9]+\.[0-9]+$',w)]
# Out:
# ['0.0085',
#  '0.05',
#  '0.1',
#  '0.16',
#  '0.2',
#  '0.25',
#  '0.28',
#  '0.3',
#  '0.4',
#  '0.5',
#  '0.50',
#  '0.54',
#  '0.56',
#  '0.60',
#  '0.7',
#  '0.82',
#  '0.84',
#  '0.9',
#  '0.95',
#  '0.99',
#  '1.01',
#  '1.1',
#  '1.125',
#  '1.14',
#  '1.1650',
#  '1.17',
#  '1.18',
#  '1.19',
#  '1.2',
#  '1.20',
#  '1.24',
#  '1.25',
#  '1.26',
#  '1.28',
#  '1.35',
#  '1.39',
#  '1.4',
#  '1.457',
#  '1.46',
#  '1.49',
#  '1.5',
#  '1.50',
#  '1.55',
#  '1.56',
#  '1.5755',
#  '1.5805',
#  '1.6',
#  '1.61',
#  '1.637',
#  '1.64',
#  '1.65',
#  '1.7',
#  '1.75',
#  '1.76',
#  '1.8',
#  '1.82',
#  '1.8415',
#  '1.85',
#  '1.8500',
#  '1.9',
#  '1.916',
#  '1.92',
#  '10.19',
#  '10.2',
#  '10.5',
#  '107.03',
#  '107.9',
#  '109.73',
#  '11.10',
#  '11.5',
#  '11.57',
#  '11.6',
#  '11.72',
#  '11.95',
#  '112.9',
#  '113.2',
#  '116.3',
#  '116.4',
#  '116.7',
#  '116.9',
#  '118.6',
#  '12.09',
#  '12.5',
#  '12.52',
#  '12.68',
#  '12.7',
#  '12.82',
#  '12.97',
# ...

# %%
[w for w in wsj if re.search('^[A-Z]+\$$',w)]
# Out:
# ['C$', 'US$']

# %%
[w for w in wsj if re.search('^[0-9]{4}$',w)]
# Out:
# ['1614',
#  '1637',
#  '1787',
#  '1901',
#  '1903',
#  '1917',
#  '1925',
#  '1929',
#  '1933',
#  '1934',
#  '1948',
#  '1953',
#  '1955',
#  '1956',
#  '1961',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1975',
#  '1976',
#  '1977',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2005',
#  '2009',
#  '2017',
#  '2019',
#  '2029',
#  '3057',
#  '8300']

# %%
[w for w in wsj if re.search('^[a-z]{5,}-[a-z]{2,3}-[a-z]{,6}$',w)]
# Out:
# ['black-and-white',
#  'bread-and-butter',
#  'father-in-law',
#  'machine-gun-toting',
#  'savings-and-loan']

# %%
[w for w in wsj if re.search('(ed|ing)$',w)]
# Out:
# ['62%-owned',
#  'Absorbed',
#  'According',
#  'Adopting',
#  'Advanced',
#  'Advancing',
#  'Alfred',
#  'Allied',
#  'Annualized',
#  'Anything',
#  'Arbitrage-related',
#  'Arbitraging',
#  'Asked',
#  'Assuming',
#  'Atlanta-based',
#  'Baking',
#  'Banking',
#  'Beginning',
#  'Beijing',
#  'Being',
#  'Bermuda-based',
#  'Betting',
#  'Boeing',
#  'Broadcasting',
#  'Bucking',
#  'Buying',
#  'Calif.-based',
#  'Change-ringing',
#  'Citing',
#  'Concerned',
#  'Confronted',
#  'Conn.based',
#  'Consolidated',
#  'Continued',
#  'Continuing',
#  'Declining',
#  'Defending',
#  'Depending',
#  'Designated',
#  'Determining',
#  'Developed',
#  'Died',
#  'During',
#  'Encouraged',
#  'Encouraging',
#  'English-speaking',
#  'Estimated',
#  'Everything',
#  'Excluding',
#  'Exxon-owned',
#  'Faulding',
#  'Fed',
#  'Feeding',
#  'Filling',
#  'Filmed',
#  'Financing',
#  'Following',
#  'Founded',
#  'Fracturing',
#  'Francisco-based',
#  'Fred',
#  'Funded',
#  'Funding',
# ...

# %% [markdown]
# # 3.5 Useful applications of regular expressions

# %%
# Extracting Word Pieces
import re
word = 'supercalifragilisticexpialidocious'
len(re.findall(r'[aeiou]',word))
# Out:
# 16

# %% [markdown]
# ### look for all sequences of two or more vowels in some text, and detemine their relative frequency

# %%
wsj = sorted(set(nltk.corpus.treebank.words()))
fd = nltk.FreqDist(vs for word in wsj for vs in re.findall(r'[aeiou]{2,}',word))
fd.items()
# Out:
# dict_items([('ea', 476), ('oi', 65), ('ou', 329), ('io', 549), ('ee', 217), ('ie', 331), ('ui', 95), ('ua', 109), ('ai', 261), ('ue', 105), ('ia', 253), ('ei', 86), ('iai', 1), ('oo', 174), ('au', 106), ('eau', 10), ('oa', 59), ('oei', 1), ('oe', 15), ('eo', 39), ('uu', 1), ('eu', 18), ('iu', 14), ('aii', 1), ('aiia', 1), ('ae', 11), ('aa', 3), ('oui', 6), ('ieu', 3), ('ao', 6), ('iou', 27), ('uee', 4), ('eou', 5), ('aia', 1), ('uie', 3), ('iao', 1), ('eei', 2), ('uo', 8), ('uou', 5), ('eea', 1), ('ueui', 1), ('ioa', 1), ('ooi', 1)])

# %%
[int(n) for n in re.findall(r'[0-9]{1,4}','2009-12-31')]
# Out:
# [2009, 12, 31]

# %% [markdown]
# # doing more with word pieces

# %%
regexp = r'[AEIOUaeiou]+|[AEIOUaeiou]+$[^AEIOUaeiou]'

def compress(word):
    pieces = re.findall(regexp,word)
    return ''.join(pieces)


english_udhr = nltk.corpus.udhr.words('English-Latin1')
print(nltk.tokenwrap(w for w in english_udhr[:75]))
print('\n')
print(nltk.tokenwrap(compress(w) for w in english_udhr[:75]))
# Out:
# Universal Declaration of Human Rights Preamble Whereas recognition of
# the inherent dignity and of the equal and inalienable rights of all
# members of the human family is the foundation of freedom , justice and
# peace in the world , Whereas disregard and contempt for human rights
# have resulted in barbarous acts which have outraged the conscience of
# mankind , and the advent of a world in which human beings shall enjoy
# freedom of speech and
#
#
# Uiea eaaio o ua i eae eea eoiio o e iee ii a o e eua a iaieae i o a ee
# o e ua ai i e ouaio o eeo  uie a eae i e o  eea iea a oe o ua i ae eue
# i aaou a i ae ouae e oiee o ai  a e ae o a o i i ua ei a eo eeo o ee a

# %% [markdown]
# now lets extract all consonant vowel sequences from the words of Rotokas, such as ka and si. Since each of these is a pair, it can be used to initialize a conditional frequency distribution.

# %%
rotokas_words = nltk.corpus.toolbox.words('rotokas.dic')
cvs = [cv for w in rotokas_words for cv in re.findall(r'[ptksvr][aeiou]',w)]
cfd = nltk.ConditionalFreqDist(cvs)
cfd.tabulate()
# Out:
#     a   e   i   o   u
# k 418 148  94 420 173
# p  83  31 105  34  51
# r 187  63  84  89  79
# s   0   0 100   2   1
# t  47   8   0 148  37
# v  93  27 105  48  49

# %%
cfd.items()
# Out:
# dict_items([('k', FreqDist({'o': 420, 'a': 418, 'u': 173, 'e': 148, 'i': 94})), ('r', FreqDist({'a': 187, 'o': 89, 'i': 84, 'u': 79, 'e': 63})), ('v', FreqDist({'i': 105, 'a': 93, 'u': 49, 'o': 48, 'e': 27})), ('s', FreqDist({'i': 100, 'o': 2, 'u': 1})), ('t', FreqDist({'o': 148, 'a': 47, 'u': 37, 'e': 8})), ('p', FreqDist({'i': 105, 'a': 83, 'u': 51, 'o': 34, 'e': 31}))])

# %%
cfd['k']
# Out:
# FreqDist({'o': 420, 'a': 418, 'u': 173, 'e': 148, 'i': 94})

# %% [markdown]
# If we want to be able to inspect the words behind the numbers in that table, it would be helpful to have an index, allowing us to quickly find the list of words that contains a given consonant vowel pair.

# %%
cv_word_pairs = [(cv,w) for w in rotokas_words for cv in re.findall(r'[ptksvr][aeiou]',w)]
cv_index = nltk.Index(cv_word_pairs)
cv_index['su']
# Out:
# ['kasuari']

# %%
cv_index['po']
# Out:
# ['kaapo',
#  'kaapopato',
#  'kaipori',
#  'kaiporipie',
#  'kaiporivira',
#  'kapo',
#  'kapoa',
#  'kapokao',
#  'kapokapo',
#  'kapokapo',
#  'kapokapoa',
#  'kapokapoa',
#  'kapokapora',
#  'kapokapora',
#  'kapokaporo',
#  'kapokaporo',
#  'kapokari',
#  'kapokarito',
#  'kapokoa',
#  'kapoo',
#  'kapooto',
#  'kapoovira',
#  'kapopaa',
#  'kaporo',
#  'kaporo',
#  'kaporopa',
#  'kaporoto',
#  'kapoto',
#  'karokaropo',
#  'karopo',
#  'kepo',
#  'kepoi',
#  'keposi',
#  'kepoto']

# %% [markdown]
# # Finding word stems

# %%
def stem(word):
    for suffix in ['ing','ly','ed','ious','ies','ive','es','s','ment']:
        if word.endswith(suffix):
            return word[:-len(suffix)]
    return word

# %%
base_pattern = '^.*(ing|ly|ed|ious|ies|ive|es|s|ment)$'
re.findall(base_pattern,'processing')
# Out:
# ['ing']

# %%
pattern2 = base_pattern.replace('ing','?:ing')
re.findall(pattern2,'processing')
# Out:
# ['processing']

# %%
pattern3 = base_pattern.replace('.*','(.*)')
re.findall(pattern3,'processing')
# Out:
# [('process', 'ing')]

# %%
pattern4 = base_pattern.replace('.*','(.*?)')
re.findall(pattern4,'processes')
# Out:
# [('process', 'es')]

# %%
def stem(word):
    regex = r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)?$'
    g = re.findall(regexp,word)#[0]
    if len(g)>0:
        return g

raw = """DENNIS: Listen, strange women lying in ponds distributing sowrds 
is no babsis for a system of government. Supreme executive power dervices from a 
mandate from the masses, not from some farcial aquatic ceremony."""

tokens = nltk.word_tokenize(raw)
print(tokens)
#[stem(t) for t in tokens]
# Out:
# ['DENNIS', ':', 'Listen', ',', 'strange', 'women', 'lying', 'in', 'ponds', 'distributing', 'sowrds', 'is', 'no', 'babsis', 'for', 'a', 'system', 'of', 'government', '.', 'Supreme', 'executive', 'power', 'dervices', 'from', 'a', 'mandate', 'from', 'the', 'masses', ',', 'not', 'from', 'some', 'farcial', 'aquatic', 'ceremony', '.']

# %% [markdown]
# # Searching tokenized text
#
# You can use a special kind of regular expression for searching across multiple words in a text (where a text is a list of tokens). For example "<a> <man>" finds all instances of a man in the text. The angle brackets are used to mark token boundaries, and any whitespace between the angle brackets is ignored

# %%
import nltk
from nltk.corpus import gutenberg, nps_chat
moby = nltk.Text(gutenberg.words('melville-moby_dick.txt'))
moby.findall(r"<a>(<.*>)<man>")
# Out:
# monied; nervous; dangerous; white; white; white; pious; queer; good;
# mature; white; Cape; great; wise; wise; butterless; white; fiendish;
# pale; furious; better; certain; complete; dismasted; younger; brave;
# brave; brave; brave

# %%
chat = nltk.Text(nps_chat.words())
chat.findall(r"<.*><.*><bro>")
# Out:
# you rule bro; telling you bro; u twizted bro

# %%
chat.findall(r"<l.*>{3,}")
# Out:
# lol lol lol; lmao lol lol; lol lol lol; la la la la la; la la la; la
# la la; lovely lol lol love; lol lol lol.; la la la; la la la

# %%
from nltk.corpus import brown
hobbies_learned = nltk.Text(brown.words(categories=['hobbies','learned']))
hobbies_learned.findall(r"<\w*> <and> <other> <\w*s>")
# Out:
# speed and other activities; water and other liquids; tomb and other
# landmarks; Statues and other monuments; pearls and other jewels;
# charts and other items; roads and other features; figures and other
# objects; military and other areas; demands and other factors;
# abstracts and other compilations; iron and other metals

# %% [markdown]
# # 3.6 Normalizing Text
#
# In earlier program examples, we converted text to lower case before doing anything with its words. A further step is to make sure that the resulting form is a known word in a dictionary, a task known as lemmatization. We discuss each of these in turn. First we need to define the data we will use in this section;

# %%
raw = """DENNIS: Listen, strange women lying in ponds distributing swords is no basis for a system of government. Supreme executive power derivcesfrom a mandate from the masses, not some form a farcical aquatic ceremony."""
tokens = nltk.word_tokenize(raw)

# %%
porter = nltk.PorterStemmer()
[porter.stem(t) for t in tokens]
# Out:
# ['denni',
#  ':',
#  'listen',
#  ',',
#  'strang',
#  'women',
#  'lie',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'is',
#  'no',
#  'basi',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'suprem',
#  'execut',
#  'power',
#  'derivcesfrom',
#  'a',
#  'mandat',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'some',
#  'form',
#  'a',
#  'farcic',
#  'aquat',
#  'ceremoni',
#  '.']

# %%
lancaster = nltk.LancasterStemmer()
[lancaster.stem(t) for t in tokens]
# Out:
# ['den',
#  ':',
#  'list',
#  ',',
#  'strange',
#  'wom',
#  'lying',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'is',
#  'no',
#  'bas',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'suprem',
#  'execut',
#  'pow',
#  'derivcesfrom',
#  'a',
#  'mand',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'som',
#  'form',
#  'a',
#  'farc',
#  'aqu',
#  'ceremony',
#  '.']

# %%
class IndexedText(object):
    def __init__(self,stemmer,text):
        self._text = text
        self._stemmer = stemmer
        self._index = nltk.Index((self._stem(word),i) for (i,word) in enumerate(text))
        
    def concordance(self,word,width=40):
        key = self._stem(word)
        wc = width/4
        for i in self._index[key]:
            print(wc)
            print('thisline;',self._text[i-wc:i])
            lcontext = ' '.join(self._text[i-wc:i])
            rcontext = ' '.join(self._text[i:i+wc])
            ldisplay = '%*s'%(width,lcontext[-width:])
            rdisplay = '%-*s'%(width,rcontext[:width])
            print(ldisplay,rdisplay)
            
    def _stem(self,word):
        return self._stemmer.stem(word).lower()

# %%
porter = nltk.PorterStemmer()
grail = nltk.corpus.webtext.words('grail.txt')
text = IndexedText(porter,grail)
text.concordance('lie')
# Out:
# 10.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/hj/xyjyq1ds11n1ycjbp53_4svw0000gp/T/ipykernel_3038/84134132.py in <module>
#       2 grail = nltk.corpus.webtext.words('grail.txt')
#       3 text = IndexedText(porter,grail)
# ----> 4 text.concordance('lie')
#
# /var/folders/hj/xyjyq1ds11n1ycjbp53_4svw0000gp/T/ipykernel_3038/1189017040.py in concordance(self, word, width)
#      10         for i in self._index[key]:
#      11             print(wc)
# ---> 12             print('thisline;',self._text[i-wc:i])
#      13             lcontext = ' '.join(self._text[i-wc:i])
#      14             rcontext = ' '.join(self._text[i:i+wc])
#
# ~/.local/lib/python3.9/site-packages/nltk/corpus/reader/util.py in __getitem__(self, i)
#     248             offset = self._cache[0]
#     249             if offset <= start and stop <= self._cache[1]:
# ...

# %% [markdown]
# # Word net lemmatizer removes affixes only if the resulting word is in its dictionary. This additional checking process makes the lemmatizer slower than the stemmers

# %%
wnl = nltk.WordNetLemmatizer()
[wnl.lemmatize(t) for t in tokens]
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'woman',
#  'lying',
#  'in',
#  'pond',
#  'distributing',
#  'sword',
#  'is',
#  'no',
#  'basis',
#  'for',
#  'a',
#  'system',
#  'of',
#  'government',
#  '.',
#  'Supreme',
#  'executive',
#  'power',
#  'derivcesfrom',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'some',
#  'form',
#  'a',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %% [markdown]
# # 3.7 Regular Expressions for tokenizing text

# %%
raw = """'When I'M a Duchess,' she said to herself, (not in a very hopeful tone though), 'I won't have any pepper in my kitchen AT ALL. Soup does very well without--Maybe it's always pepper that makes people hot-tempered,'..."""
import re
#splitting on white space
re.split(r' ',raw)
# Out:
# ["'When",
#  "I'M",
#  'a',
#  "Duchess,'",
#  'she',
#  'said',
#  'to',
#  'herself,',
#  '(not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'though),',
#  "'I",
#  "won't",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL.',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without--Maybe',
#  "it's",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  "hot-tempered,'..."]

# %%
#splitting on line breaks
re.split(r'[\t\n]+',raw)
# Out:
# ["'When I'M a Duchess,' she said to herself, (not in a very hopeful tone though), 'I won't have any pepper in my kitchen AT ALL. Soup does very well without--Maybe it's always pepper that makes people hot-tempered,'..."]

# %%
#try to match any sequence of characters. if no match is found, try ot match any non whitespace chracters \S followed by any word characcters
re.findall(r'\w+|\S\w*',raw)
# Out:
# ["'When",
#  'I',
#  "'M",
#  'a',
#  'Duchess',
#  ',',
#  "'",
#  'she',
#  'said',
#  'to',
#  'herself',
#  ',',
#  '(not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'though',
#  ')',
#  ',',
#  "'I",
#  'won',
#  "'t",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL',
#  '.',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without',
#  '-',
#  '-Maybe',
#  'it',
#  "'s",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  'hot',
#  '-tempered',
#  ',',
#  "'",
#  '.',
#  '.',
#  '.']

# %%
print(re.findall(r"\w+(?:[-']\w+)*|'|[-.(]+|\S\w*",raw))
# Out:
# ["'", 'When', "I'M", 'a', 'Duchess', ',', "'", 'she', 'said', 'to', 'herself', ',', '(', 'not', 'in', 'a', 'very', 'hopeful', 'tone', 'though', ')', ',', "'", 'I', "won't", 'have', 'any', 'pepper', 'in', 'my', 'kitchen', 'AT', 'ALL', '.', 'Soup', 'does', 'very', 'well', 'without', '--', 'Maybe', "it's", 'always', 'pepper', 'that', 'makes', 'people', 'hot-tempered', ',', "'", '...']

# %%
text = 'That U.S.A. poster-print costs $12.40...'
pattern = r'''(?x)([A-z]\.)+|\w+(-\w+)*|\$?\d+(\.\d+)?%?|\.\.\.|[][.,;"'?():-_`]'''
nltk.regexp_tokenize(text,pattern)
# Out:
# [('', '', ''),
#  ('A.', '', ''),
#  ('', '-print', ''),
#  ('', '', ''),
#  ('', '', '.40'),
#  ('', '', '')]

# %%
sent_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
text = nltk.corpus.gutenberg.raw('chesterton-thursday.txt')
sents = sent_tokenizer.tokenize(text)
print(sents[171:181])
# Out:
# ['In the wild events which were to follow this girl had no\npart at all; he never saw her again until all his tale was over.', 'And yet, in some indescribable way, she kept recurring like a\nmotive in music through all his mad adventures afterwards, and the\nglory of her strange hair ran like a red thread through those dark\nand ill-drawn tapestries of the night.', 'For what followed was so\nimprobable, that it might well have been a dream.', 'When Syme went out into the starlit street, he found it for the\nmoment empty.', 'Then he realised (in some odd way) that the silence\nwas rather a living silence than a dead one.', 'Directly outside the\ndoor stood a street lamp, whose gleam gilded the leaves of the tree\nthat bent out over the fence behind him.', 'About a foot from the\nlamp-post stood a figure almost as rigid and motionless as the\nlamp-post itself.', 'The tall hat and long frock coat were black; the\nface, in an abrupt shadow, was almost as dark.', 'Only a fringe of\nfiery 
# ...

# %%
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"
seg1 = "0000000000000000100000000010000000000000001000000000000"
seg2 = "0100100100001001001000010100100010010000100010010001000"

def segment(text,segs):
    words = []
    last = 0
    for i in range(len(segs)):
        if segs[i]=='1':
            words.append(text[last:i+1])
            last = i+1
    words.append(text[last:])
    return words

segment(text,seg1)
# Out:
# ['doyouseethekittys', 'eethedoggy', 'doyoulikethekitt', 'ylikethedoggy']

# %%
segment(text,seg2)
# Out:
# ['do',
#  'you',
#  'see',
#  'theki',
#  'tty',
#  'see',
#  'thedo',
#  'gg',
#  'ydo',
#  'youl',
#  'ike',
#  'theki',
#  'ttyl',
#  'ike',
#  'thed',
#  'oggy']

# %%
def evaluate(text,segs):
    words = segment(text,segs)
    text_size = len(words)
    lexicon_size = len(' '.join(list(set(words))))
    return text_size+lexicon_size

evaluate(text,seg2)
# Out:
# 73

# %%
from random import randint
def flip(segs,pos):
    return segs[:pos]+str(1-int(segs[pos]))+segs[pos+1:]

def flip_n(segs,n):
    for i in range(n):
        segs = flip(segs,randint(0,len(segs)-1))
    return segs

def anneal(text,segs,iterations,cooling_rate):
    temperature = float(len(segs))
    while temperature>0.5:
        best_segs,best = segs,evaluate(text,segs)
        for i in range(iterations):
            guess = flip_n(segs,int(round(temperature)))
            score = evaluate(text,guess)
            if score<best:
                best,best_segs = score,guess
        score,segs =best,best_segs
        temperature = temperature/cooling_rate
        print(evaluate(text,segs),segment(text,segs))
    return segs

# %%
anneal(text,seg1,5000,1.2)
# Out:
# 63 ['doyouseethekittys', 'eethedoggy', 'doyoulikethekitt', 'ylikethedoggy']
# 63 ['doyouseethekittys', 'eethedoggy', 'doyoulikethekitt', 'ylikethedoggy']
# 63 ['doyouseethekittys', 'eethedoggy', 'doyoulikethekitt', 'ylikethedoggy']
# 63 ['doyouseethekittys', 'eethedoggy', 'doyoulikethekitt', 'ylikethedoggy']
# 63 ['doyouseethekittys', 'eethedoggy', 'doyoulikethekitt', 'ylikethedoggy']
# 63 ['doyouseethekittys', 'eethedoggy', 'doyoulikethekitt', 'ylikethedoggy']
# 63 ['doyouseethekittys', 'eethedoggy', 'doyoulikethekitt', 'ylikethedoggy']
# 63 ['doyouseethekittys', 'eethedoggy', 'doyoulikethekitt', 'ylikethedoggy']
# 63 ['doyouseethekittys', 'eethedoggy', 'doyoulikethekitt', 'ylikethedoggy']
# 61 ['doyouseethekittys', 'eet', 'hedoggy', 'doyoulik', 'et', 'hekittyliket', 'hedoggy']
# 57 ['doyouse', 'ethekitty', 's', 'eet', 'hedoggy', 'd', 'oyoulik', 'ethekitty', 'liket', 'hedoggy']
# 57 ['doyouse', 'ethekitty', 's', 'eet', 'hedoggy', 'd', 'oyoulik', 'ethekitty', 'liket', 'hedoggy']
# ...
