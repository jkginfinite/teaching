# %% [markdown]
# # DS542 Final exam: All problems are equal in weight.

# %% [markdown]
# # Problem 1: Load the head of the csv file `superconductors.csv`

# %%
import pandas as pd
df = pd.read_csv('supercondcutors.csv')
df.head()
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                   4         88.944468             57.862692
# 1                   5         92.729214             58.518416
# 2                   4         88.944468             57.885242
# 3                   4         88.944468             57.873967
# 4                   4         88.944468             57.840143
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0          66.361592              36.116612             1.181795
# 1          73.132787              36.396602             1.449309
# 2          66.361592              36.122509             1.181795
# 3          66.361592              36.119560             1.181795
# 4          66.361592              36.110716             1.181795
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                 1.062396          122.90607              31.794921
# ...

# %% [markdown]
# # 2. Print the shape of the full dataframe from problem 1

# %%
print(df.shape)
# Out:
# (21263, 82)

# %% [markdown]
# # 3. Print the columns of the full dataframe from problem 1

# %%
print(df.columns)
# Out:
# Index(['number_of_elements', 'mean_atomic_mass', 'wtd_mean_atomic_mass',
#        'gmean_atomic_mass', 'wtd_gmean_atomic_mass', 'entropy_atomic_mass',
#        'wtd_entropy_atomic_mass', 'range_atomic_mass', 'wtd_range_atomic_mass',
#        'std_atomic_mass', 'wtd_std_atomic_mass', 'mean_fie', 'wtd_mean_fie',
#        'gmean_fie', 'wtd_gmean_fie', 'entropy_fie', 'wtd_entropy_fie',
#        'range_fie', 'wtd_range_fie', 'std_fie', 'wtd_std_fie',
#        'mean_atomic_radius', 'wtd_mean_atomic_radius', 'gmean_atomic_radius',
#        'wtd_gmean_atomic_radius', 'entropy_atomic_radius',
#        'wtd_entropy_atomic_radius', 'range_atomic_radius',
#        'wtd_range_atomic_radius', 'std_atomic_radius', 'wtd_std_atomic_radius',
#        'mean_Density', 'wtd_mean_Density', 'gmean_Density',
#        'wtd_gmean_Density', 'entropy_Density', 'wtd_entropy_Density',
#        'range_Density', 'wtd_range_Density', 'std_Density', 'wtd_std_Density',
# ...

# %% [markdown]
# # 4. Print the info of the dataframe from problem 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21263 entries, 0 to 21262
# Data columns (total 82 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   number_of_elements               21263 non-null  int64
#  1   mean_atomic_mass                 21263 non-null  float64
#  2   wtd_mean_atomic_mass             21263 non-null  float64
#  3   gmean_atomic_mass                21263 non-null  float64
#  4   wtd_gmean_atomic_mass            21263 non-null  float64
#  5   entropy_atomic_mass              21263 non-null  float64
#  6   wtd_entropy_atomic_mass          21263 non-null  float64
#  7   range_atomic_mass                21263 non-null  float64
#  8   wtd_range_atomic_mass            21263 non-null  float64
#  9   std_atomic_mass                  21263 non-null  float64
#  10  wtd_std_atomic_mass              21263 non-null  float64
# ...

# %% [markdown]
# # 5. Describe the dataframe (using the describe method) of the dataframe in problem 1

# %%
df.describe()
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# count        21263.000000      21263.000000          21263.000000
# mean             4.115224         87.557631             72.988310
# std              1.439295         29.676497             33.490406
# min              1.000000          6.941000              6.423452
# 25%              3.000000         72.458076             52.143839
# 50%              4.000000         84.922750             60.696571
# 75%              5.000000        100.404410             86.103540
# max              9.000000        208.980400            208.980400
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# count       21263.000000           21263.000000         21263.000000
# mean           71.290627              58.539916             1.165608
# std            31.030272              36.651067             0.364930
# min             5.320573               1.960849             0.000000
# ...

# %% [markdown]
# # 6. Load the `sales-funnel.csv` file's
#
# * Group by the `Name` column
# * aggregate the rows using the `.count()` method.
# *  `.reset_index()` on this object.
# * Access only the only the `Name` and `Quantity` columns
# * Sort it by the `Quantity` in descending order
# * Call this object `grouped`

# %%
sales_funnel = pd.read_csv('sales-funnel.csv')
grouped = sales_funnel.groupby('Name').count().reset_index()[['Name','Quantity']].sort_values(by='Quantity',ascending=False)
grouped
# Out:
#                             Name  Quantity
# 11               Trantow-Barrows         3
# 7                      Koepp Ltd         2
# 8                      Kulas Inc         2
# 10                    Stokes LLC         2
# 0                     Barton LLC         1
# 1   Fritsch, Russel and Anderson         1
# 2                     Herman LLC         1
# 3                  Jerde-Hilpert         1
# 4    Kassulke, Ondricka and Metz         1
# 5                    Keeling LLC         1
# 6                   Kiehn-Spinka         1
# 9                    Purdy-Kunde         1

# %% [markdown]
# # Problem 7: Pivot the sales table
# * Let the indices be the `Name`, `Rep` and `Manager` columns
# * Let the column to pivot be the `Status` column
# * Let the value column be the `Price`
# * Let the aggregation function be the mean
# * Fill any null values with 0
# * Do this in ONE LINE OF CODE
# * Save as the object `sales_pivot`

# %%
sales_pivot = sales_funnel.pivot_table(index=['Name','Rep','Manager'],
                              columns=['Status'],
                              values='Price',
                              aggfunc='mean',
                              fill_value=0)
sales_pivot
# Out:
# Status                                                    declined  pending  \
# Name                         Rep           Manager
# Barton LLC                   John Smith    Debra Henley      35000        0
# Fritsch, Russel and Anderson Craig Booker  Debra Henley      35000        0
# Herman LLC                   Cedric Moss   Fred Anderson         0        0
# Jerde-Hilpert                John Smith    Debra Henley          0     5000
# Kassulke, Ondricka and Metz  Wendy Yule    Fred Anderson         0        0
# Keeling LLC                  Wendy Yule    Fred Anderson         0        0
# Kiehn-Spinka                 Daniel Hilton Debra Henley          0        0
# Koepp Ltd                    Wendy Yule    Fred Anderson     65000        0
# Kulas Inc                    Daniel Hilton Debra Henley          0    40000
# Purdy-Kunde                  Cedric Moss   Fred Anderson         0        0
# Stokes LLC                   Cedric Moss   Fred Anderson         0     5000
# ...

# %% [markdown]
# # 8. Using the `grouped` object from problem 6, make a bar plot
#
# * x values are the `Name`
# * y values are the `Account`
# * Use one line of code, acting on the dataframe

# %%
grouped.plot(x='Name',y='Quantity',kind='bar')
# Out:
# <AxesSubplot:xlabel='Name'>

# %% [markdown]
# # 9. Using the `superconductors.csv` data from problem 1 make a histogram via `matplotlib`
# * Let the figure size be `(5,5)`
# * Run a histogram on the `critical_temp` column
# * Give it a title of `Superconducting Temperature`
# * Give it a ylabel of `Count`
# * Give it an xlabel of `Kelvin`
# * Show the plot

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
df['critical_temp'].hist()
plt.title('Superconducting Temperature')
plt.ylabel('Count')
plt.xlabel('Kelvin')
plt.show()

# %% [markdown]
# # Problem 10:
#
# * Create a class called `Name`
# * The constructor should have two input parameters `name` and `profession`
# * Make a method called `name_profession`, with no arguments, that returns the string `'Name: (the input name), Profession: (the profession)`
#
# * Demonstrate that it works

# %%
class Name:
    def __init__(self,name,profession):
        self.name = name
        self.profession = profession
        
    def name_profession(self):
        return 'Name: {}, Profession: {}'.format(self.name,self.profession)
    
n = Name('Joe','Professor')
n.name_profession()
# Out:
# 'Name: Joe, Profession: Professor'
