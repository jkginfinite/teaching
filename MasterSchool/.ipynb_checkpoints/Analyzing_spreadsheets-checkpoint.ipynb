# %%
file = "Aiden's Copy of Data Salary.xlsx"
file_path = '/Users/teaching/Downloads'

# %%
import pandas as pd

df = pd.read_excel(file_path+'/'+file)
df
# Out:
#                timestamp                     company                 level  \
# 0    2021-02-22 14:54:05                   Microsoft                    60
# 1    2019-05-30 15:56:08                         IBM                     6
# 2    2021-06-28 19:18:49                   MathWorks                    L3
# 3    2021-08-05 07:07:36                 Wells Fargo  Technology Executive
# 4    2021-05-08 00:25:57                       Intel               Grade 7
# ...                  ...                         ...                   ...
# 1995 2020-12-20 18:15:32  The New York Times Company                    L3
# 1996 2021-04-27 12:03:38                      Amazon                    L5
# 1997 2019-01-27 21:13:38                      Google                    L4
# 1998 2019-02-05 12:45:25                 Capital One   Master Software Eng
# 1999 2020-08-17 19:03:23                    LinkedIn              Director
#
#                              title  totalyearlycompensation  \
# ...

# %%
df['title'].unique()
# Out:
# array(['Business Analyst', 'Software Engineer', 'Human Resources',
#        'Software Engineering Manager', 'Hardware Engineer',
#        'Technical Program Manager', 'Data Scientist', 'Product Manager',
#        'Management Consultant', 'Product Designer', 'Solution Architect',
#        'Mechanical Engineer', 'Marketing', 'Sales', 'Recruiter'],
#       dtype=object)

# %%
ba = df[df['title']=='Business Analyst']
ba
# Out:
#                timestamp       company                   level  \
# 0    2021-02-22 14:54:05     Microsoft                      60
# 62   2021-05-27 04:45:14     Capgemini                      C1
# 123  2021-07-30 18:17:54        Amazon                      L4
# 174  2021-06-22 09:13:02        Google                      L5
# 214  2020-08-21 12:10:34          CBRE                      L1
# 326  2020-09-29 08:45:28           SAP               Associate
# 353  2021-05-16 13:10:24          Wise                       5
# 443  2020-09-22 22:21:15        Google                      L3
# 448  2020-07-25 21:11:07    Fannie mae                       3
# 590  2020-09-29 10:19:08       Zalando                      C7
# 774  2021-03-25 12:19:27          Lyft                      L3
# 803  2021-06-09 15:53:31         Apple                    ICT3
# 810  2020-10-10 20:34:18        Intuit   Principal / Architect
# 846  2020-11-18 11:40:54        Boeing                      L3
# ...

# %%
import matplotlib.pyplot as plt
ba['totalyearlycompensation'].hist()
plt.axvline(ba['totalyearlycompensation'].mean(),c='r')
plt.show()

# %%
ba['totalyearlycompensation'].mean()
# Out:
# 135724.1379310345

# %%
ba[['yearsofexperience','totalyearlycompensation']].groupby('yearsofexperience').mean()
# Out:
#                    totalyearlycompensation
# yearsofexperience
# 0.0                           94000.000000
# 1.0                           80000.000000
# 2.0                           85333.333333
# 3.0                          124000.000000
# 4.0                           98500.000000
# 5.0                          112375.000000
# 6.0                          152250.000000
# 8.0                          237500.000000
# 9.0                          120000.000000
# 10.0                         190000.000000
# 12.0                         214000.000000
# 20.0                         300000.000000

# %%
ba[['yearsofexperience','totalyearlycompensation']].groupby('yearsofexperience').count()
# Out:
#                    totalyearlycompensation
# yearsofexperience
# 0.0                                      3
# 1.0                                      1
# 2.0                                      3
# 3.0                                      1
# 4.0                                      2
# 5.0                                      8
# 6.0                                      4
# 8.0                                      2
# 9.0                                      1
# 10.0                                     2
# 12.0                                     1
# 20.0                                     1

# %%
#['yearsofexperience','totalyearlycompensation','title']

full = df[['yearsofexperience','totalyearlycompensation','title']].groupby(['title','yearsofexperience']).mean()

# %%
full.reset_index()
# Out:
#                          title  yearsofexperience  totalyearlycompensation
# 0             Business Analyst                0.0             94000.000000
# 1             Business Analyst                1.0             80000.000000
# 2             Business Analyst                2.0             85333.333333
# 3             Business Analyst                3.0            124000.000000
# 4             Business Analyst                4.0             98500.000000
# ..                         ...                ...                      ...
# 242  Technical Program Manager               16.0            310000.000000
# 243  Technical Program Manager               20.0            296250.000000
# 244  Technical Program Manager               22.0            299000.000000
# 245  Technical Program Manager               25.0            179000.000000
# 246  Technical Program Manager               35.0            189000.000000
#
# [247 rows x 3 columns]
