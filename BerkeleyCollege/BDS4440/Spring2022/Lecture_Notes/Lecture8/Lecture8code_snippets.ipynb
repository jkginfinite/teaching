# %%
from textblob import Word

index = Word('index')

index.pluralize()
# Out:
# 'indices'

# %%
from textblob import TextBlob

animals = TextBlob('dog cat fish bird').words

animals.pluralize()
# Out:
# WordList(['dogs', 'cats', 'fish', 'birds'])

# %%
from textblob import TextBlob

t = TextBlob('flowers clouds raindrops').words

t.singularize()
# Out:
# WordList(['flower', 'cloud', 'raindrop'])

# %%
from textblob import Word

indices = Word('indices')

indices.singularize()
# Out:
# 'index'

# %%
from textblob import TextBlob

sentence = TextBlob('Ths sentense has missplled words')

sentence.correct()
# Out:
# TextBlob("The sentence has misspelled words")

# %%
from textblob import Word

w = Word('ussfll')

w.spellcheck()
# Out:
# [('useful', 0.9125), ('russell', 0.0875)]

# %%
from textblob import Word

word = Word('butterflies')

word.stem()
# Out:
# 'butterfli'

# %%
from textblob import Word
word = Word('leaves')
word.lemmatize()
# Out:
# 'leaf'

# %%
from textblob import Word
word = Word('leaves')
word.stem()
# Out:
# 'leav'

# %%
import urllib.request  # the lib that handles the url stuff

url = 'https://www.gutenberg.org/files/1112/1112.txt'
text = ''
for line in urllib.request.urlopen(url):
    text = text + line.decode('utf-8')+'\n'

# %%
blob = TextBlob(text)

blob.word_counts['juliet']
# Out:
# 72

# %%
blob.word_counts['romeo']
# Out:
# 162

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/joseph.ganser/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

stops = stopwords.words('english')

blob = TextBlob('TextBlob is easy to use.')

[word for word in blob.words if word not in stops]
# Out:
# ['TextBlob', 'easy', 'use']

# %%
stops
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
from textblob import TextBlob

text = 'Today is a beautiful day. Tomorrow looks like bad weather.'

blob = TextBlob(text)

blob.ngrams(n=3)
# Out:
# [WordList(['Today', 'is', 'a']),
#  WordList(['is', 'a', 'beautiful']),
#  WordList(['a', 'beautiful', 'day']),
#  WordList(['beautiful', 'day', 'Tomorrow']),
#  WordList(['day', 'Tomorrow', 'looks']),
#  WordList(['Tomorrow', 'looks', 'like']),
#  WordList(['looks', 'like', 'bad']),
#  WordList(['like', 'bad', 'weather'])]

# %%
from textblob import TextBlob

text = 'Today is a beautiful day. Tomorrow looks like bad weather.'

blob = TextBlob(text)

blob.ngrams(n=2)
# Out:
# [WordList(['Today', 'is']),
#  WordList(['is', 'a']),
#  WordList(['a', 'beautiful']),
#  WordList(['beautiful', 'day']),
#  WordList(['day', 'Tomorrow']),
#  WordList(['Tomorrow', 'looks']),
#  WordList(['looks', 'like']),
#  WordList(['like', 'bad']),
#  WordList(['bad', 'weather'])]

# %%
import urllib.request
from textblob import TextBlob
from nltk.corpus import stopwords
from operator import itemgetter
import pandas as pd
import matplotlib.pyplot as plt
url = 'https://www.gutenberg.org/files/1112/1112.txt'
text = ''
for line in urllib.request.urlopen(url):
    text = text + line.decode('utf-8')+'\n'

blob = TextBlob(text)
stop_words = stopwords.words('english')    

items = blob.word_counts.items()
items = [item for item in items if item[0] not in stop_words]
sorted_items = sorted(items,key=itemgetter(1),reverse=True)
top20 = sorted_items[1:21]
df = pd.DataFrame(top20,columns=['word','count'])
axes = df.plot.bar(y='count',x='word',legend=False)
plt.title('Top 20 word counts, romeo & juliet text')
plt.gcf().tight_layout()
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/joseph.ganser/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
items = blob.word_counts.items()
items1 = [item for item in items if item[0] not in stop_words]
sorted_items = sorted(items1,key=itemgetter(1),reverse=True)

# %%
sorted_items
# Out:
# [('thou', 278),
#  ('thy', 164),
#  ('rom', 163),
#  ('romeo', 162),
#  ('nurse', 150),
#  ('love', 148),
#  ('thee', 138),
#  ('jul', 117),
#  ('shall', 112),
#  ('come', 99),
#  ('friar', 93),
#  ('project', 90),
#  ('enter', 82),
#  ('good', 82),
#  ('man', 77),
#  ('lady', 77),
#  ('go', 76),
#  ('night', 73),
#  ('juliet', 72),
#  ('death', 72),
#  ('may', 66),
#  ('one', 65),
#  ('tybalt', 65),
#  ('ben', 64),
#  ('hath', 64),
#  ('mer', 62),
#  ('well', 60),
#  ('sir', 56),
#  ('would', 56),
#  ('gutenberg-tm', 56),
#  ('art', 55),
#  ('cap', 53),
#  ('give', 52),
#  ('say', 52),
#  ('let', 51),
#  ('must', 50),
#  ('dead', 49),
#  ('day', 48),
#  ('work', 48),
#  ('wife', 47),
#  ('doth', 47),
#  ('yet', 47),
#  ('upon', 46),
#  ('tell', 45),
#  ('capulet', 44),
#  ('fair', 44),
#  ('make', 43),
#  ('prince', 42),
#  ('like', 41),
#  ('take', 41),
#  ('see', 40),
#  ('much', 38),
#  ('works', 36),
#  ('paris', 36),
#  ('know', 36),
#  ('old', 35),
#  ('time', 34),
#  ('gutenberg', 33),
#  ('montague', 33),
#  ('exit', 33),
#  ('look', 33),
#  ('exeunt', 33),
#  ('sweet', 33),
#  ('heart', 33),
#  ('gone', 33),
#  ('god', 32),
#  ('ay', 31),
#  ('us', 31),
#  ('stay', 31),
#  ('lord', 31),
#  ('wilt', 30),
#  ('mother', 30),
#  ('electronic', 29),
#  ('word', 29),
#  ('back', 29),
#  ('light', 29),
#  ('father', 29),
#  ('mine', 29),
#  ('house', 28),
#  ('men', 28),
#  ('speak', 28),
#  ('eyes', 28),
#  ('hast', 28),
#  ('heaven', 28),
#  ('away', 27),
#  ('scene', 27),
#  ('part', 27),
#  ('hence', 27),
#  ('name', 27),
#  ('use', 26),
#  ('mercutio', 26),
#  ('stand', 26),
#  ('true', 26),
#  ('comes', 26),
#  ('call', 26),
#  ('dear', 26),
#  ('two', 25),
#  ('hand', 25),
#  ('foundation', 25),
#  ('young', 24),
#  ('life', 24),
#  ('find', 24),
#  ('full', 24),
#  ('therefore', 23),
#  ('marry', 23),
#  ('hear', 23),
#  ('madam', 23),
#  ('bed', 23),
#  ('die', 23),
#  ('par', 23),
#  ('within', 23),
#  ('watch', 23),
#  ('terms', 22),
#  ('laurence', 22),
#  ('till', 22),
#  ('bid', 22),
#  ('face', 22),
#  ('world', 21),
#  ('made', 21),
#  ('forth', 21),
#  ('lie', 21),
#  ('without', 21),
#  ('farewell', 21),
#  ('think', 21),
#  ('holy', 21),
#  ('help', 21),
#  ('peter', 20),
#  ('samp', 20),
#  ('nay', 20),
#  ('ere', 20),
#  ('tears', 20),
#  ('county', 20),
#  ('serv', 20),
#  ('live', 19),
#  ('peace', 19),
#  ('earth', 19),
#  ('lies', 19),
#  ('married', 19),
#  ('early', 18),
#  ('set', 18),
#  ('long', 18),
#  ('verona', 18),
#  ('son', 18),
#  ('could', 18),
#  ('keep', 18),
#  ('hold', 18),
#  ('cousin', 18),
#  ('ah', 18),
#  ('never', 18),
#  ('eye', 18),
#  ('pray', 18),
#  ('faith', 18),
#  ('alone', 18),
#  ('agreement', 18),
#  ('benvolio', 17),
#  ('daughter', 17),
#  ('blood', 17),
#  ('tyb', 17),
#  ('villain', 17),
#  ('many', 17),
#  ('poor', 17),
#  ('lips', 17),
#  ('kill', 17),
#  ('cell', 17),
#  ('slain', 17),
#  ('banished', 17),
#  ('1', 16),
#  ('friend', 16),
#  ('new', 16),
#  ('put', 16),
#  ('grave', 16),
#  ('rest', 16),
#  ('breath', 16),
#  ('hour', 16),
#  ('sun', 16),
#  ('dost', 16),
#  ('child', 16),
#  ('license', 15),
#  ('mantua', 15),
#  ('whose', 15),
#  ('greg', 15),
#  ('fear', 15),
#  ('talk', 15),
#  ('said', 15),
#  ('none', 15),
#  ('fall', 15),
#  ('to-night', 15),
#  ('to-morrow', 15),
#  ('letter', 15),
#  ('news', 15),
#  ('donations', 15),
#  ('copyright', 14),
#  ('kinsman', 14),
#  ('place', 14),
#  ('lives', 14),
#  ('head', 14),
#  ('nothing', 14),
#  ('still', 14),
#  ('thine', 14),
#  ('get', 14),
#  ('another', 14),
#  ('poison', 14),
#  ('soul', 14),
#  ('gentleman', 14),
#  ('woe', 14),
#  ('boy', 14),
#  ('joy', 14),
#  ('send', 14),
#  ('haste', 14),
#  ('thursday', 14),
#  ('mus', 14),
#  ('states', 14),
#  ('ebook', 13),
#  ('public', 13),
#  ('makes', 13),
#  ('hands', 13),
#  ('turn', 13),
#  ('run', 13),
#  ('law', 13),
#  ('hate', 13),
#  ('ho', 13),
#  ('came', 13),
#  ('soon', 13),
#  ('beauty', 13),
#  ('grief', 13),
#  ('else', 13),
#  ('leave', 13),
#  ('even', 13),
#  ('days', 13),
#  ('husband', 13),
#  ('thing', 13),
#  ('little', 13),
#  ('sound', 13),
#  ('literary', 13),
#  ('archive', 13),
#  ('copy', 12),
#  ('access', 12),
#  ('ever', 12),
#  ('bear', 12),
#  ('aside', 12),
#  ('better', 12),
#  ('master', 12),
#  ('happy', 12),
#  ('gentle', 12),
#  ('sleep', 12),
#  ('ill', 12),
#  ('wit', 12),
#  ('years', 12),
#  ('best', 12),
#  ('late', 12),
#  ('hither', 12),
#  ('sin', 12),
#  ('shame', 12),
#  ('trademark', 11),
#  ('gentlemen', 11),
#  ('lay', 11),
#  ('end', 11),
#  ('draw', 11),
#  ('quarrel', 11),
#  ('show', 11),
#  ('shalt', 11),
#  ('morning', 11),
#  ('means', 11),
#  ('way', 11),
#  ('mistress', 11),
#  ("o'er", 11),
#  ('though', 11),
#  ('ye', 11),
#  ('since', 11),
#  ('need', 11),
#  ('warrant', 11),
#  ('marriage', 11),
#  ('every', 11),
#  ('state', 11),
#  ('pale', 11),
#  ('tongue', 11),
#  ('alack', 11),
#  ('pardon', 11),
#  ('bring', 11),
#  ('body', 11),
#  ('paragraph', 11),
#  ('2', 10),
#  ('three', 10),
#  ('ears', 10),
#  ('wall', 10),
#  ('maid', 10),
#  ('mon', 10),
#  ('either', 10),
#  ('saw', 10),
#  ('found', 10),
#  ('heavy', 10),
#  ('black', 10),
#  ('unless', 10),
#  ('rich', 10),
#  ('kiss', 10),
#  ('bound', 10),
#  ('agree', 10),
#  ('comfort', 10),
#  ('mad', 10),
#  ('rosaline', 10),
#  ("ne'er", 10),
#  ('calls', 10),
#  ('done', 10),
#  ('dream', 10),
#  ('thus', 10),
#  ('straight', 10),
#  ('things', 10),
#  ('music', 10),
#  ('says', 10),
#  ('answer', 10),
#  ('tomb', 10),
#  ('church', 10),
#  ('fee', 10),
#  ('pet', 10),
#  ('united', 10),
#  ('refund', 10),
#  ('domain', 9),
#  ('copies', 9),
#  ('others', 9),
#  ('john', 9),
#  ('musicians', 9),
#  ('ancient', 9),
#  ('mean', 9),
#  ('move', 9),
#  ('foot', 9),
#  ('ground', 9),
#  ('case', 9),
#  ('right', 9),
#  ('chamber', 9),
#  ('first', 9),
#  ('weep', 9),
#  ('arm', 9),
#  ('forget', 9),
#  ('unto', 9),
#  ('read', 9),
#  ('fellow', 9),
#  ('fortune', 9),
#  ('indeed', 9),
#  ('great', 9),
#  ('sight', 9),
#  ('flower', 9),
#  ('swear', 9),
#  ('play', 9),
#  ('saint', 9),
#  ('meet', 9),
#  ('return', 9),
#  ('twenty', 9),
#  ('form', 9),
#  ('silver', 9),
#  ('thought', 9),
#  ('charge', 9),
#  ('vault', 9),
#  ('bal', 9),
#  ('william', 8),
#  ('shakespeare', 8),
#  ('permission', 8),
#  ('lovers', 8),
#  ('bite', 8),
#  ('mind', 8),
#  ('clouds', 8),
#  ('counsel', 8),
#  ('alas', 8),
#  ('hide', 8),
#  ('welcome', 8),
#  ('written', 8),
#  ('last', 8),
#  ('desperate', 8),
#  ('merry', 8),
#  ('ask', 8),
#  ('enough', 8),
#  ('follow', 8),
#  ('torch', 8),
#  ('times', 8),
#  ('anon', 8),
#  ('bosom', 8),
#  ('vile', 8),
#  ('3', 8),
#  ('high', 8),
#  ('sorrow', 8),
#  ('woes', 8),
#  ('bones', 8),
#  ('hie', 8),
#  ('page', 8),
#  ('banishment', 8),
#  ('dagger', 8),
#  ('associated', 8),
#  ('http', 8),
#  ('laws', 8),
#  ('including', 8),
#  ('information', 8),
#  ('date', 7),
#  ('proud', 7),
#  ('library', 7),
#  ('distribution', 7),
#  ('heads', 7),
#  ('houses', 7),
#  ('balthasar', 7),
#  ('servant', 7),
#  ('fearful', 7),
#  ('hours', 7),
#  ('act', 7),
#  ('feel', 7),
#  ('pretty', 7),
#  ('flesh', 7),
#  ('sword', 7),
#  ('bloody', 7),
#  ('home', 7),
#  ('cause', 7),
#  ('noble', 7),
#  ('air', 7),
#  ('short', 7),
#  ('cold', 7),
#  ('sick', 7),
#  ('sea', 7),
#  ('near', 7),
#  ('hit', 7),
#  ('canst', 7),
#  ('behold', 7),
#  ('stars', 7),
#  ('dark', 7),
#  ('writ', 7),
#  ('book', 7),
#  ('brother', 7),
#  ('fool', 7),
#  ('thousand', 7),
#  ('knock', 7),
#  ('wish', 7),
#  ('beseech', 7),
#  ('measure', 7),
#  ('tender', 7),
#  ('web', 7),
#  ('ear', 7),
#  ('hot', 7),
#  ('sit', 7),
#  ('past', 7),
#  ('fetch', 7),
#  ('prepare', 7),
#  ('honest', 7),
#  ('looks', 7),
#  ('orchard', 7),
#  ('kind', 7),
#  ('thyself', 7),
#  ('words', 7),
#  ('sudden', 7),
#  ('next', 7),
#  ('second', 7),
#  ('goose', 7),
#  ('falls', 7),
#  ('corse', 7),
#  ('free', 7),
#  ('monument', 7),
#  ('woful', 7),
#  ('churchyard', 7),
#  ('chief', 7),
#  ('distributing', 7),
#  ('ebooks', 7),
#  ('section', 7),
#  ('provide', 7),
#  ('anyone', 6),
#  ('future', 6),
#  ('provided', 6),
#  ('distributed', 6),
#  ('gregory', 6),
#  ('citizens', 6),
#  ('moved', 6),
#  ('dog', 6),
#  ('stir', 6),
#  ('shows', 6),
#  ('maids', 6),
#  ('hadst', 6),
#  ('thumb', 6),
#  ('serve', 6),
#  ('remember', 6),
#  ('fight', 6),
#  ('among', 6),
#  ('capulets', 6),
#  ('noise', 6),
#  ('foe', 6),
#  ('fire', 6),
#  ('close', 6),
#  ('hurt', 6),
#  ('might', 6),
#  ('seen', 6),
#  ('deep', 6),
#  ('prove', 6),
#  ('envious', 6),
#  ('please', 6),
#  ('morrow', 6),
#  ('loving', 6),
#  ('anything', 6),
#  ('lead', 6),
#  ('breast', 6),
#  ('mark', 6),
#  ('ii', 6),
#  ('street', 6),
#  ('fourteen', 6),
#  ('feast', 6),
#  ('sirrah', 6),
#  ('person', 6),
#  ('gives', 6),
#  ('match', 6),
#  ('iii', 6),
#  ('girl', 6),
#  ('matter', 6),
#  ('awhile', 6),
#  ('age', 6),
#  ('took', 6),
#  ('jest', 6),
#  ('wast', 6),
#  ('already', 6),
#  ('less', 6),
#  ('strength', 6),
#  ('spoke', 6),
#  ('care', 6),
#  ('kisses', 6),
#  ('ha', 6),
#  ('tale', 6),
#  ('r', 6),
#  ('yonder', 6),
#  ('cheek', 6),
#  ('youth', 6),
#  ('thank', 6),
#  ('enemy', 6),
#  ('strange', 6),
#  ('nature', 6),
#  ('speaks', 6),
#  ('murther', 6),
#  ('didst', 6),
#  ('company', 6),
#  ('flowers', 6),
#  ('cheeks', 6),
#  ('cords', 6),
#  ('fie', 6),
#  ('reason', 6),
#  ('hang', 6),
#  ('doom', 6),
#  ('exile', 6),
#  ('lark', 6),
#  ('distribute', 6),
#  ('comply', 6),
#  ('paid', 6),
#  ('tax', 6),
#  ('volunteers', 6),
#  ('almost', 5),
#  ('count', 5),
#  ('apothecary', 5),
#  ('maskers', 5),
#  ('break', 5),
#  ('piteous', 5),
#  ('remove', 5),
#  ('swords', 5),
#  ('strike', 5),
#  ('quickly', 5),
#  ('montagues', 5),
#  ('dare', 5),
#  ('abr', 5),
#  ('side', 5),
#  ('hell', 5),
#  ('pay', 5),
#  ('pleasure', 5),
#  ('withal', 5),
#  ('scorn', 5),
#  ('window', 5),
#  ('city', 5),
#  ('sighs', 5),
#  ('far', 5),
#  ('shrift', 5),
#  ('nine', 5),
#  ('sad', 5),
#  ('rough', 5),
#  ('bright', 5),
#  ('soft', 5),
#  ('cupid', 5),
#  ('th', 5),
#  ('gold', 5),
#  ('wise', 5),
#  ('wisely', 5),
#  ('ladies', 5),
#  ('blind', 5),
#  ('honourable', 5),
#  ('change', 5),
#  ('bride', 5),
#  ('woo', 5),
#  ('consent', 5),
#  ('voice', 5),
#  ('number', 5),
#  ('shut', 5),
#  ('letters', 5),
#  ('crow', 5),
#  ('knowest', 5),
#  ('laid', 5),
#  ('quoth', 5),
#  ('bad', 5),
#  ('grace', 5),
#  ('honour', 5),
#  ('brief', 5),
#  ('servingman', 5),
#  ('iv', 5),
#  ('five', 5),
#  ('excuse', 5),
#  ('dance', 5),
#  ('wings', 5),
#  ('rude', 5),
#  ('phrase', 5),
#  ('wits', 5),
#  ('asleep', 5),
#  ('shape', 5),
#  ('small', 5),
#  ('half', 5),
#  ('fingers', 5),
#  ('fees', 5),
#  ('dreams', 5),
#  ('anger', 5),
#  ('untimely', 5),
#  ('course', 5),
#  ('v', 5),
#  ('ready', 5),
#  ('longer', 5),
#  ("is't", 5),
#  ('blessed', 5),
#  ('wherefore', 5),
#  ('truth', 5),
#  ('patience', 5),
#  ('fine', 5),
#  ('yond', 5),
#  ('heir', 5),
#  ('wedding', 5),
#  ('power', 5),
#  ('satisfied', 5),
#  ('open', 5),
#  ('business', 5),
#  ('tear', 5),
#  ('wash', 5),
#  ('fain', 5),
#  ('trust', 5),
#  ('gave', 5),
#  ('purpose', 5),
#  ('by-and-by', 5),
#  ('met', 5),
#  ('ring', 5),
#  ('chide', 5),
#  ('wench', 5),
#  ('lamentable', 5),
#  ('ease', 5),
#  ('stop', 5),
#  ('hare', 5),
#  ('commend', 5),
#  ('joyful', 5),
#  ('simple', 5),
#  ('draws', 5),
#  ('slew', 5),
#  ('point', 5),
#  ('mercy', 5),
#  ('general', 5),
#  ('living', 5),
#  ('banish', 5),
#  ('search', 5),
#  ('hope', 5),
#  ('wake', 5),
#  ('iron', 5),
#  ('compliance', 5),
#  ('1.e.1', 5),
#  ('posted', 5),
#  ('owner', 5),
#  ('medium', 5),
#  ('1.f.3', 5),
#  ('replacement', 5),
#  ('limited', 5),
#  ('received', 5),
#  ('cost', 4),
#  ('online', 4),
#  ('complete', 4),
#  ('charges', 4),
#  ('used', 4),
#  ('nephew', 4),
#  ('sampson', 4),
#  ('civil', 4),
#  ('fatal', 4),
#  ('rage', 4),
#  ('women', 4),
#  ('fought', 4),
#  ('cruel', 4),
#  ('cut', 4),
#  ('known', 4),
#  ('pass', 4),
#  ('kinsmen', 4),
#  ('beats', 4),
#  ('beat', 4),
#  ('spite', 4),
#  ('seek', 4),
#  ('steel', 4),
#  ('veins', 4),
#  ('torture', 4),
#  ('sentence', 4),
#  ('quiet', 4),
#  ('streets', 4),
#  ('depart', 4),
#  ('along', 4),
#  ('approach', 4),
#  ('fray', 4),
#  ('golden', 4),
#  ('east', 4),
#  ('walk', 4),
#  ('abroad', 4),
#  ('towards', 4),
#  ('sought', 4),
#  ('dew', 4),
#  ('daylight', 4),
#  ('uncle', 4),
#  ('learn', 4),
#  ('secret', 4),
#  ('sadness', 4),
#  ('coz', 4),
#  ('rather', 4),
#  ('tut', 4),
#  ('dies', 4),
#  ('forsworn', 4),
#  ('vow', 4),
#  ('note', 4),
#  ('paper', 4),
#  ('names', 4),
#  ('writing', 4),
#  ('signior', 4),
#  ('supper', 4),
#  ('thither', 4),
#  ('lamb', 4),
#  ('brow', 4),
#  ('yea', 4),
#  ('left', 4),
#  ('choose', 4),
#  ('stands', 4),
#  ('wisdom', 4),
#  ('lover', 4),
#  ('fly', 4),
#  ('guests', 4),
#  ('believe', 4),
#  ('going', 4),
#  ('empty', 4),
#  ('oft', 4),
#  ('foul', 4),
#  ('deny', 4),
#  ('worn', 4),
#  ('fellows', 4),
#  ('dares', 4),
#  ('town', 4),
#  ('lest', 4),
#  ('sake', 4),
#  ('birth', 4),
#  ('ran', 4),
#  ('conjure', 4),
#  ('appear', 4),
#  ('cry', 4),
#  ('raise', 4),
#  ('spirit', 4),
#  ('tree', 4),
#  ('arise', 4),
#  ('moon', 4),
#  ('green', 4),
#  ('wear', 4),
#  ('bold', 4),
#  ('hateful', 4),
#  ('lent', 4),
#  ('lightning', 4),
#  ('cease', 4),
#  ('adieu', 4),
#  ('ghostly', 4),
#  ('dry', 4),
#  ('womb', 4),
#  ('slow', 4),
#  ('sure', 4),
#  ('flies', 4),
#  ('wild', 4),
#  ('broad', 4),
#  ('wide', 4),
#  ('hair', 4),
#  ('gentlewoman', 4),
#  ('fault', 4),
#  ('something', 4),
#  ('hoar', 4),
#  ('sings', 4),
#  ('minute', 4),
#  ('knave', 4),
#  ('hark', 4),
#  ('knife', 4),
#  ('warm', 4),
#  ('sour', 4),
#  ('beshrew', 4),
#  ('heavens', 4),
#  ('amen', 4),
#  ('receive', 4),
#  ('friends', 4),
#  ('beg', 4),
#  ('loss', 4),
#  ('damned', 4),
#  ('following', 4),
#  ('weeping', 4),
#  ('weeps', 4),
#  ('slay', 4),
#  ('coming', 4),
#  ('doubt', 4),
#  ('nightly', 4),
#  ('bridegroom', 4),
#  ('waking', 4),
#  ('needs', 4),
#  ('seal', 4),
#  ('buried', 4),
#  ('office', 4),
#  ('money', 4),
#  ('sell', 4),
#  ('apoth', 4),
#  ('laur', 4),
#  ('notice', 4),
#  ('strew', 4),
#  ('intents', 4),
#  ('people', 4),
#  ('editions', 4),
#  ('creating', 4),
#  ('copying', 4),
#  ('mission', 4),
#  ('using', 4),
#  ('1.e.8', 4),
#  ('collection', 4),
#  ('individual', 4),
#  ('located', 4),
#  ('displaying', 4),
#  ('support', 4),
#  ('freely', 4),
#  ('format', 4),
#  ('status', 4),
#  ('holder', 4),
#  ('providing', 4),
#  ('requirements', 4),
#  ('additional', 4),
#  ('site', 4),
#  ('contact', 4),
#  ('damages', 4),
#  ('pglaf.org', 4),
#  ('files', 3),
#  ('title', 3),
#  ('anywhere', 3),
#  ('included', 3),
#  ('ascii', 3),
#  ('start', 3),
#  ('neither', 3),
#  ('readable', 3),
#  ('chorus', 3),
#  ('franciscan', 3),
#  ('officer', 3),
#  ('servants', 3),
#  ('prologue', 3),
#  ('alike', 3),
#  ('bury', 3),
#  ('children', 3),
#  ('naught', 3),
#  ('patient', 3),
#  ('attend', 3),
#  ('toil', 3),
#  ('carry', 3),
#  ('weak', 3),
#  ('slave', 3),
#  ('goes', 3),
#  ('thrust', 3),
#  ('sense', 3),
#  ('servingmen', 3),
#  ('begin', 3),
#  ('drawn', 3),
#  ('four', 3),
#  ('partisans', 3),
#  ('pain', 3),
#  ('airy', 3),
#  ('disturb', 3),
#  ('cast', 3),
#  ('afternoon', 3),
#  ('farther', 3),
#  ('judgment', 3),
#  ('blows', 3),
#  ('to-day', 3),
#  ('affections', 3),
#  ('humour', 3),
#  ('curtains', 3),
#  ('spread', 3),
#  ('cure', 3),
#  ('wert', 3),
#  ('fast', 3),
#  ('view', 3),
#  ('proof', 3),
#  ('laugh', 3),
#  ('oppression', 3),
#  ('griefs', 3),
#  ('lost', 3),
#  ('groan', 3),
#  ('urg', 3),
#  ('woman', 3),
#  ('lov', 3),
#  ('strong', 3),
#  ('bow', 3),
#  ('encounter', 3),
#  ('sworn', 3),
#  ('waste', 3),
#  ('making', 3),
#  ('teach', 3),
#  ('giving', 3),
#  ('liberty', 3),
#  ('beauties', 3),
#  ('brows', 3),
#  ('precious', 3),
#  ('hard', 3),
#  ('suit', 3),
#  ('delight', 3),
#  ('sent', 3),
#  ('backward', 3),
#  ('madman', 3),
#  ('food', 3),
#  ('cup', 3),
#  ('compare', 3),
#  ('often', 3),
#  ('seems', 3),
#  ('year', 3),
#  ('forbid', 3),
#  ('susan', 3),
#  ('dug', 3),
#  ('brain', 3),
#  ('taste', 3),
#  ('bitter', 3),
#  ('jule', 3),
#  ('wretch', 3),
#  ("e'er", 3),
#  ('summer', 3),
#  ('lends', 3),
#  ('content', 3),
#  ('cover', 3),
#  ('share', 3),
#  ('possess', 3),
#  ('burthen', 3),
#  ('prick', 3),
#  ('visor', 3),
#  ('blush', 3),
#  ('mouse', 3),
#  ('burn', 3),
#  ('delay', 3),
#  ('vain', 3),
#  ('meaning', 3),
#  ('dreamt', 3),
#  ('mab', 3),
#  ('knees', 3),
#  ('sometime', 3),
#  ('substance', 3),
#  ('inconstant', 3),
#  ('wind', 3),
#  ('clos', 3),
#  ('sail', 3),
#  ('save', 3),
#  ('loves', 3),
#  ('grown', 3),
#  ('mask', 3),
#  ('thirty', 3),
#  ('rapier', 3),
#  ('solemnity', 3),
#  ('virtuous', 3),
#  ('chance', 3),
#  ('contrary', 3),
#  ('hearts', 3),
#  ('different', 3),
#  ('withdraw', 3),
#  ('seeming', 3),
#  ('touch', 3),
#  ('saints', 3),
#  ('craves', 3),
#  ('door', 3),
#  ('passion', 3),
#  ('n', 3),
#  ('likeness', 3),
#  ('pronounce', 3),
#  ('shot', 3),
#  ('hid', 3),
#  ('wound', 3),
#  ('knew', 3),
#  ('gaze', 3),
#  ('drunk', 3),
#  ('hundred', 3),
#  ('walls', 3),
#  ('dwell', 3),
#  ('mayst', 3),
#  ('fond', 3),
#  ('confess', 3),
#  ('exchange', 3),
#  ('faithful', 3),
#  ('worse', 3),
#  ('toward', 3),
#  ('wanton', 3),
#  ('bird', 3),
#  ('morn', 3),
#  ('turns', 3),
#  ('keeps', 3),
#  ('lo', 3),
#  ('plain', 3),
#  ('confession', 3),
#  ('truly', 3),
#  ('jesu', 3),
#  ('salt', 3),
#  ...]

# %%
from wordcloud import WordCloud
import imageio

img_url = "heart.png"
mask_image = imageio.imread(img_url)
wordcloud = WordCloud(colormap='prism')#,mask=mask_image)
wordcloud = wordcloud.generate(text)
wordcloud.to_file('word_cloud2.png')

# %%
# !pip install textatistic
# Out:
# Collecting textastic
#   ERROR: Could not find a version that satisfies the requirement textastic (from versions: none)
# ERROR: No matching distribution found for textastic
# WARNING: You are using pip version 20.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import urllib.request
url = 'https://www.gutenberg.org/files/1112/1112.txt'
text = ''
for line in urllib.request.urlopen(url):
    text = text + line.decode('utf-8')+'\n'

# %%
from textatistic import Textatistic
readability = Textatistic(text)
readability.dict()
# Out:
# {'char_count': 128909,
#  'word_count': 29228,
#  'sent_count': 3557,
#  'sybl_count': 34791,
#  'notdalechall_count': 6392,
#  'polysyblword_count': 898,
#  'flesch_score': 97.79268900649028,
#  'fleschkincaid_score': 1.6605523966200781,
#  'gunningfog_score': 4.515773264428966,
#  'smog_score': 5.9994917394147285,
#  'dalechall_score': 7.497249644197978}

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-14d257ed08ca> in <module>
#       1 import spacy
# ----> 2 nlp = spacy.load("en_core_web_sm")
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/__init__.py in load(name, vocab, disable, exclude, config)
#      50     """
#      51     return util.load_model(
# ---> 52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#      54
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model(name, vocab, disable, exclude, config)
#     425     if name in OLD_MODEL_SHORTCUTS:
#     426         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 427     raise IOError(Errors.E050.format(name=name))
#     428
#     429
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.
